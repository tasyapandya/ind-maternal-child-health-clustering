# %% [markdown]
# # Setup

# %%
# !pip install pyreadstat
# Out:
# Collecting pyreadstat
#   Downloading pyreadstat-1.3.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: narwhals>=2.0 in /usr/local/lib/python3.12/dist-packages (from pyreadstat) (2.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyreadstat) (2.0.2)
# Downloading pyreadstat-1.3.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 49.5 MB/s eta 0:00:00
# Installing collected packages: pyreadstat
# Successfully installed pyreadstat-1.3.2

# %%
import pandas as pd
import pyreadstat
import zipfile
import os
import numpy as np
import warnings
import re

warnings.filterwarnings('ignore')

# %% [markdown]
# # Extract Main Indicators
#
# Purpose: Process DHS (Demographic and Health Survey) data to create regional-level indicators for maternal and child health services.

# %% [markdown]
# ## A. Data DHS (2017)

# %% [markdown]
# ### 1. Load Data

# %%
print("Preprocessing Data SDKI 2017...")

ibu_dta_path = 'IDIR71FL.DTA' # File ibu
anak_dta_path = 'IDKR71FL.DTA' # File anak
rt_dta_path = 'IDHR71FL.DTA'   # File Rumah Tangga
lahir_dta_path = 'IDBR71FL.DTA' # File Kelahiran

print("\nMembaca file data Stata (.DTA)...")

try:
    df_ibu, meta_ibu = pyreadstat.read_dta(ibu_dta_path)
    df_anak, meta_anak = pyreadstat.read_dta(anak_dta_path)
    df_rt, meta_rt = pyreadstat.read_dta(rt_dta_path)
    df_lahir, meta_lahir = pyreadstat.read_dta(lahir_dta_path)
    print("File Ibu, Rumah Tangga, Kelahiran, & Anak (.DTA) berhasil dibaca.")
except Exception as e:
    print(f"Error saat membaca file: {e}")
    exit()

df_ibu.columns = df_ibu.columns.str.lower()
df_anak.columns = df_anak.columns.str.lower()
df_rt.columns = df_rt.columns.str.lower()
df_lahir.columns = df_lahir.columns.str.lower()

print("\n--- Check Dataset ---")
print("Jumlah kolom di df_ibu:", len(df_ibu.columns))
print("Jumlah kolom di df_anak:", len(df_anak.columns))
print("Jumlah kolom di df_rt:", len(df_rt.columns))
print("Jumlah kolom di df_lahir:", len(df_lahir.columns))
print("-------------------------------------------------------")
# Out:
# Preprocessing Data SDKI 2017...
#
# Membaca file data Stata (.DTA)...
# File Ibu, Rumah Tangga, Kelahiran, & Anak (.DTA) berhasil dibaca.
#
# --- Check Dataset ---
# Jumlah kolom di df_ibu: 5491
# Jumlah kolom di df_anak: 1678
# Jumlah kolom di df_rt: 1283
# Jumlah kolom di df_lahir: 1678
# -------------------------------------------------------

# %% [markdown]
# ### 2. Check Variable Name

# %%
print("\n--- Mencari Variabel Pendidikan ---")
kata_kunci = 'educa'

for var, label in meta_ibu.column_names_to_labels.items():
    if kata_kunci in var.lower() or kata_kunci in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Pendidikan ---
# Nama Variabel: v106, Label: highest educational level
# Nama Variabel: v107, Label: highest year of education
# Nama Variabel: v133, Label: education in single years
# Nama Variabel: v149, Label: educational attainment
# Nama Variabel: awfacte, Label: all woman factor - educational
# Nama Variabel: v701, Label: husband/partner's education level
# Nama Variabel: v702, Label: husband/partner's highest year of education (at level in v701)
# Nama Variabel: v715, Label: husband/partner's total number of years of education
# Nama Variabel: v729, Label: husband/partner's educational attainment
# Nama Variabel: s108, Label: highest educational level
# Nama Variabel: s904, Label: partner's level of education
# ---------------------------------

# %%
print("\n--- Mencari Variabel Ukuran Bayi Lahir ---")

kata_kunci_1 = 'size'  # Kata kunci: ukuran
kata_kunci_2 = 'weight' # Kata kunci: berat

for var, label in meta_anak.column_names_to_labels.items():
    if kata_kunci_1 in label.lower() or kata_kunci_2 in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Ukuran Bayi Lahir ---
# Nama Variabel: v005, Label: women's individual sample weight (6 decimals)
# Nama Variabel: v419, Label: entries in height/weight roster
# Nama Variabel: v437, Label: na - respondent's weight in kilograms (1 decimal)
# Nama Variabel: v442, Label: na - weight/height percent ref. median (dhs)
# Nama Variabel: v443, Label: na - weight/height percent ref. median (fog)
# Nama Variabel: v444, Label: na - weight/height percent ref. median (who)
# Nama Variabel: v444a, Label: weight/height standard deviation (dhs)
# Nama Variabel: v447, Label: na - result of measurement - height/weight
# Nama Variabel: m18, Label: size of child at birth
# Nama Variabel: m19, Label: birth weight in kilograms (3 decimals)
# Nama Variabel: m19a, Label: weight at birth/recall
# Nama Variabel: hw2, Label: na - child's weight in kilograms (1 decimal)
# Nama Variabel: hw7, Label: na - weight/age percentile
# Nama Variabel: hw8, Label: na - weight/age standard deviation
# Nama Variabel: hw9, Label: na - weight/age percent of ref. median
# Nama Variabel: hw10, Label: na - weight/height percentile
# Nama Variabel: hw11, Label: na - weight/height standard deviation
# Nama Variabel: hw12, Label: na - weight/height percent of ref. median
# Nama Variabel: hw13, Label: na - result of measurement - height/weight
# Nama Variabel: hw71, Label: na - weight/age standard deviation (new who)
# Nama Variabel: hw72, Label: na - weight/height standard deviation (new who)
# Nama Variabel: s1042ck, Label: male sti symptoms: loss of weight
# Nama Variabel: s1042dk, Label: female sti symptoms: loss of weight
# ---------------------------------

# %%
print("\n--- Mencari Variabel Penolong Persalinan ---")
kata_kunci_1 = 'delivery'
kata_kunci_2 = 'birth'
kata_kunci_3 = 'attendant'

for var, label in meta_lahir.column_names_to_labels.items():
    if kata_kunci_1 in label.lower() or kata_kunci_2 in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Penolong Persalinan ---
# Nama Variabel: bidx, Label: birth column number
# Nama Variabel: v009, Label: respondent's month of birth
# Nama Variabel: v010, Label: respondent's year of birth
# Nama Variabel: v011, Label: date of birth (cmc)
# Nama Variabel: v208, Label: births in last five years
# Nama Variabel: v209, Label: births in past year
# Nama Variabel: v210, Label: births in month of interview
# Nama Variabel: v211, Label: date of first birth (cmc)
# Nama Variabel: v212, Label: age of respondent at 1st birth
# Nama Variabel: v221, Label: marriage to first birth interval (months)
# Nama Variabel: v222, Label: last birth to interview (months)
# Nama Variabel: v224, Label: entries in birth history
# Nama Variabel: v237, Label: birth between last and interview
# Nama Variabel: v238, Label: births in last three years
# Nama Variabel: v244, Label: can women get pregnant after birth and before period
# Nama Variabel: v401, Label: last birth a caesarean section
# Nama Variabel: v468, Label: record for last birth
# Nama Variabel: v603, Label: preferred waiting time for birth of a/another child
# Nama Variabel: v604, Label: preferred waiting time for birth of a/another child (grouped)
# Nama Variabel: v616, Label: time for future birth
# Nama Variabel: v633c, Label: na - reason for not having sex: recent birth
# Nama Variabel: bord, Label: birth order number
# Nama Variabel: b1, Label: month of birth
# Nama Variabel: b2, Label: year of birth
# Nama Variabel: b3, Label: date of birth (cmc)
# Nama Variabel: b11, Label: preceding birth interval (months)
# Nama Variabel: b12, Label: succeeding birth interval (months)
# Nama Variabel: b15, Label: live birth between births
# Nama Variabel: b17, Label: na - day of birth
# Nama Variabel: b18, Label: na - century day code of birth (cdc)
# Nama Variabel: b19, Label: current age of child in months (months since birth for dead children)
# Nama Variabel: midx, Label: index to birth history
# Nama Variabel: m1, Label: number of tetanus injections before birth
# Nama Variabel: m2g, Label: prenatal: other person-traditional birth attendant
# Nama Variabel: m3g, Label: assistance: traditional birth attendant
# Nama Variabel: m15, Label: place of delivery
# Nama Variabel: m17, Label: delivery by caesarean section
# Nama Variabel: m18, Label: size of child at birth
# Nama Variabel: m19, Label: birth weight in kilograms (3 decimals)
# Nama Variabel: m19a, Label: weight at birth/recall
# Nama Variabel: m54, Label: na - received vitamin a dose in first 2 months after delivery
# Nama Variabel: m61, Label: time spent at place of delivery
# Nama Variabel: m66, Label: respondent's health checked after discharge/delivery at home
# Nama Variabel: m67, Label: how long after discharge/delivery at home respondent health check took place
# Nama Variabel: m68, Label: who checked respondent health after discharge/delivery at home
# Nama Variabel: m69, Label: where respondent check after discharge/delivery at home took place
# Nama Variabel: m71, Label: time after delivery postnatal check took place
# Nama Variabel: m77, Label: was child put on mother's chest and bare skin after birth
# Nama Variabel: hidx, Label: index to birth history
# Nama Variabel: h50, Label: received hepatitis b at birth
# Nama Variabel: h50d, Label: hepatitis b at birth day
# Nama Variabel: h50m, Label: hepatitis b at birth month
# Nama Variabel: h50y, Label: hepatitis b at birth year
# Nama Variabel: hidxa, Label: index to birth history
# Nama Variabel: h12u, Label: diarrhea: other traditional birth attendant
# Nama Variabel: hwidx, Label: na - index to birth history
# Nama Variabel: hw16, Label: na - day of birth of child
# Nama Variabel: idxml, Label: index to birth history
# Nama Variabel: s234a_1, Label: pregnancy end in miscarriage, abortion, or stillbirth
# Nama Variabel: s234a_2, Label: pregnancy end in miscarriage, abortion, or stillbirth
# Nama Variabel: s234a_3, Label: pregnancy end in miscarriage, abortion, or stillbirth
# Nama Variabel: s234a_4, Label: pregnancy end in miscarriage, abortion, or stillbirth
# Nama Variabel: s234a_5, Label: pregnancy end in miscarriage, abortion, or stillbirth
# Nama Variabel: s234a_6, Label: pregnancy end in miscarriage, abortion, or stillbirth
# Nama Variabel: s238ac, Label: number of times stillbirth before january 2012
# Nama Variabel: s714fa, Label: problems during labor/delivery: water breaks too soon
# Nama Variabel: s714fb, Label: problems during labor/delivery: excessive bleeding during and after delivery
# Nama Variabel: s714fc, Label: problems during labor/delivery: fever
# Nama Variabel: s714fd, Label: problems during labor/delivery: long labor
# Nama Variabel: s714fe, Label: problems during labor/delivery: faint
# Nama Variabel: s714ff, Label: problems during labor/delivery: convulsions
# Nama Variabel: s714fg, Label: problems during labor/delivery: placenta does not come out
# Nama Variabel: s714fh, Label: problems during labor/delivery: stillbirth
# Nama Variabel: s714fx, Label: problems during labor/delivery: other
# Nama Variabel: s714fz, Label: problems during labor/delivery: don't know
# Nama Variabel: s714ga, Label: should do if experience this problem during labor/delivery: nothing
# Nama Variabel: s714gb, Label: should do if experience this problem during labor/delivery: rest
# Nama Variabel: s714gc, Label: should do if experience this problem during labor/delivery: take medication
# Nama Variabel: s714gd, Label: should do if experience this problem during labor/delivery: take herbs
# Nama Variabel: s714ge, Label: should do if experience this problem during labor/delivery: see tba
# Nama Variabel: s714gf, Label: should do if experience this problem during labor/delivery: see midwife
# Nama Variabel: s714gg, Label: should do if experience this problem during labor/delivery: see doctor
# Nama Variabel: s714gh, Label: should do if experience this problem during labor/delivery: go to a health facil
# Nama Variabel: s714gx, Label: should do if experience this problem during labor/delivery: other
# Nama Variabel: s714gz, Label: should do if experience this problem during labor/delivery: don't know
# Nama Variabel: s714ha, Label: problems after giving birth/during seclusion: excessive bleeding
# Nama Variabel: s714hb, Label: problems after giving birth/during seclusion: faint
# Nama Variabel: s714hc, Label: problems after giving birth/during seclusion: convulsions
# Nama Variabel: s714hd, Label: problems after giving birth/during seclusion: fever
# Nama Variabel: s714he, Label: problems after giving birth/during seclusion: foul-smelling discharge
# Nama Variabel: s714hf, Label: problems after giving birth/during seclusion: sore breast
# Nama Variabel: s714hg, Label: problems after giving birth/during seclusion: sadness/depression
# Nama Variabel: s714hx, Label: problems after giving birth/during seclusion: other
# Nama Variabel: s714hz, Label: problems after giving birth/during seclusion: don't know
# Nama Variabel: s714ia, Label: should do if experience this problem after giving birth/during seclusion: nothin
# Nama Variabel: s714ib, Label: should do if experience this problem after giving birth/during seclusion: rest
# Nama Variabel: s714ic, Label: should do if experience this problem after giving birth/during seclusion: take m
# Nama Variabel: s714id, Label: should do if experience this problem after giving birth/during seclusion: take h
# Nama Variabel: s714ie, Label: should do if experience this problem after giving birth/during seclusion: see tb
# Nama Variabel: s714if, Label: should do if experience this problem after giving birth/during seclusion: see mi
# Nama Variabel: s714ig, Label: should do if experience this problem after giving birth/during seclusion: see do
# Nama Variabel: s714ih, Label: should do if experience this problem after giving birth/during seclusion: go to
# Nama Variabel: s714ix, Label: should do if experience this problem after giving birth/during seclusion: other
# Nama Variabel: s714iz, Label: should do if experience this problem after giving birth/during seclusion: don't
# Nama Variabel: s1110bb, Label: type of service used for the health insurance card: delivery care
# Nama Variabel: s1412, Label: time should be waited for the next birth
# Nama Variabel: s1504b, Label: methods of birth control - school
# Nama Variabel: s1505b, Label: methods of birth control - level
# Nama Variabel: s1731c, Label: person helped to stop pregnancy:traditional birth attendant
# Nama Variabel: idx92, Label: index to birth history
# Nama Variabel: idx94, Label: index to birth history
# Nama Variabel: s407ab, Label: birth registered and documented
# Nama Variabel: s407c, Label: baby's age when registering the birth
# Nama Variabel: s412bc, Label: number of antenatal visits - between 7th month and delivery
# Nama Variabel: s413fc, Label: during pregnancy discuss: person to assist delivery
# Nama Variabel: s413fd, Label: during pregnancy discuss: payment for the delivery
# Nama Variabel: s428aa, Label: time of birth: prolonged labor
# Nama Variabel: s428ab, Label: time of birth: excessive vaginal bleeding
# Nama Variabel: s428ac, Label: time of birth: fever and foul smelling vaginal discharge
# Nama Variabel: s428ad, Label: time of birth: convulsions
# Nama Variabel: s428ae, Label: time of birth: water broke more than 6 hours before baby was born
# Nama Variabel: s428af, Label: time of birth: no strength to press
# Nama Variabel: s428ag, Label: time of birth: anxious
# Nama Variabel: s428ah, Label: time of birth: any other complications
# Nama Variabel: s431a, Label: accompanied by husband in delivery
# Nama Variabel: s457da, Label: in the two months after birth child's health was checked by health care provider
# Nama Variabel: s457ea, Label: received vitamin a in the first two months after delivery
# Nama Variabel: idx95, Label: index to birth history
# ---------------------------------

# %%
print("\n--- Mencari Variabel Penolong Persalinan ---")
kata_kunci_1 = 'visits'

for var, label in meta_ibu.column_names_to_labels.items():
    if kata_kunci_1 in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Penolong Persalinan ---
# Nama Variabel: v027, Label: number of visits
# Nama Variabel: m14_1, Label: number of antenatal visits during pregnancy
# Nama Variabel: m14_2, Label: number of antenatal visits during pregnancy
# Nama Variabel: m14_3, Label: number of antenatal visits during pregnancy
# Nama Variabel: m14_4, Label: number of antenatal visits during pregnancy
# Nama Variabel: m14_5, Label: number of antenatal visits during pregnancy
# Nama Variabel: m14_6, Label: number of antenatal visits during pregnancy
# Nama Variabel: v743d, Label: person who usually decides on visits to family or relatives
# Nama Variabel: v804, Label: number of visits
# Nama Variabel: s412ba_1, Label: number of antenatal visits - first 3 months
# Nama Variabel: s412ba_2, Label: number of antenatal visits - first 3 months
# Nama Variabel: s412ba_3, Label: number of antenatal visits - first 3 months
# Nama Variabel: s412ba_4, Label: number of antenatal visits - first 3 months
# Nama Variabel: s412ba_5, Label: number of antenatal visits - first 3 months
# Nama Variabel: s412ba_6, Label: number of antenatal visits - first 3 months
# Nama Variabel: s412bb_1, Label: number of antenatal visits - between 4th and 6th month
# Nama Variabel: s412bb_2, Label: number of antenatal visits - between 4th and 6th month
# Nama Variabel: s412bb_3, Label: number of antenatal visits - between 4th and 6th month
# Nama Variabel: s412bb_4, Label: number of antenatal visits - between 4th and 6th month
# Nama Variabel: s412bb_5, Label: number of antenatal visits - between 4th and 6th month
# Nama Variabel: s412bb_6, Label: number of antenatal visits - between 4th and 6th month
# Nama Variabel: s412bc_1, Label: number of antenatal visits - between 7th month and delivery
# Nama Variabel: s412bc_2, Label: number of antenatal visits - between 7th month and delivery
# Nama Variabel: s412bc_3, Label: number of antenatal visits - between 7th month and delivery
# Nama Variabel: s412bc_4, Label: number of antenatal visits - between 7th month and delivery
# Nama Variabel: s412bc_5, Label: number of antenatal visits - between 7th month and delivery
# Nama Variabel: s412bc_6, Label: number of antenatal visits - between 7th month and delivery
# ---------------------------------

# %%
print("\n--- Mencari Semua Variabel Bantuan Persalinan ---")
kata_kunci = 'assistance'

for var, label in meta_ibu.column_names_to_labels.items():
    # hanya cari di variabel yang berawalan 'm3' untuk menjaga relevansi
    if var.startswith('m3') and kata_kunci in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Semua Variabel Bantuan Persalinan ---
# Nama Variabel: m3a_1, Label: assistance: general practitioner
# Nama Variabel: m3a_2, Label: assistance: general practitioner
# Nama Variabel: m3a_3, Label: assistance: general practitioner
# Nama Variabel: m3a_4, Label: assistance: general practitioner
# Nama Variabel: m3a_5, Label: assistance: general practitioner
# Nama Variabel: m3a_6, Label: assistance: general practitioner
# Nama Variabel: m3b_1, Label: assistance: obstetrician
# Nama Variabel: m3b_2, Label: assistance: obstetrician
# Nama Variabel: m3b_3, Label: assistance: obstetrician
# Nama Variabel: m3b_4, Label: assistance: obstetrician
# Nama Variabel: m3b_5, Label: assistance: obstetrician
# Nama Variabel: m3b_6, Label: assistance: obstetrician
# Nama Variabel: m3c_1, Label: assistance:  nurse
# Nama Variabel: m3c_2, Label: assistance:  nurse
# Nama Variabel: m3c_3, Label: assistance:  nurse
# Nama Variabel: m3c_4, Label: assistance:  nurse
# Nama Variabel: m3c_5, Label: assistance:  nurse
# Nama Variabel: m3c_6, Label: assistance:  nurse
# Nama Variabel: m3d_1, Label: assistance: midwife
# Nama Variabel: m3d_2, Label: assistance: midwife
# Nama Variabel: m3d_3, Label: assistance: midwife
# Nama Variabel: m3d_4, Label: assistance: midwife
# Nama Variabel: m3d_5, Label: assistance: midwife
# Nama Variabel: m3d_6, Label: assistance: midwife
# Nama Variabel: m3e_1, Label: assistance: village midwife
# Nama Variabel: m3e_2, Label: assistance: village midwife
# Nama Variabel: m3e_3, Label: assistance: village midwife
# Nama Variabel: m3e_4, Label: assistance: village midwife
# Nama Variabel: m3e_5, Label: assistance: village midwife
# Nama Variabel: m3e_6, Label: assistance: village midwife
# Nama Variabel: m3f_1, Label: na - assistance: health professional
# Nama Variabel: m3f_2, Label: na - assistance: health professional
# Nama Variabel: m3f_3, Label: na - assistance: health professional
# Nama Variabel: m3f_4, Label: na - assistance: health professional
# Nama Variabel: m3f_5, Label: na - assistance: health professional
# Nama Variabel: m3f_6, Label: na - assistance: health professional
# Nama Variabel: m3g_1, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_2, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_3, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_4, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_5, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_6, Label: assistance: traditional birth attendant
# Nama Variabel: m3h_1, Label: assistance: relative/friend
# Nama Variabel: m3h_2, Label: assistance: relative/friend
# Nama Variabel: m3h_3, Label: assistance: relative/friend
# Nama Variabel: m3h_4, Label: assistance: relative/friend
# Nama Variabel: m3h_5, Label: assistance: relative/friend
# Nama Variabel: m3h_6, Label: assistance: relative/friend
# Nama Variabel: m3i_1, Label: na - assistance: other person
# Nama Variabel: m3i_2, Label: na - assistance: other person
# Nama Variabel: m3i_3, Label: na - assistance: other person
# Nama Variabel: m3i_4, Label: na - assistance: other person
# Nama Variabel: m3i_5, Label: na - assistance: other person
# Nama Variabel: m3i_6, Label: na - assistance: other person
# Nama Variabel: m3j_1, Label: na - assistance: cs other person
# Nama Variabel: m3j_2, Label: na - assistance: cs other person
# Nama Variabel: m3j_3, Label: na - assistance: cs other person
# Nama Variabel: m3j_4, Label: na - assistance: cs other person
# Nama Variabel: m3j_5, Label: na - assistance: cs other person
# Nama Variabel: m3j_6, Label: na - assistance: cs other person
# Nama Variabel: m3k_1, Label: assistance: other
# Nama Variabel: m3k_2, Label: assistance: other
# Nama Variabel: m3k_3, Label: assistance: other
# Nama Variabel: m3k_4, Label: assistance: other
# Nama Variabel: m3k_5, Label: assistance: other
# Nama Variabel: m3k_6, Label: assistance: other
# Nama Variabel: m3l_1, Label: na - assistance:  other
# Nama Variabel: m3l_2, Label: na - assistance:  other
# Nama Variabel: m3l_3, Label: na - assistance:  other
# Nama Variabel: m3l_4, Label: na - assistance:  other
# Nama Variabel: m3l_5, Label: na - assistance:  other
# Nama Variabel: m3l_6, Label: na - assistance:  other
# Nama Variabel: m3m_1, Label: na - assistance:  other
# Nama Variabel: m3m_2, Label: na - assistance:  other
# Nama Variabel: m3m_3, Label: na - assistance:  other
# Nama Variabel: m3m_4, Label: na - assistance:  other
# Nama Variabel: m3m_5, Label: na - assistance:  other
# Nama Variabel: m3m_6, Label: na - assistance:  other
# Nama Variabel: m3n_1, Label: assistance: no one
# Nama Variabel: m3n_2, Label: assistance: no one
# Nama Variabel: m3n_3, Label: assistance: no one
# Nama Variabel: m3n_4, Label: assistance: no one
# Nama Variabel: m3n_5, Label: assistance: no one
# Nama Variabel: m3n_6, Label: assistance: no one
# ---------------------------------

# %%
print("\n--- Mencari Variabel Pemeriksaan Nifas Ibu ---")
kata_kunci_1 = 'postnatal'

for var, label in meta_ibu.column_names_to_labels.items():
    if kata_kunci_1 in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Pemeriksaan Nifas Ibu ---
# Nama Variabel: m70_1, Label: baby postnatal check within 2 months
# Nama Variabel: m70_2, Label: baby postnatal check within 2 months
# Nama Variabel: m70_3, Label: baby postnatal check within 2 months
# Nama Variabel: m70_4, Label: baby postnatal check within 2 months
# Nama Variabel: m70_5, Label: baby postnatal check within 2 months
# Nama Variabel: m70_6, Label: baby postnatal check within 2 months
# Nama Variabel: m71_1, Label: time after delivery postnatal check took place
# Nama Variabel: m71_2, Label: time after delivery postnatal check took place
# Nama Variabel: m71_3, Label: time after delivery postnatal check took place
# Nama Variabel: m71_4, Label: time after delivery postnatal check took place
# Nama Variabel: m71_5, Label: time after delivery postnatal check took place
# Nama Variabel: m71_6, Label: time after delivery postnatal check took place
# Nama Variabel: m72_1, Label: person who performed postnatal checkup
# Nama Variabel: m72_2, Label: person who performed postnatal checkup
# Nama Variabel: m72_3, Label: person who performed postnatal checkup
# Nama Variabel: m72_4, Label: person who performed postnatal checkup
# Nama Variabel: m72_5, Label: person who performed postnatal checkup
# Nama Variabel: m72_6, Label: person who performed postnatal checkup
# Nama Variabel: v417, Label: entries in pregnancy and postnatal care roster
# ---------------------------------

# %%
print("\n--- Mencari Variabel Pemeriksaan Ibu (checkup) ---")
kata_kunci = 'checkup'

for var, label in meta_ibu.column_names_to_labels.items():
    # Kita cari di variabel 'm' (maternity)
    if var.startswith('m') and kata_kunci in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Pemeriksaan Ibu (checkup) ---
# Nama Variabel: m72_1, Label: person who performed postnatal checkup
# Nama Variabel: m72_2, Label: person who performed postnatal checkup
# Nama Variabel: m72_3, Label: person who performed postnatal checkup
# Nama Variabel: m72_4, Label: person who performed postnatal checkup
# Nama Variabel: m72_5, Label: person who performed postnatal checkup
# Nama Variabel: m72_6, Label: person who performed postnatal checkup
# ---------------------------------

# %%
print("\n--- Mencari Variabel Kunci di Data Rumah Tangga ---")

# Cari ID Klaster dan Nomor Rumah Tangga
print("\n--> Mencari ID Klaster & RT:")
for var, label in meta_rt.column_names_to_labels.items():
    if 'cluster' in label.lower() or 'household number' in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

# Cari variabel Asuransi
print("\n--- Mencari Variabel Asuransi (Pencarian Lanjutan) ---")

kata_kunci_list = [ 'jaminan', 'bpjs', 'insurance', 'asuransi'] # Kita coba beberapa kata kunci

for var, label in meta_ibu.column_names_to_labels.items():
    for kata_kunci in kata_kunci_list:
        if kata_kunci in label.lower():
            print(f"Nama Variabel: {var}, Label: {label}")
            break # Hentikan jika sudah ketemu agar tidak duplikat

print("---------------------------------")
# Out:
# --- Mencari Variabel Kunci di Data Rumah Tangga ---
#
# --> Mencari ID Klaster & RT:
# Nama Variabel: hv001, Label: cluster number
# Nama Variabel: hv002, Label: household number
# Nama Variabel: hv040, Label: na - cluster altitude in meters
#
# --- Mencari Variabel Asuransi (Pencarian Lanjutan) ---
# Nama Variabel: v481, Label: covered by health insurance
# Nama Variabel: v481a, Label: health insurance type: mutual/community organization
# Nama Variabel: v481b, Label: health insurance type: through employer
# Nama Variabel: v481c, Label: health insurance type: social security -kartu jkn/bp non pbi
# Nama Variabel: v481d, Label: health insurance type: private health insurance
# Nama Variabel: v481e, Label: health insurance type: health security-non contribution
# Nama Variabel: v481f, Label: na - health insurance type: cs
# Nama Variabel: v481g, Label: na - health insurance type: cs
# Nama Variabel: v481h, Label: na - health insurance type: cs
# Nama Variabel: v481x, Label: health insurance type: other
# Nama Variabel: s309c, Label: whether obtaining national health insurance for current method
# Nama Variabel: s1110ba, Label: type of service used for the health insurance card: antenatal care
# Nama Variabel: s1110bb, Label: type of service used for the health insurance card: delivery care
# Nama Variabel: s1110bc, Label: type of service used for the health insurance card: postpartum care
# Nama Variabel: s1110bd, Label: type of service used for the health insurance card: newborn care
# Nama Variabel: s1110be, Label: type of service used for the health insurance card family planning
# Nama Variabel: s1110bf, Label: type of service used for the health insurance card: inpatient care
# Nama Variabel: s1110bg, Label: type of service used for the health insurance card: outpatient care/check up
# Nama Variabel: s1110bh, Label: type of service used for the health insurance card: never used
# ---------------------------------

# %% [markdown]
# ### 3. Extracting

# %% [markdown]
# #### 3.1 Define Required Variables

# %%
print("Defining Required Variables")
print("="*70)

# Mother-level variables
ibu_vars_needed = [
    'caseid',           # Unique case identifier
    'v001',             # Cluster number
    'v002',             # Household number
    'v024',             # Region/Province
    'v025',             # Type of residence (1=Urban, 2=Rural)
    'v106',             # Highest education level
    'v201',             # Total children ever born (v201)
    'v212',             # Age of respondent
    'm14_1',            # Number of ANC visits for last birth
    'm15_1',            # Place of delivery (codes 20+ = health facility)
    'v481',             # Health insurance coverage (1=Yes)
    'v208',             # Births in last five years
    'v005' ,            # Weighted

] + [f'm3{c}_1' for c in 'abcdef']

# Child-level variables
anak_vars_needed = [
    'caseid',           # Links to mother
    'v024',             # Region/Province
    'm18',              # Size of child at birth (1-3=Normal/Large, 4-5=Small)
    'h2',               # BCG vaccination (1=Yes)
    'h4',               # DPT1 vaccination (1=Yes)
    'h6',               # Polio1 vaccination (1=Yes)
    'h8',               # Measles vaccination (1=Yes)
    'h0',                # Child's age in months
    'm70',              # Baby postnatal check within 2 months
    'm71',               # Time after delivery postnatal check took place
    'v005' ,            # Weighted
]

# Birth history variables
lahir_vars_needed = [
    'caseid',           # Links to mother
    'v024',             # Region/Province
    'b11'            # Preceding birth interval
]

print(f"Mother variables needed: {len(ibu_vars_needed)}")
print(f"Child variables needed: {len(anak_vars_needed)}")
print(f"Birth history variables needed: {len(lahir_vars_needed)}")
# Out:
# Defining Required Variables
# ======================================================================
# Mother variables needed: 19
# Child variables needed: 11
# Birth history variables needed: 3

# %% [markdown]
# #### 3.2 Check Data Availability & Quality

# %%
# ============================================================================
# VALIDATE DATASET AVAILABILITY
# ============================================================================
print("Validating Variable Availability")
print("-"*70)

def check_missing_variables(df, var_list, dataset_name):
    """Check if required variables exist in dataset"""
    missing = [v for v in var_list if v not in df.columns]
    if missing:
        print(f"\nWARNING - {dataset_name}:")
        print(f"   Missing {len(missing)} variables: {missing[:10]}")  # Show first 10
        if len(missing) > 10:
            print(f"   ... and {len(missing)-10} more")
        return False
    else:
        print(f"✓ {dataset_name}: All {len(var_list)} variables found")
        return True

# Validate each dataset
ibu_valid = check_missing_variables(df_ibu, ibu_vars_needed, "Mother Dataset")
anak_valid = check_missing_variables(df_anak, anak_vars_needed, "Child Dataset")
lahir_valid = check_missing_variables(df_lahir, lahir_vars_needed, "Birth Dataset")

if not all([ibu_valid, anak_valid, lahir_valid]):
    print("\nSome variables are missing. Please check your dataset!")
# Out:
# Validating Variable Availability
# ----------------------------------------------------------------------
# ✓ Mother Dataset: All 19 variables found
# ✓ Child Dataset: All 11 variables found
# ✓ Birth Dataset: All 3 variables found

# %%
# ============================================================================
# SELECT AND COPY VARIABLES
# ============================================================================
print("Selecting Required Variables")
print("="*70)

df_ibu_clean = df_ibu[ibu_vars_needed].copy()
df_anak_clean = df_anak[anak_vars_needed].copy()
df_lahir_clean = df_lahir[lahir_vars_needed].copy()

print(f"✓ Mother data: {df_ibu_clean.shape[0]:,} rows, {df_ibu_clean.shape[1]} columns")
print(f"✓ Child data: {df_anak_clean.shape[0]:,} rows, {df_anak_clean.shape[1]} columns")
print(f"✓ Birth data: {df_lahir_clean.shape[0]:,} rows, {df_lahir_clean.shape[1]} columns")
# Out:
# Selecting Required Variables
# ======================================================================
# ✓ Mother data: 49,627 rows, 19 columns
# ✓ Child data: 17,848 rows, 11 columns
# ✓ Birth data: 86,265 rows, 3 columns

# %%
# ============================================================================
# DATA CLEANING
# ============================================================================
print("Data Quality Checks & Cleaning")
print("="*70)

def handle_dhs_special_codes(df, var, missing_codes=[98, 99], method='nan'):
    """
    Handle DHS special codes (Don't Know, Missing, Not Applicable)

    Parameters:
    - df: DataFrame
    - var: Variable name
    - missing_codes: List of codes to treat as missing
    - method: 'nan' or 'zero'
    """
    if var in df.columns:
        original_missing = df[var].isna().sum()
        df[var] = df[var].replace(missing_codes, np.nan)
        new_missing = df[var].isna().sum()
        if new_missing > original_missing:
            print(f"  • {var}: Cleaned {new_missing - original_missing:,} special codes → NaN")
    return df

# Clean Mother data
print("\nCleaning Mother Dataset:")
# Corrected calls for handle_dhs_special_codes
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'm14_1', missing_codes=[97, 98, 99])  # ANC visits
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'm15_1', missing_codes=[97, 98, 99])  # Delivery Places
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'v212', missing_codes=[98, 99])  # Age
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'v106', missing_codes=[8, 9]) # Education
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'v481', missing_codes=[8, 9]) # Insurance
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'b11_01', missing_codes=[98, 99]) # Birth weight


# Clean Child data
print("\nCleaning Child Dataset:")
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'm18', missing_codes=[8, 9, 98, 99])  # Birth size
# Assuming immunization variables h2, h4, h6, h8 also need cleaning for 8, 9
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h2', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h4', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h6', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h8', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'm70', [8,9]) # Postnatal Check
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'm71', [998, 999]) # Time after delivery

# Clean Birth data
print("\nCleaning Birth Dataset:")
df_lahir_clean = handle_dhs_special_codes(df_lahir_clean, 'b11', missing_codes=[98, 99])  # Birth interval
# Out:
# Data Quality Checks & Cleaning
# ======================================================================
#
# Cleaning Mother Dataset:
#   • m14_1: Cleaned 79 special codes → NaN
#
# Cleaning Child Dataset:
#   • m18: Cleaned 298 special codes → NaN
#   • h2: Cleaned 31 special codes → NaN
#   • h4: Cleaned 28 special codes → NaN
#   • h6: Cleaned 28 special codes → NaN
#   • h8: Cleaned 28 special codes → NaN
#   • m70: Cleaned 80 special codes → NaN
#   • m71: Cleaned 123 special codes → NaN
#
# Cleaning Birth Dataset:
#   • b11: Cleaned 373 special codes → NaN

# %%
# ============================================================================
# FILTER TO APPROPRIATE SAMPLE
# ============================================================================
print("="*70)
print("Sample Selection")
print("="*70)

print(f"Original sample: {len(df_ibu_clean):,} mothers")

# m14_1 is only asked for most recent birth in last 5 years
df_ibu_analysis = df_ibu_clean[df_ibu_clean['v208'] > 0].copy()
print(f"Analysis sample: {len(df_ibu_analysis):,} mothers with recent births")
print(f"Filtered out: {len(df_ibu_clean) - len(df_ibu_analysis):,} mothers without recent births")

df_anak_analysis = df_anak_clean[df_anak_clean['h0']<=23].copy()
print(f"Analysis child sample: {len(df_anak_analysis):,} children aged 0–23 months")
print(f"Filtered out: {len(df_anak_clean) - len(df_anak_analysis):,} children age > 23 months")
# Out:
# ======================================================================
# Sample Selection
# ======================================================================
# Original sample: 49,627 mothers
# Analysis sample: 15,357 mothers with recent births
# Filtered out: 34,270 mothers without recent births
# Analysis child sample: 10,325 children aged 0–23 months
# Filtered out: 7,523 children age > 23 months

# %%
# Show missing data summary
print("\nMissing Data Summary:")
print("-" * 50)
key_vars = ['m14_1', 'm15_1', 'v212', 'v481', 'm18', 'v220']
for var in key_vars:
    for df, name in [(df_ibu_analysis, 'ibu'), (df_anak_clean, 'anak'), (df_lahir_clean, 'lahir')]:
        if var in df.columns:
            missing_pct = (df[var].isna().sum() / len(df)) * 100
            print(f"  {name}.{var}: {missing_pct:.1f}% missing")
# Out:
# Missing Data Summary:
# --------------------------------------------------
#   ibu.m14_1: 0.6% missing
#   ibu.m15_1: 0.2% missing
#   ibu.v212: 0.0% missing
#   ibu.v481: 0.0% missing
#   anak.m18: 2.3% missing

# %% [markdown]
# #### 3.3 Feature Engineering

# %%
# ============================================================================
# FEATURE ENGINEERING
# ============================================================================
print("Feature Engineering")
print("-"*70)

# -----------------------------------------------------------------------------
# A. MATERNAL HEALTH SERVICE INDICATORS
# -----------------------------------------------------------------------------
print("\nA. Creating Maternal Health Service Indicators:")

# Ensure `df_ibu_analysis` is used as the base for feature engineering
df_ibu_analysis = df_ibu_analysis[df_ibu_analysis['m14_1'].notna()].copy()

# 1. ANC 4+ visits (m14_1 >= 4)
df_ibu_analysis['anc4_pct'] = (df_ibu_analysis['m14_1'] >= 4).astype(int)
print(f"4+ ANC visits: {df_ibu_analysis['anc4_pct'].mean()*100:.1f}%")

# 2. Facility delivery (m15_1: 20-36 = health facilities)
df_ibu_analysis['facility_delivery_pct'] = (
    (df_ibu_analysis['m15_1'] >= 20) & (df_ibu_analysis['m15_1'] <= 36)
).astype(int)
print(f"Facility delivery: {df_ibu_analysis['facility_delivery_pct'].mean()*100:.1f}%")

# 3. Skilled Birth Attendant
# m3a_1 = doctor, m3b_1 = nurse/midwife, m3c_1 = auxiliary midwife
sba_cols = [col for col in df_ibu_analysis.columns if col.startswith('m3') and col.endswith('_1')]
excluded_tba = ['m3f_1'] # Not Skilled
sba_cols_filtered = [c for c in sba_cols if c not in excluded_tba]

df_ibu_analysis['sba_pct'] = df_ibu_analysis[sba_cols_filtered].eq(1).any(axis=1).astype(int)
print(f"Skilled Birth Attendant: {df_ibu_analysis['sba_pct'].mean()*100:.1f}%")

# 4. Any PNC (m70 = 1 → dapat pemeriksaan nifas bayi dalam 2 bulan)
df_pnc = df_anak_analysis[df_anak_analysis['m70'].notna()].copy()
df_pnc['pnc_any_flag'] = (df_pnc['m70'] == 1).astype(int)
print(f"Any PNC (age<=23mo): {df_pnc['pnc_any_flag'].mean()*100:.1f}%")

# 5. PNC within 2 days (m71: hours/days after delivery)
m71 = df_pnc['m71']

mask_hours = m71.between(100, 171)          # 100–171: jam
mask_hours_dk = m71.isin([198, 199])        # DK in hours → tetap dianggap <= 48h
mask_days = m71.between(200, 202)           # 200–202: 0–2 hari

df_pnc['pnc48h_flag'] = (mask_hours | mask_hours_dk | mask_days).astype(int)
print(f"PNC within 2 days (age<=23mo): {df_pnc['pnc48h_flag'].mean()*100:.1f}%")

# 6. Parity
df_ibu_analysis.rename(columns={'v201': 'parity'}, inplace=True)

# -----------------------------------------------------------------------------
# B. SOCIO-DEMOGRAPHIC INDICATORS
# -----------------------------------------------------------------------------
print("\nB. Creating Socio-Demographic Indicators:")

df_ibu_analysis['insured_pct'] = (df_ibu_analysis['v481'] == 1).astype(int)
print(f"Health insurance: {df_ibu_analysis['insured_pct'].mean()*100:.1f}%")

df_ibu_analysis['urban_share_pct'] = (df_ibu_analysis['v025'] == 1).astype(int)
print(f"Urban residence: {df_ibu_analysis['urban_share_pct'].mean()*100:.1f}%")

df_ibu_analysis['low_education_pct'] = (df_ibu_analysis['v106'] <= 1).astype(int)
print(f"Low education (\u2264Primary): {df_ibu_analysis['low_education_pct'].mean()*100:.1f}%")

# -----------------------------------------------------------------------------
# C. RISK FACTORS
# -----------------------------------------------------------------------------
print("\nC. Creating Risk Factor Indicators:")

df_ibu_analysis['maternal_age_risky_pct'] = (
    (df_ibu_analysis['v212'] < 20) | (df_ibu_analysis['v212'] >= 35)
).astype(int)
print(f"Risky maternal age: {df_ibu_analysis['maternal_age_risky_pct'].mean()*100:.1f}%")

# Birth interval (from birth recode)
df_lahir_clean['short_interval_flag'] = (
    df_lahir_clean['b11'] < 24  # Less than 24 months
).astype(int)
print(f"Short birth interval (<24mo): {df_lahir_clean['short_interval_flag'].mean()*100:.1f}%")

# Child variables
df_anak_analysis['small_birth_size_pct'] = (
    df_anak_analysis['m18'].isin([4, 5])  # 4=small, 5=very small
).astype(int)
print(f"Small birth size: {df_anak_analysis['small_birth_size_pct'].mean()*100:.1f}%")

# Full immunization (h2=BCG, h3=DPT1, h5=Polio1, h9=Measles)
# Code 1 = Yes (from card or recall), 0 = No
immun_vars = ['h2', 'h4', 'h6', 'h8']
for var in immun_vars:
    if var in df_anak_analysis.columns:
        coverage = (df_anak_analysis[var] == 1).mean() * 100
        print(f"    \u2022 {var}: {coverage:.1f}%")

for var in immun_vars:
    if var in df_anak_analysis.columns:
        df_anak_analysis[f'{var}_binary'] = (df_anak_analysis[var] == 1).astype(int)

binary_vars = [f'{v}_binary' for v in immun_vars if f'{v}_binary' in df_anak_analysis.columns]
df_anak_analysis['full_immun_pct'] = df_anak_analysis[binary_vars].all(axis=1).astype(int)
print(f"\nFull immunization (all 4 vaccines): {df_anak_analysis['full_immun_pct'].mean()*100:.1f}%")
# Out:
# Feature Engineering
# ----------------------------------------------------------------------
#
# A. Creating Maternal Health Service Indicators:
# 4+ ANC visits: 88.6%
# Facility delivery: 75.1%
# Skilled Birth Attendant: 90.2%
# Any PNC (age<=23mo): 66.8%
# PNC within 2 days (age<=23mo): 20.7%
#
# B. Creating Socio-Demographic Indicators:
# Health insurance: 62.0%
# Urban residence: 49.4%
# Low education (≤Primary): 26.3%
#
# C. Creating Risk Factor Indicators:
# Risky maternal age: 30.2%
# Short birth interval (<24mo): 10.8%
# Small birth size: 12.8%
#     • h2: 46.7%
#     • h4: 42.4%
#     • h6: 39.1%
#     • h8: 34.3%
#
# Full immunization (all 4 vaccines): 33.4%

# %% [markdown]
# #### 3.4 Merging

# %%
# Mother-level indicators

df_ibu_2017 = df_ibu_analysis.copy()

# ANC 4+
df_ibu_2017['anc4_flag'] = (df_ibu_2017['m14_1'] >= 4).astype(int)

# Facility delivery (20–89 = health facility)
df_ibu_2017['facility_flag'] = df_ibu_2017['m15_1'].between(20, 89).astype(int)

# SBA (pakai loop semua m3*_1 kecuali TBA, misal m3f_1)
sba_cols = [c for c in df_ibu_2017.columns if c.startswith('m3') and c.endswith('_1')]
excluded_tba = ['m3f_1']  # sesuaikan kalau TBA di kode lain
sba_cols = [c for c in sba_cols if c not in excluded_tba]
df_ibu_2017['sba_flag'] = df_ibu_2017[sba_cols].eq(1).any(axis=1).astype(int)

# Insurance
df_ibu_2017['insured_flag'] = (df_ibu_2017['v481'] == 1).astype(int)

# Urban
df_ibu_2017['urban_flag'] = (df_ibu_2017['v025'] == 1).astype(int)

# Low education (≤ primary)
df_ibu_2017['lowedu_flag'] = df_ibu_2017['v106'].isin([0, 1]).astype(int)  # 0 = no edu, 1 = primary

# Risky maternal age (<20 or >=35)
df_ibu_2017['risky_age_flag'] = ((df_ibu_2017['v212'] < 20) | (df_ibu_2017['v212'] >= 35)).astype(int)

# Parity (bisa dipakai langsung mean)
df_ibu_2017['parity'] = df_ibu_2017['parity']

# Weighting
df_ibu_2017['weight'] = df_ibu_2017['v005'] / 1_000_000

# %%
# Merge Birth interval with df_ibu

df_birth = df_lahir_clean.copy()

# Flag short birth interval <24 bulan
df_birth['short_interval_flag'] = (df_birth['b11'] < 24).astype(int)

# Aggregate ke level ibu: kalau ada kelahiran dengan interval pendek → ibu dianggap punya risiko
df_interval_mother = (
    df_birth
    .groupby('caseid')['short_interval_flag']
    .max()
    .reset_index()
)

# Merge ke df_ibu (1-1, aman)
df_ibu_2017 = df_ibu_2017.merge(df_interval_mother, on='caseid', how='left')
df_ibu_2017['short_interval_flag'] = df_ibu_2017['short_interval_flag'].fillna(0).astype(int)

# %%
# Child-level indicators

df_child_2017 = df_anak_analysis.copy()

# LBW proxy: small_birth_size (m18: 4/5 = small/very small, 1–3 = average/large)
df_child_2017['small_birth_flag'] = df_child_2017['m18'].isin([4, 5]).astype(int)

# Immunization flags (anggap 1 = received, 2/3 juga treated as received kalau ada)
for col in ['h2', 'h4', 'h6', 'h8']:
    df_child_2017[col + '_flag'] = df_child_2017[col].isin([1, 2, 3]).astype(int)

# Full immunization (semua 4 vaksin diterima)
imm_cols = ['h2_flag', 'h4_flag', 'h6_flag', 'h8_flag']
df_child_2017['full_immun_flag'] = df_child_2017[imm_cols].all(axis=1).astype(int)

# Weighting
df_child_2017['weight'] = df_child_2017['v005'] / 1_000_000

# %%
# PNC indicators

df_pnc = df_child_2017[df_child_2017['m70'].notna()].copy()

# Any PNC
df_pnc['pnc_any_flag'] = (df_pnc['m70'] == 1).astype(int)

# PNC ≤48h (pakai coding numeric)
m71 = df_pnc['m71']
mask_hours = m71.between(100, 171)
mask_hours_dk = m71.isin([198, 199])
mask_days = m71.between(200, 202)
df_pnc['pnc48h_flag'] = (mask_hours | mask_hours_dk | mask_days).astype(int)

# %%
group_cols = ['v024']  # v024 = province

# Aggregate Mother
prov_mother = (
    df_ibu_2017
    .groupby(group_cols)
    .agg(
        anc4_pct=('anc4_flag', 'mean'),
        facility_delivery_pct=('facility_flag', 'mean'),
        sba_pct=('sba_flag', 'mean'),
        insured_pct=('insured_flag', 'mean'),
        urban_share_pct=('urban_flag', 'mean'),
        low_education_pct=('lowedu_flag', 'mean'),
        risky_maternal_age_pct=('risky_age_flag', 'mean'),
        birth_interval_short_pct=('short_interval_flag', 'mean'),
        avg_parity=('parity', 'mean')
    )
    .reset_index()
)

# Aggregate Child
prov_child = (
    df_child_2017
    .groupby(group_cols)
    .agg(
        lbw_pct=('small_birth_flag', 'mean'),
        full_immun_pct=('full_immun_flag', 'mean')
    )
    .reset_index()
)

# Aggregate PNC
prov_pnc = (
    df_pnc
    .groupby(group_cols)
    .agg(
        pnc_any_pct=('pnc_any_flag', 'mean'),
        pnc48h_pct=('pnc48h_flag', 'mean')
    )
    .reset_index()
)

# %%
df_2017 = prov_mother.merge(prov_child, on=['v024'], how='left')
df_2017 = df_2017.merge(prov_pnc, on=['v024'], how='left')

df_2017.rename(columns={'v024': 'region'}, inplace=True)

# %%
prov_map = {
    11: "Aceh",
    12: "Sumatera Utara",
    13: "Sumatera Barat",
    14: "Riau",
    15: "Jambi",
    16: "Sumatera Selatan",
    17: "Bengkulu",
    18: "Lampung",
    19: "Kepulauan Bangka Belitung",
    21: "Kepulauan Riau",
    31: "DKI Jakarta",
    32: "Jawa Barat",
    33: "Jawa Tengah",
    34: "DI Yogyakarta",
    35: "Jawa Timur",
    36: "Banten",
    51: "Bali",
    52: "Nusa Tenggara Barat",
    53: "Nusa Tenggara Timur",
    61: "Kalimantan Barat",
    62: "Kalimantan Tengah",
    63: "Kalimantan Selatan",
    64: "Kalimantan Timur",
    65: "Kalimantan Utara",
    71: "Sulawesi Utara",
    72: "Sulawesi Tengah",
    73: "Sulawesi Selatan",
    74: "Sulawesi Tenggara",
    75: "Gorontalo",
    76: "Sulawesi Barat",
    81: "Maluku",
    82: "Maluku Utara",
    91: "Papua",
    92: "Papua Barat",
    94: "Papua Barat"
}

df_2017['province'] = df_2017['region'].map(prov_map)

# cek apakah ada kode yang belum ter-map
unmapped = df_2017[df_2017['province'].isna()]['region'].unique()
print("Unmapped province codes:", unmapped)
# Out:
# Unmapped province codes: []

# %%
cols = df_2017.columns.tolist()

new_order = ['region', 'province'] + [c for c in cols if c not in ['region', 'province']]

# Reorder dataframe
df_2012 = df_2017[new_order]

# %%
# ============================================================================
# FINAL DATA QUALITY SUMMARY
# ============================================================================
print("="*80)
print("FINAL DATA QUALITY SUMMARY – PROVINCIAL INDICATORS")
print("="*80)

# 1. Basic dataset info
print(f"\nTotal observations        : {len(df_2017):,}")
print(f"Unique provinces          : {df_2017['region'].nunique()}")
print(f"Total indicators          : {df_2017.shape[1] - 2} (excluding region/year)")

# 2. Missing check
missing = df_2017.isna().sum()
if missing.sum() == 0:
    print("\nMissing values            : 0")
else:
    print("\nMissing values:")
    print(missing[missing > 0])

# 3. Indicator ranges (auto-detect pct columns)
print("\nIndicator Ranges by Province:")
print("-" * 80)

indicator_cols = [
    col for col in df_2017.columns
    if col not in ['region', 'province'] # Exclude 'province' column from numerical checks
]

for col in indicator_cols:
    col_min = df_2017[col].min()
    col_max = df_2017[col].max()

    # convert to percentage if value seems 0-1
    if col_max <= 1.5:
        print(f"{col:30s}: {col_min*100:6.1f}% – {col_max*100:6.1f}%")
    else:
        print(f"{col:30s}: {col_min:6.2f} – {col_max:6.2f}")

# 4. Quick descriptive stats
print("\nQuick Descriptive Stats:")
print("-" * 80)
print(df_2017[indicator_cols].describe().T[['mean','std','min','max']])

print("\nData preview:")
print(df_2017.head())

print("\nPROCESSING COMPLETE ✔")
print("="*80)
# Out:
# ================================================================================
# FINAL DATA QUALITY SUMMARY – PROVINCIAL INDICATORS
# ================================================================================
#
# Total observations        : 34
# Unique provinces          : 34
# Total indicators          : 13 (excluding region/year)
#
# Missing values            : 0
#
# Indicator Ranges by Province:
# --------------------------------------------------------------------------------
# anc4_pct                      :   70.3% –   98.1%
# facility_delivery_pct         :   34.1% –   99.4%
# sba_pct                       :   72.0% –   99.3%
# insured_pct                   :   40.5% –   89.7%
# urban_share_pct               :   18.9% –  100.0%
# low_education_pct             :    5.0% –   43.8%
# risky_maternal_age_pct        :   14.3% –   46.0%
# birth_interval_short_pct      :    5.0% –   39.8%
# avg_parity                    :   1.89 –   3.28
# lbw_pct                       :    6.5% –   26.9%
# full_immun_pct                :   26.7% –   77.4%
# pnc_any_pct                   :   37.7% –   94.1%
# pnc48h_pct                    :    4.0% –   52.6%
#
# Quick Descriptive Stats:
# --------------------------------------------------------------------------------
#                               mean       std       min       max
# anc4_pct                  0.880152  0.069390  0.703390  0.981366
# facility_delivery_pct     0.735340  0.174975  0.341463  0.993789
# sba_pct                   0.903293  0.075368  0.720339  0.993289
# insured_pct               0.629218  0.113519  0.404834  0.896815
# urban_share_pct           0.484495  0.196687  0.188995  1.000000
# low_education_pct         0.252288  0.084276  0.049689  0.437799
# risky_maternal_age_pct    0.314423  0.077012  0.142857  0.459596
# birth_interval_short_pct  0.171070  0.088017  0.049689  0.398305
# avg_parity                2.389240  0.317838  1.894410  3.283898
# lbw_pct                   0.130961  0.043510  0.064516  0.269231
# full_immun_pct            0.602493  0.115130  0.266667  0.774194
# pnc_any_pct               0.684771  0.145580  0.376923  0.940789
# pnc48h_pct                0.215133  0.129486  0.040000  0.525680
#
# Data preview:
#    region  anc4_pct  facility_delivery_pct   sba_pct  insured_pct  \
# 0      11  0.822930               0.794904  0.954140     0.896815
# 1      12  0.783007               0.665359  0.913725     0.529412
# 2      13  0.927445               0.946372  0.981073     0.687697
# 3      14  0.802817               0.549296  0.923944     0.470423
# 4      15  0.889401               0.626728  0.894009     0.488479
#
#    urban_share_pct  low_education_pct  risky_maternal_age_pct  \
# 0         0.300637           0.226752                0.244586
# 1         0.505882           0.220915                0.197386
# 2         0.460568           0.123028                0.211356
# 3         0.383099           0.270423                0.259155
# 4         0.447005           0.207373                0.327189
#
#    birth_interval_short_pct  avg_parity   lbw_pct  full_immun_pct  \
# 0                  0.170701    2.568153  0.118280        0.324373
# 1                  0.298039    2.673203  0.119508        0.537786
# 2                  0.154574    2.498423  0.090909        0.468182
# 3                  0.208451    2.419718  0.114173        0.492126
# 4                  0.050691    2.050691  0.155039        0.604651
#
#    pnc_any_pct  pnc48h_pct        province
# 0     0.403810    0.154286            Aceh
# 1     0.647173    0.323587  Sumatera Utara
# 2     0.841346    0.129808  Sumatera Barat
# 3     0.476395    0.175966            Riau
# 4     0.809524    0.468254           Jambi
#
# PROCESSING COMPLETE ✔
# ================================================================================

# %%
print("Saving Results")

df_2017.to_csv('dhs_regional_2017.csv', index=False)
print("Files saved successfully!")
# Out:
# Saving Results
# Files saved successfully!

# %% [markdown]
# ## B. Data DHS (2012)

# %% [markdown]
# ### 1. Load Data

# %%
print("Preprocessing Data SDKI 2012...")

ibu_dta_path = 'IDIR63FL.DTA' # File ibu
anak_dta_path = 'IDKR63FL.DTA' # File anak
lahir_dta_path = 'IDBR63FL.DTA' # File Kelahiran

print("\nMembaca file data Stata (.DTA)...")

try:
    df_ibu, meta_ibu = pyreadstat.read_dta(ibu_dta_path)
    df_anak, meta_anak = pyreadstat.read_dta(anak_dta_path)
    df_lahir, meta_lahir = pyreadstat.read_dta(lahir_dta_path)
    print("File Ibu, Rumah Tangga, Kelahiran, & Anak (.DTA) berhasil dibaca.")
except Exception as e:
    print(f"Error saat membaca file: {e}")
    exit()

df_ibu.columns = df_ibu.columns.str.lower()
df_anak.columns = df_anak.columns.str.lower()
df_lahir.columns = df_lahir.columns.str.lower()

print("\n--- Check Dataset ---")
print("Jumlah kolom di df_ibu:", len(df_ibu.columns))
print("Jumlah kolom di df_anak:", len(df_anak.columns))
print("Jumlah kolom di df_lahir:", len(df_lahir.columns))
print("-------------------------------------------------------")
# Out:
# Preprocessing Data SDKI 2012...
#
# Membaca file data Stata (.DTA)...
# File Ibu, Rumah Tangga, Kelahiran, & Anak (.DTA) berhasil dibaca.
#
# --- Check Dataset ---
# Jumlah kolom di df_ibu: 4167
# Jumlah kolom di df_anak: 1136
# Jumlah kolom di df_lahir: 1136
# -------------------------------------------------------

# %% [markdown]
# ### 2. Check Variable Name

# %%
print("\n--- Mencari Variabel Pendidikan ---")
kata_kunci = 'educa'

# Mencari di dalam nama kolom dan label deskripsinya
for var, label in meta_ibu.column_names_to_labels.items():
    if kata_kunci in var.lower() or kata_kunci in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Pendidikan ---
# Nama Variabel: v106, Label: highest educational level
# Nama Variabel: v107, Label: highest year of education
# Nama Variabel: v133, Label: education in single years
# Nama Variabel: v149, Label: educational attainment
# Nama Variabel: awfacte, Label: all woman factor - educational
# Nama Variabel: v701, Label: husband/partner's education level
# Nama Variabel: v702, Label: husband/partner's highest year of education (at level in v701)
# Nama Variabel: v715, Label: husband/partner's total number of years of education
# Nama Variabel: v729, Label: husband/partner's educational attainment
# Nama Variabel: s105, Label: highest educational level
# Nama Variabel: s804, Label: partner's level of education
# ---------------------------------

# %%
print("\n--- Mencari Variabel Ukuran Bayi Lahir ---")
# meta_anak berisi "kamus" untuk df_anak
kata_kunci_1 = 'size'  # Kata kunci: ukuran
kata_kunci_2 = 'weight' # Kata kunci: berat

# Mencari di dalam nama kolom dan label deskripsinya
for var, label in meta_anak.column_names_to_labels.items():
    if kata_kunci_1 in label.lower() or kata_kunci_2 in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Ukuran Bayi Lahir ---
# Nama Variabel: v005, Label: women's individual sample weight (6 decimals)
# Nama Variabel: v419, Label: entries in height/weight table
# Nama Variabel: v437, Label: na - respondent's weight in kilograms (1 decimal)
# Nama Variabel: v442, Label: na - weight/height percent ref. median (dhs)
# Nama Variabel: v443, Label: na - weight/height percent ref. median (fog)
# Nama Variabel: v444, Label: na - weight/height percent ref. median (who)
# Nama Variabel: v444a, Label: weight/height standard deviation (dhs)
# Nama Variabel: v447, Label: na - result of measurement - height/weight
# Nama Variabel: m18, Label: size of child at birth
# Nama Variabel: m19, Label: birth weight in kilograms (3 decimals)
# Nama Variabel: m19a, Label: weight at birth/recall
# Nama Variabel: hw2, Label: na - child's weight in kilograms (1 decimal)
# Nama Variabel: hw7, Label: na - weight/age percentile
# Nama Variabel: hw8, Label: weight/age standard deviation
# Nama Variabel: hw9, Label: na - weight/age percent of ref. median
# Nama Variabel: hw10, Label: na - weight/height percentile
# Nama Variabel: hw11, Label: weight/height standard deviation
# Nama Variabel: hw12, Label: na - weight/height percent of ref. median
# Nama Variabel: hw13, Label: result of measurement - height/weight
# Nama Variabel: hw71, Label: weight/age standard deviation (new who)
# Nama Variabel: hw72, Label: weight/height standard deviation (new who)
# Nama Variabel: s937ck, Label: male sti symptoms: loss of weight
# Nama Variabel: s937dk, Label: female sti symptoms: loss of weight
# ---------------------------------

# %%
print("\n--- Mencari Variabel Penolong Persalinan ---")
kata_kunci_1 = 'order'
kata_kunci_2 = 'birth'

for var, label in meta_lahir.column_names_to_labels.items():
    if kata_kunci_1 in label.lower() or kata_kunci_2 in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Penolong Persalinan ---
# Nama Variabel: bidx, Label: birth column number
# Nama Variabel: v009, Label: respondent's month of birth
# Nama Variabel: v010, Label: respondent's year of birth
# Nama Variabel: v011, Label: date of birth (cmc)
# Nama Variabel: v208, Label: births in last five years
# Nama Variabel: v209, Label: births in past year
# Nama Variabel: v210, Label: births in month of interview
# Nama Variabel: v211, Label: date of first birth (cmc)
# Nama Variabel: v212, Label: age of respondent at 1st birth
# Nama Variabel: v221, Label: marriage to first birth interval (months)
# Nama Variabel: v222, Label: last birth to interview (months)
# Nama Variabel: v224, Label: entries in birth history
# Nama Variabel: v237, Label: birth between last and interview
# Nama Variabel: v238, Label: births in last three years
# Nama Variabel: v401, Label: last birth a caesarean section
# Nama Variabel: v468, Label: record for last birth
# Nama Variabel: v603, Label: preferred waiting time for birth of a/another child
# Nama Variabel: v604, Label: preferred waiting time for birth of a/another child (grouped)
# Nama Variabel: v616, Label: time for future birth
# Nama Variabel: v633c, Label: reason for not having sex: recent birth
# Nama Variabel: bord, Label: birth order number
# Nama Variabel: b1, Label: month of birth
# Nama Variabel: b2, Label: year of birth
# Nama Variabel: b3, Label: date of birth (cmc)
# Nama Variabel: b11, Label: preceding birth interval (months)
# Nama Variabel: b12, Label: succeeding birth interval (months)
# Nama Variabel: b15, Label: live birth between births
# Nama Variabel: midx, Label: index to birth history
# Nama Variabel: m1, Label: number of tetanus injections before birth
# Nama Variabel: m2g, Label: prenatal: traditional birth attendant
# Nama Variabel: m3g, Label: assistance: traditional birth attendant
# Nama Variabel: m18, Label: size of child at birth
# Nama Variabel: m19, Label: birth weight in kilograms (3 decimals)
# Nama Variabel: m19a, Label: weight at birth/recall
# Nama Variabel: hidx, Label: index to birth history
# Nama Variabel: h12u, Label: diarrhea: traditional birth attendant
# Nama Variabel: hwidx, Label: index to birth history
# Nama Variabel: hw16, Label: na - day of birth of child
# Nama Variabel: s236c, Label: stillbirth before january 2007
# Nama Variabel: s236f, Label: number of stillbirths before january 2007
# Nama Variabel: s305d, Label: why is it that you have not taken the pill (in order)?
# Nama Variabel: s632jh, Label: problems during labor/delivery: stillbirth
# Nama Variabel: s632la, Label: problems after giving birth/during seclusion: excessive bleeding
# Nama Variabel: s632lb, Label: problems after giving birth/during seclusion: faint
# Nama Variabel: s632lc, Label: problems after giving birth/during seclusion: convulsions
# Nama Variabel: s632ld, Label: problems after giving birth/during seclusion: fever
# Nama Variabel: s632le, Label: problems after giving birth/during seclusion: foul-smelling discharge
# Nama Variabel: s632lf, Label: problems after giving birth/during seclusion: sore breast
# Nama Variabel: s632lg, Label: problems after giving birth/during seclusion: sadness/depression
# Nama Variabel: s632lx, Label: problems after giving birth/during seclusion: other
# Nama Variabel: s632lz, Label: problems after giving birth/during seclusion: don't know
# Nama Variabel: s632ma, Label: should do if experience this problem after giving birth/during seclusion: nothin
# Nama Variabel: s632mb, Label: should do if experience this problem after giving birth/during seclusion: rest
# Nama Variabel: s632mc, Label: should do if experience this problem after giving birth/during seclusion: take m
# Nama Variabel: s632md, Label: should do if experience this problem after giving birth/during seclusion: take h
# Nama Variabel: s632me, Label: should do if experience this problem after giving birth/during seclusion: see tb
# Nama Variabel: s632mf, Label: should do if experience this problem after giving birth/during seclusion: see mi
# Nama Variabel: s632mg, Label: should do if experience this problem after giving birth/during seclusion: see do
# Nama Variabel: s632mh, Label: should do if experience this problem after giving birth/during seclusion: go to
# Nama Variabel: s632mx, Label: should do if experience this problem after giving birth/during seclusion: other
# Nama Variabel: s632mz, Label: should do if experience this problem after giving birth/during seclusion: don't
# Nama Variabel: idx94, Label: index to birth history
# Nama Variabel: s407ab, Label: birth registered and documented
# Nama Variabel: s407c, Label: baby's age when registering the birth
# Nama Variabel: s432aa, Label: time of birth: prolonged labor
# Nama Variabel: s432ab, Label: time of birth: excessive vaginal bleeding
# Nama Variabel: s432ac, Label: time of birth: fever and foul smelling vaginal discharge
# Nama Variabel: s432ad, Label: time of birth: convulsions
# Nama Variabel: s432ae, Label: time of birth: water broke > 6 hours before delivery
# Nama Variabel: s432af, Label: time of birth: other
# Nama Variabel: idx95, Label: index to birth history
# ---------------------------------

# %%
print("\n--- Mencari Semua Variabel Bantuan Persalinan ---")
kata_kunci = 'assistance'

for var, label in meta_ibu.column_names_to_labels.items():
    # Kita hanya cari di variabel yang berawalan 'm3' untuk menjaga relevansi
    if var.startswith('m3') and kata_kunci in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Semua Variabel Bantuan Persalinan ---
# Nama Variabel: m3a_1, Label: assistance: doctor
# Nama Variabel: m3a_2, Label: assistance: doctor
# Nama Variabel: m3a_3, Label: assistance: doctor
# Nama Variabel: m3a_4, Label: assistance: doctor
# Nama Variabel: m3a_5, Label: assistance: doctor
# Nama Variabel: m3a_6, Label: assistance: doctor
# Nama Variabel: m3b_1, Label: assistance: obstetrician
# Nama Variabel: m3b_2, Label: assistance: obstetrician
# Nama Variabel: m3b_3, Label: assistance: obstetrician
# Nama Variabel: m3b_4, Label: assistance: obstetrician
# Nama Variabel: m3b_5, Label: assistance: obstetrician
# Nama Variabel: m3b_6, Label: assistance: obstetrician
# Nama Variabel: m3c_1, Label: assistance: nurse
# Nama Variabel: m3c_2, Label: assistance: nurse
# Nama Variabel: m3c_3, Label: assistance: nurse
# Nama Variabel: m3c_4, Label: assistance: nurse
# Nama Variabel: m3c_5, Label: assistance: nurse
# Nama Variabel: m3c_6, Label: assistance: nurse
# Nama Variabel: m3d_1, Label: assistance: midwife
# Nama Variabel: m3d_2, Label: assistance: midwife
# Nama Variabel: m3d_3, Label: assistance: midwife
# Nama Variabel: m3d_4, Label: assistance: midwife
# Nama Variabel: m3d_5, Label: assistance: midwife
# Nama Variabel: m3d_6, Label: assistance: midwife
# Nama Variabel: m3e_1, Label: assistance: village midwife
# Nama Variabel: m3e_2, Label: assistance: village midwife
# Nama Variabel: m3e_3, Label: assistance: village midwife
# Nama Variabel: m3e_4, Label: assistance: village midwife
# Nama Variabel: m3e_5, Label: assistance: village midwife
# Nama Variabel: m3e_6, Label: assistance: village midwife
# Nama Variabel: m3f_1, Label: na - assistance: cs health professional
# Nama Variabel: m3f_2, Label: na - assistance: cs health professional
# Nama Variabel: m3f_3, Label: na - assistance: cs health professional
# Nama Variabel: m3f_4, Label: na - assistance: cs health professional
# Nama Variabel: m3f_5, Label: na - assistance: cs health professional
# Nama Variabel: m3f_6, Label: na - assistance: cs health professional
# Nama Variabel: m3g_1, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_2, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_3, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_4, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_5, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_6, Label: assistance: traditional birth attendant
# Nama Variabel: m3h_1, Label: assistance: relative/friend
# Nama Variabel: m3h_2, Label: assistance: relative/friend
# Nama Variabel: m3h_3, Label: assistance: relative/friend
# Nama Variabel: m3h_4, Label: assistance: relative/friend
# Nama Variabel: m3h_5, Label: assistance: relative/friend
# Nama Variabel: m3h_6, Label: assistance: relative/friend
# Nama Variabel: m3i_1, Label: na - assistance: cs other person
# Nama Variabel: m3i_2, Label: na - assistance: cs other person
# Nama Variabel: m3i_3, Label: na - assistance: cs other person
# Nama Variabel: m3i_4, Label: na - assistance: cs other person
# Nama Variabel: m3i_5, Label: na - assistance: cs other person
# Nama Variabel: m3i_6, Label: na - assistance: cs other person
# Nama Variabel: m3j_1, Label: na - assistance: cs other person
# Nama Variabel: m3j_2, Label: na - assistance: cs other person
# Nama Variabel: m3j_3, Label: na - assistance: cs other person
# Nama Variabel: m3j_4, Label: na - assistance: cs other person
# Nama Variabel: m3j_5, Label: na - assistance: cs other person
# Nama Variabel: m3j_6, Label: na - assistance: cs other person
# Nama Variabel: m3k_1, Label: assistance: other
# Nama Variabel: m3k_2, Label: assistance: other
# Nama Variabel: m3k_3, Label: assistance: other
# Nama Variabel: m3k_4, Label: assistance: other
# Nama Variabel: m3k_5, Label: assistance: other
# Nama Variabel: m3k_6, Label: assistance: other
# Nama Variabel: m3l_1, Label: na - assistance: cs other
# Nama Variabel: m3l_2, Label: na - assistance: cs other
# Nama Variabel: m3l_3, Label: na - assistance: cs other
# Nama Variabel: m3l_4, Label: na - assistance: cs other
# Nama Variabel: m3l_5, Label: na - assistance: cs other
# Nama Variabel: m3l_6, Label: na - assistance: cs other
# Nama Variabel: m3m_1, Label: na - assistance: cs other
# Nama Variabel: m3m_2, Label: na - assistance: cs other
# Nama Variabel: m3m_3, Label: na - assistance: cs other
# Nama Variabel: m3m_4, Label: na - assistance: cs other
# Nama Variabel: m3m_5, Label: na - assistance: cs other
# Nama Variabel: m3m_6, Label: na - assistance: cs other
# Nama Variabel: m3n_1, Label: assistance: no one
# Nama Variabel: m3n_2, Label: assistance: no one
# Nama Variabel: m3n_3, Label: assistance: no one
# Nama Variabel: m3n_4, Label: assistance: no one
# Nama Variabel: m3n_5, Label: assistance: no one
# Nama Variabel: m3n_6, Label: assistance: no one
# ---------------------------------

# %%
print("\n--- Mencari Variabel Pemeriksaan Nifas Ibu ---")
kata_kunci_1 = 'postnatal'

for var, label in meta_ibu.column_names_to_labels.items():
    if kata_kunci_1 in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Pemeriksaan Nifas Ibu ---
# Nama Variabel: m70_1, Label: baby postnatal check within 2 months
# Nama Variabel: m70_2, Label: baby postnatal check within 2 months
# Nama Variabel: m70_3, Label: baby postnatal check within 2 months
# Nama Variabel: m70_4, Label: baby postnatal check within 2 months
# Nama Variabel: m70_5, Label: baby postnatal check within 2 months
# Nama Variabel: m70_6, Label: baby postnatal check within 2 months
# Nama Variabel: m71_1, Label: time after delivery postnatal check took place
# Nama Variabel: m71_2, Label: time after delivery postnatal check took place
# Nama Variabel: m71_3, Label: time after delivery postnatal check took place
# Nama Variabel: m71_4, Label: time after delivery postnatal check took place
# Nama Variabel: m71_5, Label: time after delivery postnatal check took place
# Nama Variabel: m71_6, Label: time after delivery postnatal check took place
# Nama Variabel: m72_1, Label: person who performed postnatal checkup
# Nama Variabel: m72_2, Label: person who performed postnatal checkup
# Nama Variabel: m72_3, Label: person who performed postnatal checkup
# Nama Variabel: m72_4, Label: person who performed postnatal checkup
# Nama Variabel: m72_5, Label: person who performed postnatal checkup
# Nama Variabel: m72_6, Label: person who performed postnatal checkup
# ---------------------------------

# %%
# --- KODE DETEKTIF: Cari kata kunci "checkup" ---
print("\n--- Mencari Variabel Pemeriksaan Ibu (checkup) ---")
kata_kunci = 'checkup'

for var, label in meta_ibu.column_names_to_labels.items():
    # Kita cari di variabel 'm' (maternity)
    if var.startswith('m') and kata_kunci in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Pemeriksaan Ibu (checkup) ---
# Nama Variabel: m51_1, Label: respondent's checkup after deliver timing
# Nama Variabel: m51_2, Label: respondent's checkup after deliver timing
# Nama Variabel: m51_3, Label: respondent's checkup after deliver timing
# Nama Variabel: m51_4, Label: respondent's checkup after deliver timing
# Nama Variabel: m51_5, Label: respondent's checkup after deliver timing
# Nama Variabel: m51_6, Label: respondent's checkup after deliver timing
# Nama Variabel: m72_1, Label: person who performed postnatal checkup
# Nama Variabel: m72_2, Label: person who performed postnatal checkup
# Nama Variabel: m72_3, Label: person who performed postnatal checkup
# Nama Variabel: m72_4, Label: person who performed postnatal checkup
# Nama Variabel: m72_5, Label: person who performed postnatal checkup
# Nama Variabel: m72_6, Label: person who performed postnatal checkup
# ---------------------------------

# %%
# Cari variabel Asuransi
# --- KODE DETEKTIF: Cari variabel Asuransi dengan kata kunci baru ---
print("\n--- Mencari Variabel Asuransi (Pencarian Lanjutan) ---")

kata_kunci_list = [ 'jaminan', 'bpjs', 'insurance', 'asuransi'] # Kita coba beberapa kata kunci

for var, label in meta_ibu.column_names_to_labels.items():
    for kata_kunci in kata_kunci_list:
        if kata_kunci in label.lower():
            print(f"Nama Variabel: {var}, Label: {label}")
            break # Hentikan jika sudah ketemu agar tidak duplikat

print("---------------------------------")
# Out:
# --- Mencari Variabel Asuransi (Pencarian Lanjutan) ---
# Nama Variabel: v481, Label: covered by health insurance
# Nama Variabel: v481a, Label: na - health insurance type: mutual/community organization
# Nama Variabel: v481b, Label: health insurance type: provided by employer
# Nama Variabel: v481c, Label: health insurance type: social security
# Nama Variabel: v481d, Label: health insurance type: private/commercially purchased
# Nama Variabel: v481e, Label: na - health insurance type: cs
# Nama Variabel: v481f, Label: na - health insurance type: cs
# Nama Variabel: v481g, Label: na - health insurance type: cs
# Nama Variabel: v481h, Label: na - health insurance type: cs
# Nama Variabel: v481x, Label: health insurance type: other
# Nama Variabel: s1010a, Label: covered by health insurance: health donation
# Nama Variabel: s1010b, Label: covered by health insurance: jpk pns/ veteran/ pensiun
# Nama Variabel: s1010c, Label: covered by health insurance: jpk jamsostek
# Nama Variabel: s1010d, Label: covered by health insurance: health card / jpk gakin / poor card / jamkesmas car
# Nama Variabel: s1010e, Label: covered by health insurance: private health insurance
# Nama Variabel: s1010f, Label: covered by health insurance: benefolent fund / substitusion by corporate
# Nama Variabel: s1010x, Label: covered by other health insurance
# ---------------------------------

# %%
# Cari variabel Asuransi
# --- KODE DETEKTIF: Cari variabel Asuransi dengan kata kunci baru ---
print("\n--- Mencari Variabel Age ---")

kata_kunci_list = [ 'ages', 'age'] # Kita coba beberapa kata kunci

for var, label in meta_lahir.column_names_to_labels.items():
    for kata_kunci in kata_kunci_list:
        if kata_kunci in label.lower():
            print(f"Nama Variabel: {var}, Label: {label}")
            break # Hentikan jika sudah ketemu agar tidak duplikat

print("---------------------------------")
# Out:
# --- Mencari Variabel Age ---
# Nama Variabel: v012, Label: respondent's current age
# Nama Variabel: v013, Label: age in 5-year groups
# Nama Variabel: v014, Label: completeness of age information
# Nama Variabel: v152, Label: age of household head
# Nama Variabel: v212, Label: age of respondent at 1st birth
# Nama Variabel: v221, Label: marriage to first birth interval (months)
# Nama Variabel: v320, Label: age at sterilization
# Nama Variabel: v372, Label: na - shown pill package
# Nama Variabel: v372a, Label: na - shown condom package
# Nama Variabel: v3a00f, Label: source of family planning for non-users: village health post
# Nama Variabel: v3a00s, Label: source of family planning for non-users: private village midwife
# Nama Variabel: v439, Label: na - height/age percentile
# Nama Variabel: v440, Label: height/age standard deviation
# Nama Variabel: v441, Label: na - height/age percent ref. median
# Nama Variabel: v447a, Label: na - women's age in years (from household questionnaire)
# Nama Variabel: v452a, Label: na - under age 18 (from household questionnaire)
# Nama Variabel: v480, Label: syringe and needle from new, unopened package
# Nama Variabel: v482a, Label: na - arrange care of biological children under age 18
# Nama Variabel: v482b, Label: na - primary caregiver of children under age 18
# Nama Variabel: v511, Label: age at first cohabitation
# Nama Variabel: v525, Label: age at first sex
# Nama Variabel: v531, Label: age at first sex (imputed)
# Nama Variabel: v538, Label: na - how previous marriage or union ended
# Nama Variabel: v541, Label: na - intends to wait until marriage to have sex
# Nama Variabel: v730, Label: husband/partner's age
# Nama Variabel: b6, Label: age at death
# Nama Variabel: b7, Label: age at death (months, imputed)
# Nama Variabel: b8, Label: current age of child
# Nama Variabel: b13, Label: flag for age at death
# Nama Variabel: m2e, Label: prenatal: village midwife
# Nama Variabel: m3e, Label: assistance: village midwife
# Nama Variabel: m57g, Label: antenatal care: public village health post
# Nama Variabel: m57u, Label: antenatal care: private village midwife
# Nama Variabel: h12d, Label: diarrhea: public village health post
# Nama Variabel: h12s, Label: diarrhea: private village midwife
# Nama Variabel: h13b, Label: na - given pre-packaged ors liquid
# Nama Variabel: h32d, Label: fever/cough: public village health post
# Nama Variabel: h32s, Label: fever/cough: private village midwife
# Nama Variabel: hw1, Label: na - child's age in months
# Nama Variabel: hw4, Label: na - height/age percentile
# Nama Variabel: hw5, Label: height/age standard deviation
# Nama Variabel: hw6, Label: na - height/age percent of ref. median
# Nama Variabel: hw7, Label: na - weight/age percentile
# Nama Variabel: hw8, Label: weight/age standard deviation
# Nama Variabel: hw9, Label: na - weight/age percent of ref. median
# Nama Variabel: hw70, Label: height/age standard deviation (new who)
# Nama Variabel: hw71, Label: weight/age standard deviation (new who)
# Nama Variabel: svillag, Label: village
# Nama Variabel: s236a, Label: miscarriage before january 2007
# Nama Variabel: s236ba, Label: number of miscarriages before january 2007
# Nama Variabel: s305, Label: package of pills in the house
# Nama Variabel: s305b, Label: why don’t you have a/can not show the package of pills?
# Nama Variabel: s632f, Label: husband/partner know when (any of) your teenage daughter(s) had her first menstr
# Nama Variabel: s715f, Label: obtain about family planning information from village leader in last 6 months
# Nama Variabel: s947ba, Label: discuss with teenage daughter: reproductive age
# Nama Variabel: s947bb, Label: discuss with teenage daughter: stis
# Nama Variabel: s947bc, Label: discuss with teenage daughter: drugs
# Nama Variabel: s947bd, Label: discuss with teenage daughter: delay in age at marriage
# Nama Variabel: s947be, Label: discuss with teenage daughter: issues in fp and rh
# Nama Variabel: s947bf, Label: discuss with teenage daughter: puberty
# Nama Variabel: s407c, Label: baby's age when registering the birth
# ---------------------------------

# %% [markdown]
# ### 3. Extracting

# %% [markdown]
# #### 3.1 Define Required Variables

# %%
print("Defining Required Variables")
print("="*70)

# Mother-level variables
ibu_vars_needed = [
    'caseid',           # Unique case identifier
    'v001',             # Cluster number
    'v002',             # Household number
    'v024',             # Region/Province
    'v025',             # Type of residence (1=Urban, 2=Rural)
    'v106',             # Highest education level
    'v201',             # Total children ever born (v201)
    'v212',             # Age of respondent
    'm14_1',            # Number of ANC visits for last birth
    'm15_1',            # Place of delivery (codes 20+ = health facility)
    'v481',             # Health insurance coverage (1=Yes)
    'v208',             # Births in last five years
    'v005',             # Weighted
] + [f'm3{c}_1' for c in 'abcdef']

# Child-level variables
anak_vars_needed = [
    'caseid',           # Links to mother
    'v024',             # Region/Province
    'm18',              # Size of child at birth (1-3=Normal/Large, 4-5=Small)
    'h2',               # BCG vaccination (1=Yes)
    'h4',               # DPT1 vaccination (1=Yes)
    'h6',               # Polio1 vaccination (1=Yes)
    'h8',               # Measles vaccination (1=Yes)
    'v008',             # Interview Date (to calculate age)
    'b3',               # Date of birth of child (to calculate age)
    'm70',              # Baby postnatal check within 2 months
    'm71',              # Time after delivery postnatal check took place
    'v005',             # Weighted
]

# Birth history variables
lahir_vars_needed = [
    'caseid',           # Links to mother
    'v024',             # Region/Province
    'b11',               # Preceding birth interval
    'bord'              # birth order
]

print(f"Mother variables needed: {len(ibu_vars_needed)}")
print(f"Child variables needed: {len(anak_vars_needed)}")
print(f"Birth history variables needed: {len(lahir_vars_needed)}")
# Out:
# Defining Required Variables
# ======================================================================
# Mother variables needed: 19
# Child variables needed: 12
# Birth history variables needed: 4

# %% [markdown]
# #### 3.2 Check Data Availability & Quality

# %%
# ============================================================================
# VALIDATE DATASET AVAILABILITY
# ============================================================================
print("Validating Variable Availability")
print("-"*70)

def check_missing_variables(df, var_list, dataset_name):
    """Check if required variables exist in dataset"""
    missing = [v for v in var_list if v not in df.columns]
    if missing:
        print(f"\nWARNING - {dataset_name}:")
        print(f"   Missing {len(missing)} variables: {missing[:10]}")  # Show first 10
        if len(missing) > 10:
            print(f"   ... and {len(missing)-10} more")
        return False
    else:
        print(f"✓ {dataset_name}: All {len(var_list)} variables found")
        return True

# Validate each dataset
ibu_valid = check_missing_variables(df_ibu, ibu_vars_needed, "Mother Dataset")
anak_valid = check_missing_variables(df_anak, anak_vars_needed, "Child Dataset")
lahir_valid = check_missing_variables(df_lahir, lahir_vars_needed, "Birth Dataset")

if not all([ibu_valid, anak_valid, lahir_valid]):
    print("\nSome variables are missing. Please check your dataset!")
# Out:
# Validating Variable Availability
# ----------------------------------------------------------------------
# ✓ Mother Dataset: All 19 variables found
# ✓ Child Dataset: All 12 variables found
# ✓ Birth Dataset: All 4 variables found

# %%
# ============================================================================
# SELECT AND COPY VARIABLES
# ============================================================================
print("Selecting Required Variables")
print("="*70)

df_ibu_clean = df_ibu[ibu_vars_needed].copy()
df_anak_clean = df_anak[anak_vars_needed].copy()
df_lahir_clean = df_lahir[lahir_vars_needed].copy()

print(f"✓ Mother data: {df_ibu_clean.shape[0]:,} rows, {df_ibu_clean.shape[1]} columns")
print(f"✓ Child data: {df_anak_clean.shape[0]:,} rows, {df_anak_clean.shape[1]} columns")
print(f"✓ Birth data: {df_lahir_clean.shape[0]:,} rows, {df_lahir_clean.shape[1]} columns")
# Out:
# Selecting Required Variables
# ======================================================================
# ✓ Mother data: 45,607 rows, 19 columns
# ✓ Child data: 18,021 rows, 12 columns
# ✓ Birth data: 83,650 rows, 4 columns

# %%
# ============================================================================
# DATA CLEANING
# ============================================================================
print("Data Quality Checks & Cleaning")
print("="*70)

def handle_dhs_special_codes(df, var, missing_codes=[98, 99], method='nan'):
    """
    Handle DHS special codes (Don't Know, Missing, Not Applicable)

    Parameters:
    - df: DataFrame
    - var: Variable name
    - missing_codes: List of codes to treat as missing
    - method: 'nan' or 'zero'
    """
    if var in df.columns:
        original_missing = df[var].isna().sum()
        df[var] = df[var].replace(missing_codes, np.nan)
        new_missing = df[var].isna().sum()
        if new_missing > original_missing:
            print(f"  • {var}: Cleaned {new_missing - original_missing:,} special codes → NaN")
    return df

# Clean Mother data
print("\nCleaning Mother Dataset:")
# Corrected calls for handle_dhs_special_codes
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'm14_1', missing_codes=[97, 98, 99])  # ANC visits
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'm15_1', missing_codes=[97, 98, 99])  # Delivery Places
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'v212', missing_codes=[98, 99])  # Age
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'v106', missing_codes=[8, 9]) # Education
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'v481', missing_codes=[8, 9]) # Insurance
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'b11_01', missing_codes=[98, 99]) # Birth weight


# Clean Child data
print("\nCleaning Child Dataset:")
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'm18', missing_codes=[8, 9, 98, 99])  # Birth size
# Assuming immunization variables h2, h4, h6, h8 also need cleaning for 8, 9
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h2', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h4', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h6', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h8', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'm70', [8,9]) # Postnatal Check
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'm71', [998, 999]) # Time after delivery
required_cols = ['v008', 'b3']
missing_cols = [c for c in required_cols if c not in df_anak_clean.columns]
if missing_cols:
    raise ValueError(f"Missing required columns for age calculation: {missing_cols}")

# Hitung umur dalam bulan
df_anak_clean['age_months'] = df_anak_clean['v008'] - df_anak_clean['b3']

# Bersihkan nilai-nilai tidak valid
df_anak_clean.loc[df_anak_clean['age_months'] < 0, 'age_months'] = None  # impossible
df_anak_clean.loc[df_anak_clean['age_months'] > 200, 'age_months'] = None  # upper sanity bound

print("=== AGE MONTHS CHECK ===")
print(df_anak_clean['age_months'].describe())
print("Invalid ages:", df_anak_clean['age_months'].isna().sum())

# Clean Birth data
print("\nCleaning Birth Dataset:")
df_lahir_clean = handle_dhs_special_codes(df_lahir_clean, 'b11', missing_codes=[98, 99])  # Birth interval
# Out:
# Data Quality Checks & Cleaning
# ======================================================================
#
# Cleaning Mother Dataset:
#   • m14_1: Cleaned 139 special codes → NaN
#
# Cleaning Child Dataset:
#   • m18: Cleaned 570 special codes → NaN
#   • h2: Cleaned 73 special codes → NaN
#   • h4: Cleaned 72 special codes → NaN
#   • h6: Cleaned 72 special codes → NaN
#   • h8: Cleaned 72 special codes → NaN
#   • m70: Cleaned 86 special codes → NaN
#   • m71: Cleaned 337 special codes → NaN
# === AGE MONTHS CHECK ===
# count    18021.000000
# mean        29.267965
# std         17.289612
# min          0.000000
# 25%         14.000000
# 50%         29.000000
# 75%         44.000000
# max         59.000000
# Name: age_months, dtype: float64
# Invalid ages: 0
#
# Cleaning Birth Dataset:
#   • b11: Cleaned 297 special codes → NaN

# %%
# ============================================================================
# FILTER TO APPROPRIATE SAMPLE
# ============================================================================
print("="*70)
print("Sample Selection")
print("="*70)

print(f"Original sample: {len(df_ibu_clean):,} mothers")

# m14_1 is only asked for most recent birth in last 5 years
df_ibu_analysis = df_ibu_clean[df_ibu_clean['v208'] > 0].copy()
print(f"Analysis sample: {len(df_ibu_analysis):,} mothers with recent births")
print(f"Filtered out: {len(df_ibu_clean) - len(df_ibu_analysis):,} mothers without recent births")

df_anak_analysis = df_anak_clean[df_anak_clean['age_months'].between(0, 23)].copy()
print(f"Analysis child sample: {len(df_anak_analysis):,}")
print(f"Filtered out: {len(df_anak_clean) - len(df_anak_analysis):,}")
# Out:
# ======================================================================
# Sample Selection
# ======================================================================
# Original sample: 45,607 mothers
# Analysis sample: 15,262 mothers with recent births
# Filtered out: 30,345 mothers without recent births
# Analysis child sample: 7,334
# Filtered out: 10,687

# %%
# Show missing data summary
print("\nMissing Data Summary:")
print("-" * 50)
key_vars = ['m14_1', 'm15_1', 'v212', 'v481', 'm18', 'v220']
for var in key_vars:
    for df, name in [(df_ibu_clean, 'ibu'), (df_anak_clean, 'anak'), (df_lahir_clean, 'lahir')]:
        if var in df.columns:
            missing_pct = (df[var].isna().sum() / len(df)) * 100
            print(f"  {name}.{var}: {missing_pct:.1f}% missing")
# Out:
# Missing Data Summary:
# --------------------------------------------------
#   ibu.m14_1: 66.8% missing
#   ibu.m15_1: 66.6% missing
#   ibu.v212: 29.6% missing
#   ibu.v481: 0.1% missing
#   anak.m18: 4.0% missing

# %% [markdown]
# #### 3.3 Feature Engineering

# %%
# ============================================================================
# FEATURE ENGINEERING
# ============================================================================
print("Feature Engineering")
print("-"*70)

# -----------------------------------------------------------------------------
# A. MATERNAL HEALTH SERVICE INDICATORS
# -----------------------------------------------------------------------------
print("\nA. Creating Maternal Health Service Indicators:")

# Ensure `df_ibu_analysis` is used as the base for feature engineering
df_ibu_analysis = df_ibu_analysis[df_ibu_analysis['m14_1'].notna()].copy()

# 1. ANC 4+ visits (m14_1 >= 4)
df_ibu_analysis['anc4_pct'] = (df_ibu_analysis['m14_1'] >= 4).astype(int)
print(f"4+ ANC visits: {df_ibu_analysis['anc4_pct'].mean()*100:.1f}%")

# 2. Facility delivery (m15_1: 20-36 = health facilities)
df_ibu_analysis['facility_delivery_pct'] = (
    ((df_ibu_analysis['m15_1'] >= 21) & (df_ibu_analysis['m15_1'] <= 27)) |
    ((df_ibu_analysis['m15_1'] >= 31) & (df_ibu_analysis['m15_1'] <= 37))
).astype(int)
print(f"Facility delivery: {df_ibu_analysis['facility_delivery_pct'].mean()*100:.1f}%")

# 3. Skilled Birth Attendant
# m3a_1 = doctor, m3b_1 = nurse/midwife, m3c_1 = auxiliary midwife
sba_cols = [col for col in df_ibu_analysis.columns if col.startswith('m3') and col.endswith('_1')]
excluded_tba = ['m3f_1'] # Not Skilled
sba_cols_filtered = [c for c in sba_cols if c not in excluded_tba]

df_ibu_analysis['sba_pct'] = df_ibu_analysis[sba_cols_filtered].eq(1).any(axis=1).astype(int)
print(f"Skilled Birth Attendant: {df_ibu_analysis['sba_pct'].mean()*100:.1f}%")

# 4. Any PNC (m70 = 1 → dapat pemeriksaan nifas bayi dalam 2 bulan)
df_pnc = df_anak_analysis[df_anak_analysis['m70'].notna()].copy()
df_pnc['pnc_any_flag'] = (df_pnc['m70'] == 1).astype(int)
print(f"Any PNC (age<=23mo): {df_pnc['pnc_any_flag'].mean()*100:.1f}%")

# 5. PNC within 2 days (m71: hours/days after delivery)
m71 = df_pnc['m71']

mask_hours = m71.between(100, 171)          # 100–171: jam
mask_hours_dk = m71.isin([198, 199])        # DK in hours → tetap dianggap <= 48h
mask_days = m71.between(200, 202)           # 200–202: 0–2 hari

df_pnc['pnc48h_flag'] = (mask_hours | mask_hours_dk | mask_days).astype(int)
print(f"PNC within 2 days (age<=23mo): {df_pnc['pnc48h_flag'].mean()*100:.1f}%")

# 6. Parity
df_ibu_analysis.rename(columns={'v201': 'parity'}, inplace=True)

# -----------------------------------------------------------------------------
# B. SOCIO-DEMOGRAPHIC INDICATORS
# -----------------------------------------------------------------------------
print("\nB. Creating Socio-Demographic Indicators:")

df_ibu_analysis['insured_pct'] = (df_ibu_analysis['v481'] == 1).astype(int)
print(f"Health insurance: {df_ibu_analysis['insured_pct'].mean()*100:.1f}%")

df_ibu_analysis['urban_share_pct'] = (df_ibu_analysis['v025'] == 1).astype(int)
print(f"Urban residence: {df_ibu_analysis['urban_share_pct'].mean()*100:.1f}%")

df_ibu_analysis['low_education_pct'] = (df_ibu_analysis['v106'] <= 1).astype(int)
print(f"Low education (\u2264Primary): {df_ibu_analysis['low_education_pct'].mean()*100:.1f}%")

# -----------------------------------------------------------------------------
# C. RISK FACTORS
# -----------------------------------------------------------------------------
print("\nC. Creating Risk Factor Indicators:")

df_ibu_analysis['maternal_age_risky_pct'] = (
    (df_ibu_analysis['v212'] < 20) | (df_ibu_analysis['v212'] >= 35)
).astype(int)
print(f"Risky maternal age: {df_ibu_analysis['maternal_age_risky_pct'].mean()*100:.1f}%")

# Birth interval (from birth recode)
mask_multibirth = df_lahir_clean['bord'] > 1

df_lahir_clean['short_interval_flag'] = np.nan
df_lahir_clean.loc[mask_multibirth, 'short_interval_flag'] = (
    df_lahir_clean.loc[mask_multibirth, 'b11'] < 24
).astype(int)

print(f"Short birth interval (<24mo): {df_lahir_clean.loc[mask_multibirth, 'short_interval_flag'].mean()*100:.1f}%")

# Child variables
df_anak_analysis['small_birth_size_pct'] = (
    df_anak_analysis['m18'].isin([4, 5])  # 4=small, 5=very small
).astype(int)
print(f"Small birth size: {df_anak_analysis['small_birth_size_pct'].mean()*100:.1f}%")

valid_yes = [1, 2, 3]
mask_12_23 = df_anak_clean['age_months'].between(12, 23)

# Default: NaN (anak di luar 12–23 bulan tidak ikut denominator)
# Full immunization (h2=BCG, h4=DPT1, h6=Polio3, h8=Measles)
# Code 1/2/3 = Yes (card/recall/marked), 0 = No, 8 = Don't know
df_anak_clean['full_immun_binary'] = np.nan

df_anak_clean.loc[mask_12_23, 'full_immun_binary'] = (
    df_anak_clean.loc[mask_12_23, 'h2'].isin(valid_yes) &
    df_anak_clean.loc[mask_12_23, 'h4'].isin(valid_yes) &
    df_anak_clean.loc[mask_12_23, 'h6'].isin(valid_yes) &
    df_anak_clean.loc[mask_12_23, 'h8'].isin(valid_yes)
).astype(int)

print(
    "Full immunization (12–23 mo, all 4 vaccines): "
    f"{df_anak_clean.loc[mask_12_23, 'full_immun_binary'].mean()*100:.1f}%"
)
# Out:
# Feature Engineering
# ----------------------------------------------------------------------
#
# A. Creating Maternal Health Service Indicators:
# 4+ ANC visits: 84.4%
# Facility delivery: 52.8%
# Skilled Birth Attendant: 80.8%
# Any PNC (age<=23mo): 63.6%
# PNC within 2 days (age<=23mo): 46.0%
#
# B. Creating Socio-Demographic Indicators:
# Health insurance: 40.0%
# Urban residence: 45.9%
# Low education (≤Primary): 33.5%
#
# C. Creating Risk Factor Indicators:
# Risky maternal age: 33.2%
# Short birth interval (<24mo): 21.2%
# Small birth size: 13.8%
# Full immunization (12–23 mo, all 4 vaccines): 69.5%

# %% [markdown]
# #### 3.4 Merging

# %%
# Mother-level indicators

df_ibu_2012 = df_ibu_analysis.copy()

# ANC 4+
df_ibu_2012['anc4_flag'] = (df_ibu_2012['m14_1'] >= 4).astype(int)

# Facility delivery (20–89 = health facility)
df_ibu_2012['facility_flag'] = df_ibu_2012['m15_1'].between(20, 89).astype(int)

# SBA (pakai loop semua m3*_1 kecuali TBA, misal m3f_1)
sba_cols = [c for c in df_ibu_2012.columns if c.startswith('m3') and c.endswith('_1')]
excluded_tba = ['m3f_1']  # sesuaikan kalau TBA di kode lain
sba_cols = [c for c in sba_cols if c not in excluded_tba]
df_ibu_2012['sba_flag'] = df_ibu_2012[sba_cols].eq(1).any(axis=1).astype(int)

# Insurance
df_ibu_2012['insured_flag'] = (df_ibu_2012['v481'] == 1).astype(int)

# Urban
df_ibu_2012['urban_flag'] = (df_ibu_2012['v025'] == 1).astype(int)

# Low education (≤ primary)
df_ibu_2012['lowedu_flag'] = df_ibu_2012['v106'].isin([0, 1]).astype(int)  # 0 = no edu, 1 = primary

# Risky maternal age (<20 or >=35)
df_ibu_2012['risky_age_flag'] = ((df_ibu_2012['v212'] < 20) | (df_ibu['v212'] >= 35)).astype(int)

# Parity (bisa dipakai langsung mean)
df_ibu_2012['parity'] = df_ibu_2012['parity']

# Weighting
df_ibu_2012['weight'] = df_ibu_2012['v005'] / 1_000_000

# %%
df_birth = df_lahir_clean.copy()

# Hanya kelahiran dengan older sibling yang punya interval
df_birth_valid = df_birth[df_birth['bord'] > 1].copy()

df_birth_valid['short_interval_flag'] = (df_birth_valid['b11'] < 24).astype(int)

# Aggregate ke ibu: jika ada short interval pada salah satu kelahiran → ibu berisiko
df_interval_mother = (
    df_birth_valid
    .groupby('caseid')['short_interval_flag']
    .max()
    .reset_index()
)

# Merge ke ibu
df_ibu_2012 = df_ibu_2012.merge(df_interval_mother, on='caseid', how='left')

# Ibu yang hanya punya 1 anak (tidak punya interval) = NA → bukan risiko, assign 0
df_ibu_2012['short_interval_flag'] = df_ibu_2012['short_interval_flag'].fillna(0).astype(int)

# %%
# Child-level indicators

df_child_2012 = df_anak_analysis.copy()

# LBW proxy: small_birth_size (m18: 4/5 = small/very small, 1–3 = average/large)
df_child_2012['small_birth_flag'] = df_child_2012['m18'].isin([4, 5]).astype(int)

# Immunization flags (anggap 1 = received, 2/3 juga treated as received kalau ada)
for col in ['h2', 'h4', 'h6', 'h8']:
    df_child_2012[col + '_flag'] = df_child_2012[col].isin([1, 2, 3]).astype(int)

# Full immunization (semua 4 vaksin diterima)
imm_cols = ['h2_flag', 'h4_flag', 'h6_flag', 'h8_flag']
df_child_2012['full_immun_flag'] = df_child_2012[imm_cols].all(axis=1).astype(int)

# Weighting
df_child_2012['weight'] = df_child_2012['v005'] / 1_000_000

# %%
# PNC indicators

df_pnc = df_child_2012[df_child_2012['m70'].notna()].copy()

# Any PNC
df_pnc['pnc_any_flag'] = (df_pnc['m70'] == 1).astype(int)

# PNC ≤48h (pakai coding numeric)
m71 = df_pnc['m71']
mask_hours = m71.between(100, 171)
mask_hours_dk = m71.isin([198, 199])
mask_days = m71.between(200, 202)
df_pnc['pnc48h_flag'] = (mask_hours | mask_hours_dk | mask_days).astype(int)

# %%
group_cols = ['v024']  # v024 = province

# Aggregate Mother
prov_mother = (
    df_ibu_2012
    .groupby(group_cols)
    .agg(
        anc4_pct=('anc4_flag', 'mean'),
        facility_delivery_pct=('facility_flag', 'mean'),
        sba_pct=('sba_flag', 'mean'),
        insured_pct=('insured_flag', 'mean'),
        urban_share_pct=('urban_flag', 'mean'),
        low_education_pct=('lowedu_flag', 'mean'),
        risky_maternal_age_pct=('risky_age_flag', 'mean'),
        birth_interval_short_pct=('short_interval_flag', 'mean'),
        avg_parity=('parity', 'mean')
    )
    .reset_index()
)

# Aggregate Child
prov_child = (
    df_child_2012
    .groupby(group_cols)
    .agg(
        lbw_pct=('small_birth_flag', 'mean'),
        full_immun_pct=('full_immun_flag', 'mean')
    )
    .reset_index()
)

# Aggregate PNC
prov_pnc = (
    df_pnc
    .groupby(group_cols)
    .agg(
        pnc_any_pct=('pnc_any_flag', 'mean'),
        pnc48h_pct=('pnc48h_flag', 'mean')
    )
    .reset_index()
)

# %%
df_2012 = prov_mother.merge(prov_child, on=['v024'], how='left')
df_2012 = df_2012.merge(prov_pnc, on=['v024'], how='left')

df_2012.rename(columns={'v024': 'region'}, inplace=True)

# %%
prov_map = {
    11: "Aceh",
    12: "Sumatera Utara",
    13: "Sumatera Barat",
    14: "Riau",
    15: "Jambi",
    16: "Sumatera Selatan",
    17: "Bengkulu",
    18: "Lampung",
    19: "Kepulauan Bangka Belitung",
    21: "Kepulauan Riau",
    31: "DKI Jakarta",
    32: "Jawa Barat",
    33: "Jawa Tengah",
    34: "DI Yogyakarta",
    35: "Jawa Timur",
    36: "Banten",
    51: "Bali",
    52: "Nusa Tenggara Barat",
    53: "Nusa Tenggara Timur",
    61: "Kalimantan Barat",
    62: "Kalimantan Tengah",
    63: "Kalimantan Selatan",
    64: "Kalimantan Timur",
    65: "Kalimantan Utara",
    71: "Sulawesi Utara",
    72: "Sulawesi Tengah",
    73: "Sulawesi Selatan",
    74: "Sulawesi Tenggara",
    75: "Gorontalo",
    76: "Sulawesi Barat",
    81: "Maluku",
    82: "Maluku Utara",
    91: "Papua",
    92: "Papua Barat",
    94: "Papua Barat"
}

df_2012['province'] = df_2012['region'].map(prov_map)

# cek apakah ada kode yang belum ter-map
unmapped = df_2012[df_2012['province'].isna()]['region'].unique()
print("Unmapped province codes:", unmapped)
# Out:
# Unmapped province codes: []

# %%
cols = df_2012.columns.tolist()

new_order = ['region', 'province'] + [c for c in cols if c not in ['region', 'province']]

# Reorder dataframe
df_2012 = df_2012[new_order]

# %%
# ============================================================================
# FINAL DATA QUALITY SUMMARY
# ============================================================================
print("="*80)
print("FINAL DATA QUALITY SUMMARY – PROVINCIAL INDICATORS")
print("="*80)

# 1. Basic dataset info
print(f"\nTotal observations        : {len(df_2012):,}")
print(f"Unique provinces          : {df_2012['region'].nunique()}")
print(f"Total indicators          : {df_2012.shape[1] - 2} (excluding region/year)")

# 2. Missing check
missing = df_2012.isna().sum()
if missing.sum() == 0:
    print("\nMissing values            : 0")
else:
    print("\nMissing values:")
    print(missing[missing > 0])

# 3. Indicator ranges (auto-detect pct columns)
print("\nIndicator Ranges by Province:")
print("-" * 80)

indicator_cols = [
    col for col in df_2012.columns
    if col not in ['region', 'province'] # Exclude 'province' column from numerical checks
]

for col in indicator_cols:
    col_min = df_2012[col].min()
    col_max = df_2012[col].max()

    # convert to percentage if value seems 0-1
    if col_max <= 1.5:
        print(f"{col:30s}: {col_min*100:6.1f}% – {col_max*100:6.1f}%")
    else:
        print(f"{col:30s}: {col_min:6.2f} – {col_max:6.2f}")

# 4. Quick descriptive stats
print("\nQuick Descriptive Stats:")
print("-" * 80)
print(df_2012[indicator_cols].describe().T[['mean','std','min','max']])

print("\nData preview:")
print(df_2012.head())

print("\nPROCESSING COMPLETE ✔")
print("="*80)
# Out:
# ================================================================================
# FINAL DATA QUALITY SUMMARY – PROVINCIAL INDICATORS
# ================================================================================
#
# Total observations        : 33
# Unique provinces          : 33
# Total indicators          : 13 (excluding region/year)
#
# Missing values            : 0
#
# Indicator Ranges by Province:
# --------------------------------------------------------------------------------
# anc4_pct                      :   41.2% –   97.2%
# facility_delivery_pct         :   20.9% –   98.4%
# sba_pct                       :   46.3% –   98.7%
# insured_pct                   :   23.2% –   75.9%
# urban_share_pct               :   22.3% –  100.0%
# low_education_pct             :   10.4% –   55.3%
# risky_maternal_age_pct        :   19.2% –   48.2%
# birth_interval_short_pct      :    7.2% –   40.3%
# avg_parity                    :   1.80 –   3.23
# lbw_pct                       :    5.2% –   24.9%
# full_immun_pct                :   34.0% –   79.0%
# pnc_any_pct                   :   26.7% –   94.5%
# pnc48h_pct                    :   12.7% –   89.0%
#
# Quick Descriptive Stats:
# --------------------------------------------------------------------------------
#                               mean       std       min       max
# anc4_pct                  0.834594  0.116341  0.411576  0.972100
# facility_delivery_pct     0.546078  0.218476  0.209476  0.983568
# sba_pct                   0.797782  0.139770  0.463023  0.986784
# insured_pct               0.406993  0.122573  0.231746  0.759140
# urban_share_pct           0.440093  0.149193  0.222989  1.000000
# low_education_pct         0.339142  0.106485  0.104478  0.553055
# risky_maternal_age_pct    0.338968  0.081059  0.192364  0.482315
# birth_interval_short_pct  0.189999  0.093449  0.072139  0.403382
# avg_parity                2.390006  0.369073  1.800995  3.234414
# lbw_pct                   0.136610  0.042241  0.052356  0.249110
# full_immun_pct            0.580531  0.106735  0.340314  0.790419
# pnc_any_pct               0.642580  0.152003  0.266990  0.945122
# pnc48h_pct                0.468620  0.169996  0.126506  0.890244
#
# Data preview:
#    region        province  anc4_pct  facility_delivery_pct   sba_pct  \
# 0      11            Aceh  0.802151               0.544086  0.920430
# 1      12  Sumatera Utara  0.801587               0.480952  0.898413
# 2      13  Sumatera Barat  0.903670               0.784404  0.935780
# 3      14            Riau  0.829710               0.498188  0.865942
# 4      15           Jambi  0.834239               0.442935  0.782609
#
#    insured_pct  urban_share_pct  low_education_pct  risky_maternal_age_pct  \
# 0     0.759140         0.335484           0.275269                0.264516
# 1     0.231746         0.455556           0.233333                0.228571
# 2     0.325688         0.440367           0.192661                0.211009
# 3     0.311594         0.389493           0.300725                0.266304
# 4     0.271739         0.355978           0.323370                0.372283
#
#    birth_interval_short_pct  avg_parity   lbw_pct  full_immun_pct  \
# 0                  0.217204    2.475269  0.120833        0.454167
# 1                  0.277778    2.755556  0.148867        0.495146
# 2                  0.158257    2.288991  0.110092        0.577982
# 3                  0.215580    2.469203  0.108871        0.532258
# 4                  0.127717    2.019022  0.116022        0.569061
#
#    pnc_any_pct  pnc48h_pct
# 0     0.634361    0.502203
# 1     0.459184    0.343537
# 2     0.643192    0.460094
# 3     0.670886    0.506329
# 4     0.696629    0.516854
#
# PROCESSING COMPLETE ✔
# ================================================================================

# %%
print("Saving Results")

df_2012.to_csv('dhs_regional_2012.csv', index=False)
print("Files saved successfully!")
# Out:
# Saving Results
# Files saved successfully!

# %% [markdown]
# ## C. Data DHS (2007)

# %% [markdown]
# ### 1. Load Data

# %%
print("Preprocessing Data SDKI 2007...")

ibu_dta_path = 'IDIR51FL.DTA' # File ibu
anak_dta_path = 'IDKR51FL.DTA' # File anak
lahir_dta_path = 'IDBR51FL.DTA' # File Kelahiran

print("\nMembaca file data Stata (.DTA)...")

try:
    df_ibu, meta_ibu = pyreadstat.read_dta(ibu_dta_path)
    df_anak, meta_anak = pyreadstat.read_dta(anak_dta_path)
    df_lahir, meta_lahir = pyreadstat.read_dta(lahir_dta_path)
    print("File Ibu, Rumah Tangga, Kelahiran, & Anak (.DTA) berhasil dibaca.")
except Exception as e:
    print(f"Error saat membaca file: {e}")
    exit()

df_ibu.columns = df_ibu.columns.str.lower()
df_anak.columns = df_anak.columns.str.lower()
df_lahir.columns = df_lahir.columns.str.lower()

print("\n--- Check Dataset ---")
print("Jumlah kolom di df_ibu:", len(df_ibu.columns))
print("Jumlah kolom di df_anak:", len(df_anak.columns))
print("Jumlah kolom di df_lahir:", len(df_lahir.columns))
print("-------------------------------------------------------")
# Out:
# Preprocessing Data SDKI 2007...
#
# Membaca file data Stata (.DTA)...
# File Ibu, Rumah Tangga, Kelahiran, & Anak (.DTA) berhasil dibaca.
#
# --- Check Dataset ---
# Jumlah kolom di df_ibu: 4920
# Jumlah kolom di df_anak: 1346
# Jumlah kolom di df_lahir: 1346
# -------------------------------------------------------

# %% [markdown]
# ### 2. Check Variable Name

# %%
print("\n--- Mencari Variabel Pendidikan ---")
kata_kunci = 'educa'

# Mencari di dalam nama kolom dan label deskripsinya
for var, label in meta_ibu.column_names_to_labels.items():
    if kata_kunci in var.lower() or kata_kunci in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Pendidikan ---
# Nama Variabel: v106, Label: highest educational level
# Nama Variabel: v107, Label: highest year of education
# Nama Variabel: v133, Label: education in single years
# Nama Variabel: v149, Label: educational attainment
# Nama Variabel: awfacte, Label: all woman factor - educational (as used in report)
# Nama Variabel: v701, Label: partner's education level
# Nama Variabel: v702, Label: highest year of education
# Nama Variabel: v715, Label: husband's education-single years
# Nama Variabel: v729, Label: partner's educational attainment
# Nama Variabel: swfacte, Label: all woman factor - educational (standard dhs breakdown)
# ---------------------------------

# %%
print("\n--- Mencari Variabel Ukuran Bayi Lahir ---")
# meta_anak berisi "kamus" untuk df_anak
kata_kunci_1 = 'size'  # Kata kunci: ukuran
kata_kunci_2 = 'weight' # Kata kunci: berat

# Mencari di dalam nama kolom dan label deskripsinya
for var, label in meta_anak.column_names_to_labels.items():
    if kata_kunci_1 in label.lower() or kata_kunci_2 in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Ukuran Bayi Lahir ---
# Nama Variabel: v005, Label: sample weight
# Nama Variabel: v419, Label: entries in height/weight table
# Nama Variabel: v437, Label: na-respondent's weight (kilos-1d)
# Nama Variabel: m18, Label: size of child at birth
# Nama Variabel: m19, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19a, Label: weight at birth recall
# Nama Variabel: hw2, Label: na-weight in kilograms (1 dec.)
# Nama Variabel: s818k, Label: male sti symptoms: loss of weight
# Nama Variabel: s819k, Label: female sti symptoms: loss of weight
# ---------------------------------

# %%
print("\n--- Mencari Variabel Penolong Persalinan ---")
kata_kunci_1 = 'delivery'
kata_kunci_2 = 'birth'

for var, label in meta_ibu.column_names_to_labels.items():
    if kata_kunci_1 in label.lower() or kata_kunci_2 in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Penolong Persalinan ---
# Nama Variabel: v009, Label: respondent's month of birth
# Nama Variabel: v010, Label: respondent's year of birth
# Nama Variabel: v011, Label: date of birth (cmc)
# Nama Variabel: bidx_01, Label: birth column number
# Nama Variabel: bidx_02, Label: birth column number
# Nama Variabel: bidx_03, Label: birth column number
# Nama Variabel: bidx_04, Label: birth column number
# Nama Variabel: bidx_05, Label: birth column number
# Nama Variabel: bidx_06, Label: birth column number
# Nama Variabel: bidx_07, Label: birth column number
# Nama Variabel: bidx_08, Label: birth column number
# Nama Variabel: bidx_09, Label: birth column number
# Nama Variabel: bidx_10, Label: birth column number
# Nama Variabel: bidx_11, Label: birth column number
# Nama Variabel: bidx_12, Label: birth column number
# Nama Variabel: bidx_13, Label: birth column number
# Nama Variabel: bidx_14, Label: birth column number
# Nama Variabel: bidx_15, Label: birth column number
# Nama Variabel: bidx_16, Label: birth column number
# Nama Variabel: bidx_17, Label: birth column number
# Nama Variabel: bidx_18, Label: birth column number
# Nama Variabel: bidx_19, Label: birth column number
# Nama Variabel: bidx_20, Label: birth column number
# Nama Variabel: bord_01, Label: birth order number
# Nama Variabel: bord_02, Label: birth order number
# Nama Variabel: bord_03, Label: birth order number
# Nama Variabel: bord_04, Label: birth order number
# Nama Variabel: bord_05, Label: birth order number
# Nama Variabel: bord_06, Label: birth order number
# Nama Variabel: bord_07, Label: birth order number
# Nama Variabel: bord_08, Label: birth order number
# Nama Variabel: bord_09, Label: birth order number
# Nama Variabel: bord_10, Label: birth order number
# Nama Variabel: bord_11, Label: birth order number
# Nama Variabel: bord_12, Label: birth order number
# Nama Variabel: bord_13, Label: birth order number
# Nama Variabel: bord_14, Label: birth order number
# Nama Variabel: bord_15, Label: birth order number
# Nama Variabel: bord_16, Label: birth order number
# Nama Variabel: bord_17, Label: birth order number
# Nama Variabel: bord_18, Label: birth order number
# Nama Variabel: bord_19, Label: birth order number
# Nama Variabel: bord_20, Label: birth order number
# Nama Variabel: b1_01, Label: month of birth
# Nama Variabel: b1_02, Label: month of birth
# Nama Variabel: b1_03, Label: month of birth
# Nama Variabel: b1_04, Label: month of birth
# Nama Variabel: b1_05, Label: month of birth
# Nama Variabel: b1_06, Label: month of birth
# Nama Variabel: b1_07, Label: month of birth
# Nama Variabel: b1_08, Label: month of birth
# Nama Variabel: b1_09, Label: month of birth
# Nama Variabel: b1_10, Label: month of birth
# Nama Variabel: b1_11, Label: month of birth
# Nama Variabel: b1_12, Label: month of birth
# Nama Variabel: b1_13, Label: month of birth
# Nama Variabel: b1_14, Label: month of birth
# Nama Variabel: b1_15, Label: month of birth
# Nama Variabel: b1_16, Label: month of birth
# Nama Variabel: b1_17, Label: month of birth
# Nama Variabel: b1_18, Label: month of birth
# Nama Variabel: b1_19, Label: month of birth
# Nama Variabel: b1_20, Label: month of birth
# Nama Variabel: b2_01, Label: year of birth
# Nama Variabel: b2_02, Label: year of birth
# Nama Variabel: b2_03, Label: year of birth
# Nama Variabel: b2_04, Label: year of birth
# Nama Variabel: b2_05, Label: year of birth
# Nama Variabel: b2_06, Label: year of birth
# Nama Variabel: b2_07, Label: year of birth
# Nama Variabel: b2_08, Label: year of birth
# Nama Variabel: b2_09, Label: year of birth
# Nama Variabel: b2_10, Label: year of birth
# Nama Variabel: b2_11, Label: year of birth
# Nama Variabel: b2_12, Label: year of birth
# Nama Variabel: b2_13, Label: year of birth
# Nama Variabel: b2_14, Label: year of birth
# Nama Variabel: b2_15, Label: year of birth
# Nama Variabel: b2_16, Label: year of birth
# Nama Variabel: b2_17, Label: year of birth
# Nama Variabel: b2_18, Label: year of birth
# Nama Variabel: b2_19, Label: year of birth
# Nama Variabel: b2_20, Label: year of birth
# Nama Variabel: b3_01, Label: date of birth (cmc)
# Nama Variabel: b3_02, Label: date of birth (cmc)
# Nama Variabel: b3_03, Label: date of birth (cmc)
# Nama Variabel: b3_04, Label: date of birth (cmc)
# Nama Variabel: b3_05, Label: date of birth (cmc)
# Nama Variabel: b3_06, Label: date of birth (cmc)
# Nama Variabel: b3_07, Label: date of birth (cmc)
# Nama Variabel: b3_08, Label: date of birth (cmc)
# Nama Variabel: b3_09, Label: date of birth (cmc)
# Nama Variabel: b3_10, Label: date of birth (cmc)
# Nama Variabel: b3_11, Label: date of birth (cmc)
# Nama Variabel: b3_12, Label: date of birth (cmc)
# Nama Variabel: b3_13, Label: date of birth (cmc)
# Nama Variabel: b3_14, Label: date of birth (cmc)
# Nama Variabel: b3_15, Label: date of birth (cmc)
# Nama Variabel: b3_16, Label: date of birth (cmc)
# Nama Variabel: b3_17, Label: date of birth (cmc)
# Nama Variabel: b3_18, Label: date of birth (cmc)
# Nama Variabel: b3_19, Label: date of birth (cmc)
# Nama Variabel: b3_20, Label: date of birth (cmc)
# Nama Variabel: b11_01, Label: preceding birth interval
# Nama Variabel: b11_02, Label: preceding birth interval
# Nama Variabel: b11_03, Label: preceding birth interval
# Nama Variabel: b11_04, Label: preceding birth interval
# Nama Variabel: b11_05, Label: preceding birth interval
# Nama Variabel: b11_06, Label: preceding birth interval
# Nama Variabel: b11_07, Label: preceding birth interval
# Nama Variabel: b11_08, Label: preceding birth interval
# Nama Variabel: b11_09, Label: preceding birth interval
# Nama Variabel: b11_10, Label: preceding birth interval
# Nama Variabel: b11_11, Label: preceding birth interval
# Nama Variabel: b11_12, Label: preceding birth interval
# Nama Variabel: b11_13, Label: preceding birth interval
# Nama Variabel: b11_14, Label: preceding birth interval
# Nama Variabel: b11_15, Label: preceding birth interval
# Nama Variabel: b11_16, Label: preceding birth interval
# Nama Variabel: b11_17, Label: preceding birth interval
# Nama Variabel: b11_18, Label: preceding birth interval
# Nama Variabel: b11_19, Label: preceding birth interval
# Nama Variabel: b11_20, Label: preceding birth interval
# Nama Variabel: b12_01, Label: succeeding birth interval
# Nama Variabel: b12_02, Label: succeeding birth interval
# Nama Variabel: b12_03, Label: succeeding birth interval
# Nama Variabel: b12_04, Label: succeeding birth interval
# Nama Variabel: b12_05, Label: succeeding birth interval
# Nama Variabel: b12_06, Label: succeeding birth interval
# Nama Variabel: b12_07, Label: succeeding birth interval
# Nama Variabel: b12_08, Label: succeeding birth interval
# Nama Variabel: b12_09, Label: succeeding birth interval
# Nama Variabel: b12_10, Label: succeeding birth interval
# Nama Variabel: b12_11, Label: succeeding birth interval
# Nama Variabel: b12_12, Label: succeeding birth interval
# Nama Variabel: b12_13, Label: succeeding birth interval
# Nama Variabel: b12_14, Label: succeeding birth interval
# Nama Variabel: b12_15, Label: succeeding birth interval
# Nama Variabel: b12_16, Label: succeeding birth interval
# Nama Variabel: b12_17, Label: succeeding birth interval
# Nama Variabel: b12_18, Label: succeeding birth interval
# Nama Variabel: b12_19, Label: succeeding birth interval
# Nama Variabel: b12_20, Label: succeeding birth interval
# Nama Variabel: b15_01, Label: live birth between births
# Nama Variabel: b15_02, Label: live birth between births
# Nama Variabel: b15_03, Label: live birth between births
# Nama Variabel: b15_04, Label: live birth between births
# Nama Variabel: b15_05, Label: live birth between births
# Nama Variabel: b15_06, Label: live birth between births
# Nama Variabel: b15_07, Label: live birth between births
# Nama Variabel: b15_08, Label: live birth between births
# Nama Variabel: b15_09, Label: live birth between births
# Nama Variabel: b15_10, Label: live birth between births
# Nama Variabel: b15_11, Label: live birth between births
# Nama Variabel: b15_12, Label: live birth between births
# Nama Variabel: b15_13, Label: live birth between births
# Nama Variabel: b15_14, Label: live birth between births
# Nama Variabel: b15_15, Label: live birth between births
# Nama Variabel: b15_16, Label: live birth between births
# Nama Variabel: b15_17, Label: live birth between births
# Nama Variabel: b15_18, Label: live birth between births
# Nama Variabel: b15_19, Label: live birth between births
# Nama Variabel: b15_20, Label: live birth between births
# Nama Variabel: v208, Label: births in last five years
# Nama Variabel: v209, Label: births in past year
# Nama Variabel: v210, Label: births in month of interview
# Nama Variabel: v211, Label: date of first birth (cmc)
# Nama Variabel: v212, Label: age of respondent at 1st birth
# Nama Variabel: v221, Label: marriage to first birth interval (months)
# Nama Variabel: v222, Label: last birth to interview (months)
# Nama Variabel: v224, Label: entries in birth history
# Nama Variabel: v237, Label: birth between last and interview
# Nama Variabel: v238, Label: births in last three years
# Nama Variabel: v3a00v, Label: source of fp for non-users: delivery post
# Nama Variabel: midx_1, Label: index to birth history
# Nama Variabel: midx_2, Label: index to birth history
# Nama Variabel: midx_3, Label: index to birth history
# Nama Variabel: midx_4, Label: index to birth history
# Nama Variabel: midx_5, Label: index to birth history
# Nama Variabel: midx_6, Label: index to birth history
# Nama Variabel: m1_1, Label: tetanus injections before birth
# Nama Variabel: m1_2, Label: tetanus injections before birth
# Nama Variabel: m1_3, Label: tetanus injections before birth
# Nama Variabel: m1_4, Label: tetanus injections before birth
# Nama Variabel: m1_5, Label: tetanus injections before birth
# Nama Variabel: m1_6, Label: tetanus injections before birth
# Nama Variabel: m2f_1, Label: na-prenatal: trained birth att.
# Nama Variabel: m2f_2, Label: na-prenatal: trained birth att.
# Nama Variabel: m2f_3, Label: na-prenatal: trained birth att.
# Nama Variabel: m2f_4, Label: na-prenatal: trained birth att.
# Nama Variabel: m2f_5, Label: na-prenatal: trained birth att.
# Nama Variabel: m2f_6, Label: na-prenatal: trained birth att.
# Nama Variabel: m2g_1, Label: prenatal: traditional birth attendant
# Nama Variabel: m2g_2, Label: prenatal: traditional birth attendant
# Nama Variabel: m2g_3, Label: prenatal: traditional birth attendant
# Nama Variabel: m2g_4, Label: prenatal: traditional birth attendant
# Nama Variabel: m2g_5, Label: prenatal: traditional birth attendant
# Nama Variabel: m2g_6, Label: prenatal: traditional birth attendant
# Nama Variabel: m3f_1, Label: na-assistance: trained birth att.
# Nama Variabel: m3f_2, Label: na-assistance: trained birth att.
# Nama Variabel: m3f_3, Label: na-assistance: trained birth att.
# Nama Variabel: m3f_4, Label: na-assistance: trained birth att.
# Nama Variabel: m3f_5, Label: na-assistance: trained birth att.
# Nama Variabel: m3f_6, Label: na-assistance: trained birth att.
# Nama Variabel: m3g_1, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_2, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_3, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_4, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_5, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_6, Label: assistance: traditional birth attendant
# Nama Variabel: m15_1, Label: place of delivery
# Nama Variabel: m15_2, Label: place of delivery
# Nama Variabel: m15_3, Label: place of delivery
# Nama Variabel: m15_4, Label: place of delivery
# Nama Variabel: m15_5, Label: place of delivery
# Nama Variabel: m15_6, Label: place of delivery
# Nama Variabel: m17_1, Label: delivery by caesarian section
# Nama Variabel: m17_2, Label: delivery by caesarian section
# Nama Variabel: m17_3, Label: delivery by caesarian section
# Nama Variabel: m17_4, Label: delivery by caesarian section
# Nama Variabel: m17_5, Label: delivery by caesarian section
# Nama Variabel: m17_6, Label: delivery by caesarian section
# Nama Variabel: m18_1, Label: size of child at birth
# Nama Variabel: m18_2, Label: size of child at birth
# Nama Variabel: m18_3, Label: size of child at birth
# Nama Variabel: m18_4, Label: size of child at birth
# Nama Variabel: m18_5, Label: size of child at birth
# Nama Variabel: m18_6, Label: size of child at birth
# Nama Variabel: m19_1, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19_2, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19_3, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19_4, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19_5, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19_6, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19a_1, Label: weight at birth recall
# Nama Variabel: m19a_2, Label: weight at birth recall
# Nama Variabel: m19a_3, Label: weight at birth recall
# Nama Variabel: m19a_4, Label: weight at birth recall
# Nama Variabel: m19a_5, Label: weight at birth recall
# Nama Variabel: m19a_6, Label: weight at birth recall
# Nama Variabel: m54_1, Label: received vitamin a dose in first 2 months after delivery
# Nama Variabel: m54_2, Label: received vitamin a dose in first 2 months after delivery
# Nama Variabel: m54_3, Label: received vitamin a dose in first 2 months after delivery
# Nama Variabel: m54_4, Label: received vitamin a dose in first 2 months after delivery
# Nama Variabel: m54_5, Label: received vitamin a dose in first 2 months after delivery
# Nama Variabel: m54_6, Label: received vitamin a dose in first 2 months after delivery
# Nama Variabel: m61_1, Label: na-time spent at place of delivery
# Nama Variabel: m61_2, Label: na-time spent at place of delivery
# Nama Variabel: m61_3, Label: na-time spent at place of delivery
# Nama Variabel: m61_4, Label: na-time spent at place of delivery
# Nama Variabel: m61_5, Label: na-time spent at place of delivery
# Nama Variabel: m61_6, Label: na-time spent at place of delivery
# Nama Variabel: m66_1, Label: na-after discharge/delivery at home anyone checked responden
# Nama Variabel: m66_2, Label: na-after discharge/delivery at home anyone checked responden
# Nama Variabel: m66_3, Label: na-after discharge/delivery at home anyone checked responden
# Nama Variabel: m66_4, Label: na-after discharge/delivery at home anyone checked responden
# Nama Variabel: m66_5, Label: na-after discharge/delivery at home anyone checked responden
# Nama Variabel: m66_6, Label: na-after discharge/delivery at home anyone checked responden
# Nama Variabel: m67_1, Label: na-how long after discharge/delivery at home respondent heal
# Nama Variabel: m67_2, Label: na-how long after discharge/delivery at home respondent heal
# Nama Variabel: m67_3, Label: na-how long after discharge/delivery at home respondent heal
# Nama Variabel: m67_4, Label: na-how long after discharge/delivery at home respondent heal
# Nama Variabel: m67_5, Label: na-how long after discharge/delivery at home respondent heal
# Nama Variabel: m67_6, Label: na-how long after discharge/delivery at home respondent heal
# Nama Variabel: m68_1, Label: na-who checked respondent health after discharge/delivery at
# Nama Variabel: m68_2, Label: na-who checked respondent health after discharge/delivery at
# Nama Variabel: m68_3, Label: na-who checked respondent health after discharge/delivery at
# Nama Variabel: m68_4, Label: na-who checked respondent health after discharge/delivery at
# Nama Variabel: m68_5, Label: na-who checked respondent health after discharge/delivery at
# Nama Variabel: m68_6, Label: na-who checked respondent health after discharge/delivery at
# Nama Variabel: m69_1, Label: na-where respondent check after discharge/delivery at home t
# Nama Variabel: m69_2, Label: na-where respondent check after discharge/delivery at home t
# Nama Variabel: m69_3, Label: na-where respondent check after discharge/delivery at home t
# Nama Variabel: m69_4, Label: na-where respondent check after discharge/delivery at home t
# Nama Variabel: m69_5, Label: na-where respondent check after discharge/delivery at home t
# Nama Variabel: m69_6, Label: na-where respondent check after discharge/delivery at home t
# Nama Variabel: m71_1, Label: how long after delivery postnatal check took place
# Nama Variabel: m71_2, Label: how long after delivery postnatal check took place
# Nama Variabel: m71_3, Label: how long after delivery postnatal check took place
# Nama Variabel: m71_4, Label: how long after delivery postnatal check took place
# Nama Variabel: m71_5, Label: how long after delivery postnatal check took place
# Nama Variabel: m71_6, Label: how long after delivery postnatal check took place
# Nama Variabel: v401, Label: last birth caesarean section
# Nama Variabel: v468, Label: columns used for last birth only variables
# Nama Variabel: hidx_1, Label: index to birth history
# Nama Variabel: hidx_2, Label: index to birth history
# Nama Variabel: hidx_3, Label: index to birth history
# Nama Variabel: hidx_4, Label: index to birth history
# Nama Variabel: hidx_5, Label: index to birth history
# Nama Variabel: hidx_6, Label: index to birth history
# Nama Variabel: h12u_1, Label: diarrhea: other delivery post
# Nama Variabel: h12u_2, Label: diarrhea: other delivery post
# Nama Variabel: h12u_3, Label: diarrhea: other delivery post
# Nama Variabel: h12u_4, Label: diarrhea: other delivery post
# Nama Variabel: h12u_5, Label: diarrhea: other delivery post
# Nama Variabel: h12u_6, Label: diarrhea: other delivery post
# Nama Variabel: h12w_1, Label: diarrhea: other traditional birth attendant
# Nama Variabel: h12w_2, Label: diarrhea: other traditional birth attendant
# Nama Variabel: h12w_3, Label: diarrhea: other traditional birth attendant
# Nama Variabel: h12w_4, Label: diarrhea: other traditional birth attendant
# Nama Variabel: h12w_5, Label: diarrhea: other traditional birth attendant
# Nama Variabel: h12w_6, Label: diarrhea: other traditional birth attendant
# Nama Variabel: h32u_1, Label: fever/cough: other delivery post
# Nama Variabel: h32u_2, Label: fever/cough: other delivery post
# Nama Variabel: h32u_3, Label: fever/cough: other delivery post
# Nama Variabel: h32u_4, Label: fever/cough: other delivery post
# Nama Variabel: h32u_5, Label: fever/cough: other delivery post
# Nama Variabel: h32u_6, Label: fever/cough: other delivery post
# Nama Variabel: h32w_1, Label: fever/cough: other traditional birth attendant
# Nama Variabel: h32w_2, Label: fever/cough: other traditional birth attendant
# Nama Variabel: h32w_3, Label: fever/cough: other traditional birth attendant
# Nama Variabel: h32w_4, Label: fever/cough: other traditional birth attendant
# Nama Variabel: h32w_5, Label: fever/cough: other traditional birth attendant
# Nama Variabel: h32w_6, Label: fever/cough: other traditional birth attendant
# Nama Variabel: hwidx_1, Label: na-index to birth history
# Nama Variabel: hwidx_2, Label: na-index to birth history
# Nama Variabel: hwidx_3, Label: na-index to birth history
# Nama Variabel: hwidx_4, Label: na-index to birth history
# Nama Variabel: hwidx_5, Label: na-index to birth history
# Nama Variabel: hwidx_6, Label: na-index to birth history
# Nama Variabel: hw16_1, Label: na-day of birth of child
# Nama Variabel: hw16_2, Label: na-day of birth of child
# Nama Variabel: hw16_3, Label: na-day of birth of child
# Nama Variabel: hw16_4, Label: na-day of birth of child
# Nama Variabel: hw16_5, Label: na-day of birth of child
# Nama Variabel: hw16_6, Label: na-day of birth of child
# Nama Variabel: v616, Label: time for future birth
# Nama Variabel: v633c, Label: reason for not having sex: recent birth
# Nama Variabel: v762av, Label: source for condoms: delivery post
# Nama Variabel: v774b, Label: aids transmit. during delivery
# Nama Variabel: mm4_01, Label: cmc date of birth of sibling
# Nama Variabel: mm4_02, Label: cmc date of birth of sibling
# Nama Variabel: mm4_03, Label: cmc date of birth of sibling
# Nama Variabel: mm4_04, Label: cmc date of birth of sibling
# Nama Variabel: mm4_05, Label: cmc date of birth of sibling
# Nama Variabel: mm4_06, Label: cmc date of birth of sibling
# Nama Variabel: mm4_07, Label: cmc date of birth of sibling
# Nama Variabel: mm4_08, Label: cmc date of birth of sibling
# Nama Variabel: mm4_09, Label: cmc date of birth of sibling
# Nama Variabel: mm4_10, Label: cmc date of birth of sibling
# Nama Variabel: mm4_11, Label: cmc date of birth of sibling
# Nama Variabel: mm4_12, Label: cmc date of birth of sibling
# Nama Variabel: mm4_13, Label: cmc date of birth of sibling
# Nama Variabel: mm4_14, Label: cmc date of birth of sibling
# Nama Variabel: mm4_15, Label: cmc date of birth of sibling
# Nama Variabel: mm4_16, Label: cmc date of birth of sibling
# Nama Variabel: mm4_17, Label: cmc date of birth of sibling
# Nama Variabel: mm4_18, Label: cmc date of birth of sibling
# Nama Variabel: mm4_19, Label: cmc date of birth of sibling
# Nama Variabel: mm4_20, Label: cmc date of birth of sibling
# Nama Variabel: mm12_01, Label: na-time between delivery & death
# Nama Variabel: mm12_02, Label: na-time between delivery & death
# Nama Variabel: mm12_03, Label: na-time between delivery & death
# Nama Variabel: mm12_04, Label: na-time between delivery & death
# Nama Variabel: mm12_05, Label: na-time between delivery & death
# Nama Variabel: mm12_06, Label: na-time between delivery & death
# Nama Variabel: mm12_07, Label: na-time between delivery & death
# Nama Variabel: mm12_08, Label: na-time between delivery & death
# Nama Variabel: mm12_09, Label: na-time between delivery & death
# Nama Variabel: mm12_10, Label: na-time between delivery & death
# Nama Variabel: mm12_11, Label: na-time between delivery & death
# Nama Variabel: mm12_12, Label: na-time between delivery & death
# Nama Variabel: mm12_13, Label: na-time between delivery & death
# Nama Variabel: mm12_14, Label: na-time between delivery & death
# Nama Variabel: mm12_15, Label: na-time between delivery & death
# Nama Variabel: mm12_16, Label: na-time between delivery & death
# Nama Variabel: mm12_17, Label: na-time between delivery & death
# Nama Variabel: mm12_18, Label: na-time between delivery & death
# Nama Variabel: mm12_19, Label: na-time between delivery & death
# Nama Variabel: mm12_20, Label: na-time between delivery & death
# Nama Variabel: mmc2, Label: preceding births before respondent's birth
# Nama Variabel: idxml_1, Label: index to birth history
# Nama Variabel: idxml_2, Label: index to birth history
# Nama Variabel: idxml_3, Label: index to birth history
# Nama Variabel: idxml_4, Label: index to birth history
# Nama Variabel: idxml_5, Label: index to birth history
# Nama Variabel: idxml_6, Label: index to birth history
# Nama Variabel: s242a, Label: problems during labor/delivery: water breaks too soon
# Nama Variabel: s242b, Label: problems during labor/delivery: excessive bleeding during an
# Nama Variabel: s242c, Label: problems during labor/delivery: fever
# Nama Variabel: s242d, Label: problems during labor/delivery: long labor
# Nama Variabel: s242e, Label: problems during labor/delivery: swollen limbs
# Nama Variabel: s242f, Label: problems during labor/delivery: faint
# Nama Variabel: s242g, Label: problems during labor/delivery: breathlessness
# Nama Variabel: s242h, Label: problems during labor/delivery: tiredness
# Nama Variabel: s242x, Label: problems during labor/delivery: other
# Nama Variabel: s242z, Label: problems during labor/delivery: don't know
# Nama Variabel: s244a, Label: problems after giving birth: excessive bleeding
# Nama Variabel: s244b, Label: problems after giving birth: faint
# Nama Variabel: s244c, Label: problems after giving birth: convulsions
# Nama Variabel: s244d, Label: problems after giving birth: fever
# Nama Variabel: s244e, Label: problems after giving birth: foul-smelling discharge
# Nama Variabel: s244f, Label: problems after giving birth: sore breast
# Nama Variabel: s244g, Label: problems after giving birth: sadness/depression
# Nama Variabel: s244x, Label: problems after giving birth: other
# Nama Variabel: s244z, Label: problems after giving birth: don't know
# Nama Variabel: s330r, Label: source known among non users: delivery post
# Nama Variabel: s525q, Label: source of condoms known: delivery post
# Nama Variabel: idx94_1, Label: index to birth history
# Nama Variabel: idx94_2, Label: index to birth history
# Nama Variabel: idx94_3, Label: index to birth history
# Nama Variabel: idx94_4, Label: index to birth history
# Nama Variabel: idx94_5, Label: index to birth history
# Nama Variabel: idx94_6, Label: index to birth history
# Nama Variabel: s410ac_1, Label: number of antenatal visits - btw 7th month and delivery
# Nama Variabel: s410ac_2, Label: number of antenatal visits - btw 7th month and delivery
# Nama Variabel: s410ac_3, Label: number of antenatal visits - btw 7th month and delivery
# Nama Variabel: s410ac_4, Label: number of antenatal visits - btw 7th month and delivery
# Nama Variabel: s410ac_5, Label: number of antenatal visits - btw 7th month and delivery
# Nama Variabel: s410ac_6, Label: number of antenatal visits - btw 7th month and delivery
# Nama Variabel: s414ac_1, Label: during pregnancy discuss: person to assist delivery
# Nama Variabel: s414ac_2, Label: during pregnancy discuss: person to assist delivery
# Nama Variabel: s414ac_3, Label: during pregnancy discuss: person to assist delivery
# Nama Variabel: s414ac_4, Label: during pregnancy discuss: person to assist delivery
# Nama Variabel: s414ac_5, Label: during pregnancy discuss: person to assist delivery
# Nama Variabel: s414ac_6, Label: during pregnancy discuss: person to assist delivery
# Nama Variabel: s414ad_1, Label: during pregnancy discuss: payment for the delivery
# Nama Variabel: s414ad_2, Label: during pregnancy discuss: payment for the delivery
# Nama Variabel: s414ad_3, Label: during pregnancy discuss: payment for the delivery
# Nama Variabel: s414ad_4, Label: during pregnancy discuss: payment for the delivery
# Nama Variabel: s414ad_5, Label: during pregnancy discuss: payment for the delivery
# Nama Variabel: s414ad_6, Label: during pregnancy discuss: payment for the delivery
# Nama Variabel: s427a_1, Label: husband was with her at delivery
# Nama Variabel: s427a_2, Label: husband was with her at delivery
# Nama Variabel: s427a_3, Label: husband was with her at delivery
# Nama Variabel: s427a_4, Label: husband was with her at delivery
# Nama Variabel: s427a_5, Label: husband was with her at delivery
# Nama Variabel: s427a_6, Label: husband was with her at delivery
# Nama Variabel: s428aa_1, Label: time of birth: prolonged labour
# Nama Variabel: s428aa_2, Label: time of birth: prolonged labour
# Nama Variabel: s428aa_3, Label: time of birth: prolonged labour
# Nama Variabel: s428aa_4, Label: time of birth: prolonged labour
# Nama Variabel: s428aa_5, Label: time of birth: prolonged labour
# Nama Variabel: s428aa_6, Label: time of birth: prolonged labour
# Nama Variabel: s428ab_1, Label: time of birth: excessive vaginal bleeding
# Nama Variabel: s428ab_2, Label: time of birth: excessive vaginal bleeding
# Nama Variabel: s428ab_3, Label: time of birth: excessive vaginal bleeding
# Nama Variabel: s428ab_4, Label: time of birth: excessive vaginal bleeding
# Nama Variabel: s428ab_5, Label: time of birth: excessive vaginal bleeding
# Nama Variabel: s428ab_6, Label: time of birth: excessive vaginal bleeding
# Nama Variabel: s428ac_1, Label: time of birth: fever and foul smelling vaginal discharge
# Nama Variabel: s428ac_2, Label: time of birth: fever and foul smelling vaginal discharge
# Nama Variabel: s428ac_3, Label: time of birth: fever and foul smelling vaginal discharge
# Nama Variabel: s428ac_4, Label: time of birth: fever and foul smelling vaginal discharge
# Nama Variabel: s428ac_5, Label: time of birth: fever and foul smelling vaginal discharge
# Nama Variabel: s428ac_6, Label: time of birth: fever and foul smelling vaginal discharge
# Nama Variabel: s428ad_1, Label: time of birth: convulsions
# Nama Variabel: s428ad_2, Label: time of birth: convulsions
# Nama Variabel: s428ad_3, Label: time of birth: convulsions
# Nama Variabel: s428ad_4, Label: time of birth: convulsions
# Nama Variabel: s428ad_5, Label: time of birth: convulsions
# Nama Variabel: s428ad_6, Label: time of birth: convulsions
# Nama Variabel: s428ae_1, Label: time of birth: water broke > 6 hours before delivery
# Nama Variabel: s428ae_2, Label: time of birth: water broke > 6 hours before delivery
# Nama Variabel: s428ae_3, Label: time of birth: water broke > 6 hours before delivery
# Nama Variabel: s428ae_4, Label: time of birth: water broke > 6 hours before delivery
# Nama Variabel: s428ae_5, Label: time of birth: water broke > 6 hours before delivery
# Nama Variabel: s428ae_6, Label: time of birth: water broke > 6 hours before delivery
# Nama Variabel: s428af_1, Label: time of birth: other
# Nama Variabel: s428af_2, Label: time of birth: other
# Nama Variabel: s428af_3, Label: time of birth: other
# Nama Variabel: s428af_4, Label: time of birth: other
# Nama Variabel: s428af_5, Label: time of birth: other
# Nama Variabel: s428af_6, Label: time of birth: other
# Nama Variabel: s471o_1, Label: advice/treatment for fever/cough: delivery post
# Nama Variabel: s471o_2, Label: advice/treatment for fever/cough: delivery post
# Nama Variabel: s471o_3, Label: advice/treatment for fever/cough: delivery post
# Nama Variabel: s471o_4, Label: advice/treatment for fever/cough: delivery post
# Nama Variabel: s471o_5, Label: advice/treatment for fever/cough: delivery post
# Nama Variabel: s471o_6, Label: advice/treatment for fever/cough: delivery post
# Nama Variabel: s471r_1, Label: advice/treatment for fever/cough: traditional birth attendan
# Nama Variabel: s471r_2, Label: advice/treatment for fever/cough: traditional birth attendan
# Nama Variabel: s471r_3, Label: advice/treatment for fever/cough: traditional birth attendan
# Nama Variabel: s471r_4, Label: advice/treatment for fever/cough: traditional birth attendan
# Nama Variabel: s471r_5, Label: advice/treatment for fever/cough: traditional birth attendan
# Nama Variabel: s471r_6, Label: advice/treatment for fever/cough: traditional birth attendan
# Nama Variabel: s482o_1, Label: advice/treatment for diarrhea: other delivery post
# Nama Variabel: s482o_2, Label: advice/treatment for diarrhea: other delivery post
# Nama Variabel: s482o_3, Label: advice/treatment for diarrhea: other delivery post
# Nama Variabel: s482o_4, Label: advice/treatment for diarrhea: other delivery post
# Nama Variabel: s482o_5, Label: advice/treatment for diarrhea: other delivery post
# Nama Variabel: s482o_6, Label: advice/treatment for diarrhea: other delivery post
# Nama Variabel: s482r_1, Label: advice/treatment for diarrhea: other traditional birth atten
# Nama Variabel: s482r_2, Label: advice/treatment for diarrhea: other traditional birth atten
# Nama Variabel: s482r_3, Label: advice/treatment for diarrhea: other traditional birth atten
# Nama Variabel: s482r_4, Label: advice/treatment for diarrhea: other traditional birth atten
# Nama Variabel: s482r_5, Label: advice/treatment for diarrhea: other traditional birth atten
# Nama Variabel: s482r_6, Label: advice/treatment for diarrhea: other traditional birth atten
# ---------------------------------

# %%
print("\n--- Mencari Semua Variabel Bantuan Persalinan ---")
kata_kunci = 'assistance'

for var, label in meta_ibu.column_names_to_labels.items():
    # Kita hanya cari di variabel yang berawalan 'm3' untuk menjaga relevansi
    if var.startswith('m3') and kata_kunci in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Semua Variabel Bantuan Persalinan ---
# Nama Variabel: m3a_1, Label: assistance: doctor
# Nama Variabel: m3a_2, Label: assistance: doctor
# Nama Variabel: m3a_3, Label: assistance: doctor
# Nama Variabel: m3a_4, Label: assistance: doctor
# Nama Variabel: m3a_5, Label: assistance: doctor
# Nama Variabel: m3a_6, Label: assistance: doctor
# Nama Variabel: m3b_1, Label: assistance: nurse
# Nama Variabel: m3b_2, Label: assistance: nurse
# Nama Variabel: m3b_3, Label: assistance: nurse
# Nama Variabel: m3b_4, Label: assistance: nurse
# Nama Variabel: m3b_5, Label: assistance: nurse
# Nama Variabel: m3b_6, Label: assistance: nurse
# Nama Variabel: m3c_1, Label: assistance: village midwife
# Nama Variabel: m3c_2, Label: assistance: village midwife
# Nama Variabel: m3c_3, Label: assistance: village midwife
# Nama Variabel: m3c_4, Label: assistance: village midwife
# Nama Variabel: m3c_5, Label: assistance: village midwife
# Nama Variabel: m3c_6, Label: assistance: village midwife
# Nama Variabel: m3d_1, Label: assistance: obgyn
# Nama Variabel: m3d_2, Label: assistance: obgyn
# Nama Variabel: m3d_3, Label: assistance: obgyn
# Nama Variabel: m3d_4, Label: assistance: obgyn
# Nama Variabel: m3d_5, Label: assistance: obgyn
# Nama Variabel: m3d_6, Label: assistance: obgyn
# Nama Variabel: m3e_1, Label: assistance: midwife
# Nama Variabel: m3e_2, Label: assistance: midwife
# Nama Variabel: m3e_3, Label: assistance: midwife
# Nama Variabel: m3e_4, Label: assistance: midwife
# Nama Variabel: m3e_5, Label: assistance: midwife
# Nama Variabel: m3e_6, Label: assistance: midwife
# Nama Variabel: m3f_1, Label: na-assistance: trained birth att.
# Nama Variabel: m3f_2, Label: na-assistance: trained birth att.
# Nama Variabel: m3f_3, Label: na-assistance: trained birth att.
# Nama Variabel: m3f_4, Label: na-assistance: trained birth att.
# Nama Variabel: m3f_5, Label: na-assistance: trained birth att.
# Nama Variabel: m3f_6, Label: na-assistance: trained birth att.
# Nama Variabel: m3g_1, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_2, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_3, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_4, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_5, Label: assistance: traditional birth attendant
# Nama Variabel: m3g_6, Label: assistance: traditional birth attendant
# Nama Variabel: m3h_1, Label: assistance: relative/friend
# Nama Variabel: m3h_2, Label: assistance: relative/friend
# Nama Variabel: m3h_3, Label: assistance: relative/friend
# Nama Variabel: m3h_4, Label: assistance: relative/friend
# Nama Variabel: m3h_5, Label: assistance: relative/friend
# Nama Variabel: m3h_6, Label: assistance: relative/friend
# Nama Variabel: m3i_1, Label: na-assistance: cs other person
# Nama Variabel: m3i_2, Label: na-assistance: cs other person
# Nama Variabel: m3i_3, Label: na-assistance: cs other person
# Nama Variabel: m3i_4, Label: na-assistance: cs other person
# Nama Variabel: m3i_5, Label: na-assistance: cs other person
# Nama Variabel: m3i_6, Label: na-assistance: cs other person
# Nama Variabel: m3j_1, Label: na-assistance: cs other person
# Nama Variabel: m3j_2, Label: na-assistance: cs other person
# Nama Variabel: m3j_3, Label: na-assistance: cs other person
# Nama Variabel: m3j_4, Label: na-assistance: cs other person
# Nama Variabel: m3j_5, Label: na-assistance: cs other person
# Nama Variabel: m3j_6, Label: na-assistance: cs other person
# Nama Variabel: m3k_1, Label: assistance: other
# Nama Variabel: m3k_2, Label: assistance: other
# Nama Variabel: m3k_3, Label: assistance: other
# Nama Variabel: m3k_4, Label: assistance: other
# Nama Variabel: m3k_5, Label: assistance: other
# Nama Variabel: m3k_6, Label: assistance: other
# Nama Variabel: m3l_1, Label: na-assistance: cs other
# Nama Variabel: m3l_2, Label: na-assistance: cs other
# Nama Variabel: m3l_3, Label: na-assistance: cs other
# Nama Variabel: m3l_4, Label: na-assistance: cs other
# Nama Variabel: m3l_5, Label: na-assistance: cs other
# Nama Variabel: m3l_6, Label: na-assistance: cs other
# Nama Variabel: m3m_1, Label: assistance: don't know
# Nama Variabel: m3m_2, Label: assistance: don't know
# Nama Variabel: m3m_3, Label: assistance: don't know
# Nama Variabel: m3m_4, Label: assistance: don't know
# Nama Variabel: m3m_5, Label: assistance: don't know
# Nama Variabel: m3m_6, Label: assistance: don't know
# Nama Variabel: m3n_1, Label: assistance: no one
# Nama Variabel: m3n_2, Label: assistance: no one
# Nama Variabel: m3n_3, Label: assistance: no one
# Nama Variabel: m3n_4, Label: assistance: no one
# Nama Variabel: m3n_5, Label: assistance: no one
# Nama Variabel: m3n_6, Label: assistance: no one
# ---------------------------------

# %%
print("\n--- Mencari Variabel Pemeriksaan Nifas Ibu ---")
kata_kunci_1 = 'postnatal'

for var, label in meta_anak.column_names_to_labels.items():
    if kata_kunci_1 in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Pemeriksaan Nifas Ibu ---
# Nama Variabel: m70, Label: baby postnatal check within 2 months
# Nama Variabel: m71, Label: how long after delivery postnatal check took place
# Nama Variabel: m72, Label: who performed postnatal checkup
# Nama Variabel: s429, Label: child received postnatal check by health professional or tba
# Nama Variabel: s429a, Label: timing of first postnatal check
# Nama Variabel: s431, Label: person who did first postnatal check
# Nama Variabel: s432, Label: place of first postnatal check
# ---------------------------------

# %%
# --- KODE DETEKTIF: Cari kata kunci "checkup" ---
print("\n--- Mencari Variabel Pemeriksaan Ibu (checkup) ---")
kata_kunci = 'checkup'

for var, label in meta_ibu.column_names_to_labels.items():
    # Kita cari di variabel 'm' (maternity)
    if var.startswith('m') and kata_kunci in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Pemeriksaan Ibu (checkup) ---
# Nama Variabel: m51a_1, Label: na-respondent checkup after deliver timing
# Nama Variabel: m51a_2, Label: na-respondent checkup after deliver timing
# Nama Variabel: m51a_3, Label: na-respondent checkup after deliver timing
# Nama Variabel: m51a_4, Label: na-respondent checkup after deliver timing
# Nama Variabel: m51a_5, Label: na-respondent checkup after deliver timing
# Nama Variabel: m51a_6, Label: na-respondent checkup after deliver timing
# Nama Variabel: m72_1, Label: who performed postnatal checkup
# Nama Variabel: m72_2, Label: who performed postnatal checkup
# Nama Variabel: m72_3, Label: who performed postnatal checkup
# Nama Variabel: m72_4, Label: who performed postnatal checkup
# Nama Variabel: m72_5, Label: who performed postnatal checkup
# Nama Variabel: m72_6, Label: who performed postnatal checkup
# ---------------------------------

# %%
# Cari variabel Asuransi
# --- KODE DETEKTIF: Cari variabel Asuransi dengan kata kunci baru ---
print("\n--- Mencari Variabel Asuransi (Pencarian Lanjutan) ---")

kata_kunci_list = [ 'jaminan', 'bpjs', 'insurance', 'asuransi'] # Kita coba beberapa kata kunci

for var, label in meta_ibu.column_names_to_labels.items():
    for kata_kunci in kata_kunci_list:
        if kata_kunci in label.lower():
            print(f"Nama Variabel: {var}, Label: {label}")
            break # Hentikan jika sudah ketemu agar tidak duplikat

print("---------------------------------")
# Out:
# --- Mencari Variabel Asuransi (Pencarian Lanjutan) ---
# Nama Variabel: v481, Label: na-covered by health insurance
# Nama Variabel: v481a, Label: na-health insurance type: mutual/community organization
# Nama Variabel: v481b, Label: na-health insurance type: provided by employer
# Nama Variabel: v481c, Label: na-health insurance type: social security
# Nama Variabel: v481d, Label: na-health insurance type: private/commercial purchased
# Nama Variabel: v481e, Label: na-health insurance type: cs
# Nama Variabel: v481f, Label: na-health insurance type: cs
# Nama Variabel: v481g, Label: na-health insurance type: cs
# Nama Variabel: v481h, Label: na-health insurance type: cs
# Nama Variabel: v481x, Label: na-health insurance type: other
# ---------------------------------

# %% [markdown]
# ### 3. Extracting

# %% [markdown]
# #### 3.1 Define Required Variables

# %%
print("Defining Required Variables")
print("="*70)

# Mother-level variables
ibu_vars_needed = [
    'caseid',           # Unique case identifier
    'v001',             # Cluster number
    'v002',             # Household number
    'v024',             # Region/Province
    'v025',             # Type of residence (1=Urban, 2=Rural)
    'v106',             # Highest education level
    'v201',             # Total children ever born (v201)
    'v212',             # Age of respondent
    'm14_1',            # Number of ANC visits for last birth
    'm15_1',            # Place of delivery (codes 20+ = health facility)
    'v481',             # Health insurance coverage (1=Yes)
    'v208',             # Births in last five years
    'm70_1',            # Baby postnatal check within 2 months
    'm71_1',            # Time after delivery postnatal check took place
    'v005',             # Weighted
] + [f'm3{c}_1' for c in 'abcdef']

# Child-level variables
anak_vars_needed = [
    'caseid',           # Links to mother
    'v024',             # Region/Province
    'm18',              # Size of child at birth (1-3=Normal/Large, 4-5=Small)
    'h2',               # BCG vaccination (1=Yes)
    'h4',               # DPT1 vaccination (1=Yes)
    'h6',               # Polio1 vaccination (1=Yes)
    'h8',               # Measles vaccination (1=Yes)
    'v008',             # Interview Date (to calculate age)
    'b3',               # Date of birth of child (to calculate age)
    's429',             # Postnatal check from health professional / TBA
    's429a',            # Timing of first postnatal check
    'v005',             # Weighted
]

# Birth history variables
lahir_vars_needed = [
    'caseid',           # Links to mother
    'v024',             # Region/Province
    'b11',               # Preceding birth interval
    'bord'              # birth order
]

print(f"Mother variables needed: {len(ibu_vars_needed)}")
print(f"Child variables needed: {len(anak_vars_needed)}")
print(f"Birth history variables needed: {len(lahir_vars_needed)}")
# Out:
# Defining Required Variables
# ======================================================================
# Mother variables needed: 21
# Child variables needed: 12
# Birth history variables needed: 4

# %% [markdown]
# #### 3.2 Check Data Availability & Quality

# %%
# ============================================================================
# VALIDATE DATASET AVAILABILITY
# ============================================================================
print("Validating Variable Availability")
print("-"*70)

def check_missing_variables(df, var_list, dataset_name):
    """Check if required variables exist in dataset"""
    missing = [v for v in var_list if v not in df.columns]
    if missing:
        print(f"\nWARNING - {dataset_name}:")
        print(f"   Missing {len(missing)} variables: {missing[:10]}")  # Show first 10
        if len(missing) > 10:
            print(f"   ... and {len(missing)-10} more")
        return False
    else:
        print(f"✓ {dataset_name}: All {len(var_list)} variables found")
        return True

# Validate each dataset
ibu_valid = check_missing_variables(df_ibu, ibu_vars_needed, "Mother Dataset")
anak_valid = check_missing_variables(df_anak, anak_vars_needed, "Child Dataset")
lahir_valid = check_missing_variables(df_lahir, lahir_vars_needed, "Birth Dataset")

if not all([ibu_valid, anak_valid, lahir_valid]):
    print("\nSome variables are missing. Please check your dataset!")
# Out:
# Validating Variable Availability
# ----------------------------------------------------------------------
# ✓ Mother Dataset: All 21 variables found
# ✓ Child Dataset: All 12 variables found
# ✓ Birth Dataset: All 4 variables found

# %%
# ============================================================================
# SELECT AND COPY VARIABLES
# ============================================================================
print("Selecting Required Variables")
print("="*70)

df_ibu_clean = df_ibu[ibu_vars_needed].copy()
df_anak_clean = df_anak[anak_vars_needed].copy()
df_lahir_clean = df_lahir[lahir_vars_needed].copy()

print(f"✓ Mother data: {df_ibu_clean.shape[0]:,} rows, {df_ibu_clean.shape[1]} columns")
print(f"✓ Child data: {df_anak_clean.shape[0]:,} rows, {df_anak_clean.shape[1]} columns")
print(f"✓ Birth data: {df_lahir_clean.shape[0]:,} rows, {df_lahir_clean.shape[1]} columns")
# Out:
# Selecting Required Variables
# ======================================================================
# ✓ Mother data: 32,895 rows, 21 columns
# ✓ Child data: 18,645 rows, 12 columns
# ✓ Birth data: 84,726 rows, 4 columns

# %%
# ============================================================================
# DATA CLEANING
# ============================================================================
print("Data Quality Checks & Cleaning")
print("="*70)

def handle_dhs_special_codes(df, var, missing_codes=[98, 99], method='nan'):
    """
    Handle DHS special codes (Don't Know, Missing, Not Applicable)

    Parameters:
    - df: DataFrame
    - var: Variable name
    - missing_codes: List of codes to treat as missing
    - method: 'nan' or 'zero'
    """
    if var in df.columns:
        original_missing = df[var].isna().sum()
        df[var] = df[var].replace(missing_codes, np.nan)
        new_missing = df[var].isna().sum()
        if new_missing > original_missing:
            print(f"  • {var}: Cleaned {new_missing - original_missing:,} special codes → NaN")
    return df

# Clean Mother data
print("\nCleaning Mother Dataset:")
# Corrected calls for handle_dhs_special_codes
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'm14_1', missing_codes=[97, 98, 99])  # ANC visits
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'm15_1', missing_codes=[97, 98, 99])  # Delivery Places
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'v212', missing_codes=[98, 99])  # Age
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'v106', missing_codes=[8, 9]) # Education
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'v481', missing_codes=[8, 9]) # Insurance
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'b11_01', missing_codes=[98, 99]) # Birth weight
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'm70_1', [8,9]) # Postnatal Check
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'm71_1', [998, 999]) # Time after delivery

# Clean Child data
print("\nCleaning Child Dataset:")
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'm18', missing_codes=[8, 9, 98, 99])  # Birth size
# Assuming immunization variables h2, h4, h6, h8 also need cleaning for 8, 9
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h2', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h4', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h6', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h8', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 's429a', [8,9,98,99,998,999])


required_cols = ['v008', 'b3']
missing_cols = [c for c in required_cols if c not in df_anak_clean.columns]
if missing_cols:
    raise ValueError(f"Missing required columns for age calculation: {missing_cols}")

# Hitung umur dalam bulan
df_anak_clean['age_months'] = df_anak_clean['v008'] - df_anak_clean['b3']

# Bersihkan nilai-nilai tidak valid
df_anak_clean.loc[df_anak_clean['age_months'] < 0, 'age_months'] = None  # impossible
df_anak_clean.loc[df_anak_clean['age_months'] > 200, 'age_months'] = None  # upper sanity bound

print("=== AGE MONTHS CHECK ===")
print(df_anak_clean['age_months'].describe())
print("Invalid ages:", df_anak_clean['age_months'].isna().sum())

# Clean Birth data
print("\nCleaning Birth Dataset:")
df_lahir_clean = handle_dhs_special_codes(df_lahir_clean, 'b11', missing_codes=[98, 99])  # Birth interval
# Out:
# Data Quality Checks & Cleaning
# ======================================================================
#
# Cleaning Mother Dataset:
#   • m14_1: Cleaned 174 special codes → NaN
#   • m15_1: Cleaned 50 special codes → NaN
#   • v106: Cleaned 3 special codes → NaN
#   • m70_1: Cleaned 97 special codes → NaN
#   • m71_1: Cleaned 53 special codes → NaN
#
# Cleaning Child Dataset:
#   • m18: Cleaned 1,151 special codes → NaN
#   • h2: Cleaned 181 special codes → NaN
#   • h4: Cleaned 182 special codes → NaN
#   • h6: Cleaned 302 special codes → NaN
#   • h8: Cleaned 302 special codes → NaN
#   • s429a: Cleaned 41 special codes → NaN
# === AGE MONTHS CHECK ===
# count    18645.000000
# mean        29.328345
# std         17.392878
# min          0.000000
# 25%         14.000000
# 50%         29.000000
# 75%         45.000000
# max         59.000000
# Name: age_months, dtype: float64
# Invalid ages: 0
#
# Cleaning Birth Dataset:
#   • b11: Cleaned 269 special codes → NaN

# %%
# ============================================================================
# FILTER TO APPROPRIATE SAMPLE
# ============================================================================
print("="*70)
print("Sample Selection")
print("="*70)

print(f"Original sample: {len(df_ibu_clean):,} mothers")

# m14_1 is only asked for most recent birth in last 5 years
df_ibu_analysis = df_ibu_clean[df_ibu_clean['v208'] > 0].copy()
print(f"Analysis sample: {len(df_ibu_analysis):,} mothers with recent births")
print(f"Filtered out: {len(df_ibu_clean) - len(df_ibu_analysis):,} mothers without recent births")

df_anak_analysis = df_anak_clean[df_anak_clean['age_months'].between(0, 23)].copy()
print(f"Analysis child sample: {len(df_anak_analysis):,}")
print(f"Filtered out: {len(df_anak_clean) - len(df_anak_analysis):,}")
# Out:
# ======================================================================
# Sample Selection
# ======================================================================
# Original sample: 32,895 mothers
# Analysis sample: 15,334 mothers with recent births
# Filtered out: 17,561 mothers without recent births
# Analysis child sample: 7,508
# Filtered out: 11,137

# %%
# Show missing data summary
print("\nMissing Data Summary:")
print("-" * 50)
key_vars = ['m14_1', 'm15_1', 'v212', 'v481', 'm18', 'v220']
for var in key_vars:
    for df, name in [(df_ibu_clean, 'ibu'), (df_anak_clean, 'anak'), (df_lahir_clean, 'lahir')]:
        if var in df.columns:
            missing_pct = (df[var].isna().sum() / len(df)) * 100
            print(f"  {name}.{var}: {missing_pct:.1f}% missing")
# Out:
# Missing Data Summary:
# --------------------------------------------------
#   ibu.m14_1: 53.9% missing
#   ibu.m15_1: 53.5% missing
#   ibu.v212: 7.5% missing
#   ibu.v481: 100.0% missing
#   anak.m18: 6.2% missing

# %% [markdown]
# #### 3.3 Feature Engineering

# %%
# ============================================================================
# FEATURE ENGINEERING
# ============================================================================
print("Feature Engineering")
print("-"*70)

# -----------------------------------------------------------------------------
# A. MATERNAL HEALTH SERVICE INDICATORS
# -----------------------------------------------------------------------------
print("\nA. Creating Maternal Health Service Indicators:")

# Ensure `df_ibu_analysis` is used as the base for feature engineering
df_ibu_analysis = df_ibu_analysis[df_ibu_analysis['m14_1'].notna()].copy()

# 1. ANC 4+ visits (m14_1 >= 4)
df_ibu_analysis['anc4_pct'] = (df_ibu_analysis['m14_1'] >= 4).astype(int)
print(f"4+ ANC visits: {df_ibu_analysis['anc4_pct'].mean()*100:.1f}%")

# 2. Facility delivery (m15_1: 20-36 = health facilities)
df_ibu_analysis['facility_delivery_pct'] = (
    ((df_ibu_analysis['m15_1'] >= 21) & (df_ibu_analysis['m15_1'] <= 27)) |
    ((df_ibu_analysis['m15_1'] >= 31) & (df_ibu_analysis['m15_1'] <= 37))
).astype(int)
print(f"Facility delivery: {df_ibu_analysis['facility_delivery_pct'].mean()*100:.1f}%")

# 3. Skilled Birth Attendant
# m3a_1 = doctor, m3b_1 = nurse/midwife, m3c_1 = auxiliary midwife
sba_cols = [col for col in df_ibu_analysis.columns if col.startswith('m3') and col.endswith('_1')]
excluded_tba = ['m3f_1'] # Not Skilled
sba_cols_filtered = [c for c in sba_cols if c not in excluded_tba]

df_ibu_analysis['sba_pct'] = df_ibu_analysis[sba_cols_filtered].eq(1).any(axis=1).astype(int)
print(f"Skilled Birth Attendant: {df_ibu_analysis['sba_pct'].mean()*100:.1f}%")

# Subset anak usia 0–23 bulan
df_pnc = df_anak_clean[df_anak_clean['age_months'] <= 23].copy()

# 4. Any PNC by health professional / TBA
df_pnc['pnc_any_flag'] = df_pnc['s429'].isin([1]).astype(int)
print(f"Any PNC (age<=23mo): {df_pnc['pnc_any_flag'].mean()*100:.1f}%")

# 5. PNC within 48h (0,1,2 = immediate / <24h / 24–47h)
df_ibu_analysis['pnc48h_flag'] = df_ibu_analysis['m71_1'].isin([201, 202]).astype(int)
print(f"PNC within 2 days (age<=23mo): {df_ibu_analysis['pnc48h_flag'].mean()*100:.1f}%")

# 6. Parity
df_ibu_analysis.rename(columns={'v201': 'parity'}, inplace=True)

# -----------------------------------------------------------------------------
# B. SOCIO-DEMOGRAPHIC INDICATORS
# -----------------------------------------------------------------------------
print("\nB. Creating Socio-Demographic Indicators:")

df_ibu_analysis['insured_pct'] = (df_ibu_analysis['v481'] == 1).astype(int)
print(f"Health insurance: {df_ibu_analysis['insured_pct'].mean()*100:.1f}%")

df_ibu_analysis['urban_share_pct'] = (df_ibu_analysis['v025'] == 1).astype(int)
print(f"Urban residence: {df_ibu_analysis['urban_share_pct'].mean()*100:.1f}%")

df_ibu_analysis['low_education_pct'] = (df_ibu_analysis['v106'] <= 1).astype(int)
print(f"Low education (\u2264Primary): {df_ibu_analysis['low_education_pct'].mean()*100:.1f}%")

# -----------------------------------------------------------------------------
# C. RISK FACTORS
# -----------------------------------------------------------------------------
print("\nC. Creating Risk Factor Indicators:")

df_ibu_analysis['maternal_age_risky_pct'] = (
    (df_ibu_analysis['v212'] < 20) | (df_ibu_analysis['v212'] >= 35)
).astype(int)
print(f"Risky maternal age: {df_ibu_analysis['maternal_age_risky_pct'].mean()*100:.1f}%")

# Birth interval (from birth recode)
mask_multibirth = df_lahir_clean['bord'] > 1

df_lahir_clean['short_interval_flag'] = np.nan
df_lahir_clean.loc[mask_multibirth, 'short_interval_flag'] = (
    df_lahir_clean.loc[mask_multibirth, 'b11'] < 24
).astype(int)

print(f"Short birth interval (<24mo): {df_lahir_clean.loc[mask_multibirth, 'short_interval_flag'].mean()*100:.1f}%")

# Child variables
df_anak_analysis['small_birth_size_pct'] = (
    df_anak_analysis['m18'].isin([4, 5])  # 4=small, 5=very small
).astype(int)
print(f"Small birth size: {df_anak_analysis['small_birth_size_pct'].mean()*100:.1f}%")

valid_yes = [1, 2, 3]
mask_12_23 = df_anak_clean['age_months'].between(12, 23)

# Default: NaN (anak di luar 12–23 bulan tidak ikut denominator)
# Full immunization (h2=BCG, h4=DPT1, h6=Polio3, h8=Measles)
# Code 1/2/3 = Yes (card/recall/marked), 0 = No, 8 = Don't know
df_anak_clean['full_immun_binary'] = np.nan

df_anak_clean.loc[mask_12_23, 'full_immun_binary'] = (
    df_anak_clean.loc[mask_12_23, 'h2'].isin(valid_yes) &
    df_anak_clean.loc[mask_12_23, 'h4'].isin(valid_yes) &
    df_anak_clean.loc[mask_12_23, 'h6'].isin(valid_yes) &
    df_anak_clean.loc[mask_12_23, 'h8'].isin(valid_yes)
).astype(int)

print(
    "Full immunization (12–23 mo, all 4 vaccines): "
    f"{df_anak_clean.loc[mask_12_23, 'full_immun_binary'].mean()*100:.1f}%"
)
# Out:
# Feature Engineering
# ----------------------------------------------------------------------
#
# A. Creating Maternal Health Service Indicators:
# 4+ ANC visits: 78.4%
# Facility delivery: 38.3%
# Skilled Birth Attendant: 71.4%
# Any PNC (age<=23mo): 82.8%
# PNC within 2 days (age<=23mo): 20.7%
#
# B. Creating Socio-Demographic Indicators:
# Health insurance: 0.0%
# Urban residence: 38.7%
# Low education (≤Primary): 43.1%
#
# C. Creating Risk Factor Indicators:
# Risky maternal age: 36.5%
# Short birth interval (<24mo): 24.6%
# Small birth size: 15.0%
# Full immunization (12–23 mo, all 4 vaccines): 64.1%

# %% [markdown]
# #### 3.4 Merging

# %%
# Mother-level indicators

df_ibu_2007 = df_ibu_analysis.copy()

# ANC 4+
df_ibu_2007['anc4_flag'] = (df_ibu_2007['m14_1'] >= 4).astype(int)

# Facility delivery (20–89 = health facility)
df_ibu_2007['facility_flag'] = df_ibu_2007['m15_1'].between(20, 89).astype(int)

# SBA (pakai loop semua m3*_1 kecuali TBA, misal m3f_1)
sba_cols = [c for c in df_ibu_2007.columns if c.startswith('m3') and c.endswith('_1')]
excluded_tba = ['m3f_1']  # sesuaikan kalau TBA di kode lain
sba_cols = [c for c in sba_cols if c not in excluded_tba]
df_ibu_2007['sba_flag'] = df_ibu_2007[sba_cols].eq(1).any(axis=1).astype(int)

# Insurance
df_ibu_2007['insured_flag'] = (df_ibu_2007['v481'] == 1).astype(int)

# Urban
df_ibu_2007['urban_flag'] = (df_ibu_2007['v025'] == 1).astype(int)

# Low education (≤ primary)
df_ibu_2007['lowedu_flag'] = df_ibu_2007['v106'].isin([0, 1]).astype(int)  # 0 = no edu, 1 = primary

# Risky maternal age (<20 or >=35)
df_ibu_2007['risky_age_flag'] = ((df_ibu_2007['v212'] < 20) | (df_ibu_2007['v212'] >= 35)).astype(int)

# Parity (bisa dipakai langsung mean)
df_ibu_2007['parity'] = df_ibu_2007['parity']

df_ibu_2007['weight'] = df_ibu_2007['v005'] / 1_000_000

# %%
df_birth = df_lahir_clean.copy()

# Hanya kelahiran dengan older sibling yang punya interval
df_birth_valid = df_birth[df_birth['bord'] > 1].copy()

df_birth_valid['short_interval_flag'] = (df_birth_valid['b11'] < 24).astype(int)

# Aggregate ke ibu: jika ada short interval pada salah satu kelahiran → ibu berisiko
df_interval_mother = (
    df_birth_valid
    .groupby('caseid')['short_interval_flag']
    .max()
    .reset_index()
)

# Merge ke ibu
df_ibu_2007 = df_ibu_2007.merge(df_interval_mother, on='caseid', how='left')

# Ibu yang hanya punya 1 anak (tidak punya interval) = NA → bukan risiko, assign 0
df_ibu_2007['short_interval_flag'] = df_ibu_2007['short_interval_flag'].fillna(0).astype(int)

# %%
# Child-level indicators

df_child_2007 = df_anak_analysis.copy()

# LBW proxy: small_birth_size (m18: 4/5 = small/very small, 1–3 = average/large)
df_child_2007['small_birth_flag'] = df_child_2007['m18'].isin([4, 5]).astype(int)

# Immunization flags (anggap 1 = received, 2/3 juga treated as received kalau ada)
for col in ['h2', 'h4', 'h6', 'h8']:
    df_child_2007[col + '_flag'] = df_child_2007[col].isin([1, 2, 3]).astype(int)

# Full immunization (semua 4 vaksin diterima)
imm_cols = ['h2_flag', 'h4_flag', 'h6_flag', 'h8_flag']
df_child_2007['full_immun_flag'] = df_child_2007[imm_cols].all(axis=1).astype(int)

# %%
# PNC indicators

# Subset hanya ibu yang punya data PNC (m70_1 atau m71_1)
df_pnc = df_ibu_clean[df_ibu_clean['m70_1'].notna() | df_ibu_clean['m71_1'].notna()].copy()

# Any PNC
df_pnc['pnc_any_flag'] = (df_pnc['m70_1'] == 1).astype(int)

# PNC ≤48h (pakai coding numeric)
df_pnc['pnc48h_flag'] = df_pnc['m71_1'].isin([201, 202]).astype(int)

# %%
group_cols = ['v024']  # v024 = province

# Aggregate Mother
prov_mother = (
    df_ibu_2007
    .groupby(group_cols)
    .agg(
        anc4_pct=('anc4_flag', 'mean'),
        facility_delivery_pct=('facility_flag', 'mean'),
        sba_pct=('sba_flag', 'mean'),
        insured_pct=('insured_flag', 'mean'),
        urban_share_pct=('urban_flag', 'mean'),
        low_education_pct=('lowedu_flag', 'mean'),
        risky_maternal_age_pct=('risky_age_flag', 'mean'),
        birth_interval_short_pct=('short_interval_flag', 'mean'),
        avg_parity=('parity', 'mean')
    )
    .reset_index()
)

# Aggregate Child
prov_child = (
    df_child_2007
    .groupby(group_cols)
    .agg(
        lbw_pct=('small_birth_flag', 'mean'),
        full_immun_pct=('full_immun_flag', 'mean')
    )
    .reset_index()
)

# Aggregate PNC
prov_pnc = (
    df_pnc
    .groupby(group_cols)
    .agg(
        pnc_any_pct=('pnc_any_flag', 'mean'),
        pnc48h_pct=('pnc48h_flag', 'mean')
    )
    .reset_index()
)

# %%
df_2007 = prov_mother.merge(prov_child, on=['v024'], how='left')
df_2007 = df_2007.merge(prov_pnc, on=['v024'], how='left')

df_2007.rename(columns={'v024': 'region'}, inplace=True)

# %%
prov_map = {
    11: "Aceh",
    12: "Sumatera Utara",
    13: "Sumatera Barat",
    14: "Riau",
    15: "Jambi",
    16: "Sumatera Selatan",
    17: "Bengkulu",
    18: "Lampung",
    19: "Kepulauan Bangka Belitung",
    21: "Kepulauan Riau",
    31: "DKI Jakarta",
    32: "Jawa Barat",
    33: "Jawa Tengah",
    34: "DI Yogyakarta",
    35: "Jawa Timur",
    36: "Banten",
    51: "Bali",
    52: "Nusa Tenggara Barat",
    53: "Nusa Tenggara Timur",
    61: "Kalimantan Barat",
    62: "Kalimantan Tengah",
    63: "Kalimantan Selatan",
    64: "Kalimantan Timur",
    65: "Kalimantan Utara",
    71: "Sulawesi Utara",
    72: "Sulawesi Tengah",
    73: "Sulawesi Selatan",
    74: "Sulawesi Tenggara",
    75: "Gorontalo",
    76: "Sulawesi Barat",
    81: "Maluku",
    82: "Maluku Utara",
    91: "Papua",
    92: "Papua Barat",
    94: "Papua Barat"
}

df_2007['province'] = df_2007['region'].map(prov_map)

# cek apakah ada kode yang belum ter-map
unmapped = df_2007[df_2007['province'].isna()]['region'].unique()
print("Unmapped province codes:", unmapped)
# Out:
# Unmapped province codes: []

# %%
cols = df_2007.columns.tolist()

new_order = ['region', 'province'] + [c for c in cols if c not in ['region', 'province']]

# Reorder dataframe
df_2007 = df_2007[new_order]

# %%
# ============================================================================
# FINAL DATA QUALITY SUMMARY
# ============================================================================
print("="*80)
print("FINAL DATA QUALITY SUMMARY – PROVINCIAL INDICATORS")
print("="*80)

# 1. Basic dataset info
print(f"\nTotal observations        : {len(df_2007):,}")
print(f"Unique provinces          : {df_2007['region'].nunique()}")
print(f"Total indicators          : {df_2007.shape[1] - 2} (excluding region/year)")

# 2. Missing check
missing = df_2007.isna().sum()
if missing.sum() == 0:
    print("\nMissing values            : 0")
else:
    print("\nMissing values:")
    print(missing[missing > 0])

# 3. Indicator ranges (auto-detect pct columns)
print("\nIndicator Ranges by Province:")
print("-" * 80)

indicator_cols = [
    col for col in df_2007.columns
    if col not in ['region', 'province'] # Exclude 'province' column from numerical checks
]

for col in indicator_cols:
    col_min = df_2007[col].min()
    col_max = df_2007[col].max()

    # convert to percentage if value seems 0-1
    if col_max <= 1.5:
        print(f"{col:30s}: {col_min*100:6.1f}% – {col_max*100:6.1f}%")
    else:
        print(f"{col:30s}: {col_min:6.2f} – {col_max:6.2f}")

# 4. Quick descriptive stats
print("\nQuick Descriptive Stats:")
print("-" * 80)
print(df_2007[indicator_cols].describe().T[['mean','std','min','max']])

print("\nData preview:")
print(df_2007.head())

print("\nPROCESSING COMPLETE ✔")
print("="*80)
# Out:
# ================================================================================
# FINAL DATA QUALITY SUMMARY – PROVINCIAL INDICATORS
# ================================================================================
#
# Total observations        : 33
# Unique provinces          : 33
# Total indicators          : 13 (excluding region/year)
#
# Missing values            : 0
#
# Indicator Ranges by Province:
# --------------------------------------------------------------------------------
# anc4_pct                      :   50.6% –   97.7%
# facility_delivery_pct         :    9.0% –   92.1%
# sba_pct                       :   39.6% –   96.8%
# insured_pct                   :    0.0% –    0.0%
# urban_share_pct               :   13.2% –  100.0%
# low_education_pct             :   18.1% –   62.1%
# risky_maternal_age_pct        :   18.9% –   51.4%
# birth_interval_short_pct      :    8.6% –   46.0%
# avg_parity                    :   1.94 –   3.39
# lbw_pct                       :    5.7% –   26.3%
# full_immun_pct                :   23.0% –   75.3%
# pnc_any_pct                   :   49.4% –   99.7%
# pnc48h_pct                    :    6.4% –   61.6%
#
# Quick Descriptive Stats:
# --------------------------------------------------------------------------------
#                               mean       std       min       max
# anc4_pct                  0.777701  0.115450  0.506211  0.977333
# facility_delivery_pct     0.404179  0.230753  0.090047  0.920892
# sba_pct                   0.708101  0.155743  0.395652  0.968000
# insured_pct               0.000000  0.000000  0.000000  0.000000
# urban_share_pct           0.368056  0.192558  0.131687  1.000000
# low_education_pct         0.433235  0.103062  0.180556  0.621399
# risky_maternal_age_pct    0.370627  0.084150  0.188889  0.514218
# birth_interval_short_pct  0.227751  0.093581  0.086111  0.460371
# avg_parity                2.552976  0.368422  1.941667  3.393478
# lbw_pct                   0.151650  0.057811  0.056604  0.263415
# full_immun_pct            0.494599  0.131114  0.230303  0.753012
# pnc_any_pct               0.846054  0.106961  0.493865  0.997222
# pnc48h_pct                0.210900  0.109716  0.063963  0.616368
#
# Data preview:
#    region        province  anc4_pct  facility_delivery_pct   sba_pct  \
# 0      11            Aceh  0.708758               0.236253  0.751527
# 1      12  Sumatera Utara  0.662732               0.328836  0.849916
# 2      13  Sumatera Barat  0.855670               0.612371  0.791753
# 3      14            Riau  0.821721               0.465164  0.858607
# 4      15           Jambi  0.769231               0.261538  0.694872
#
#    insured_pct  urban_share_pct  low_education_pct  risky_maternal_age_pct  \
# 0          0.0         0.177189           0.427699                0.374745
# 1          0.0         0.411467           0.323777                0.236088
# 2          0.0         0.274227           0.381443                0.292784
# 3          0.0         0.440574           0.344262                0.305328
# 4          0.0         0.253846           0.512821                0.443590
#
#    birth_interval_short_pct  avg_parity   lbw_pct  full_immun_pct  \
# 0                  0.248473    2.637475  0.110672        0.296443
# 1                  0.460371    3.187184  0.080110        0.361878
# 2                  0.257732    2.896907  0.183521        0.543071
# 3                  0.241803    2.493852  0.128514        0.389558
# 4                  0.120513    2.317949  0.118919        0.416216
#
#    pnc_any_pct  pnc48h_pct
# 0     0.804878    0.418699
# 1     0.705980    0.327243
# 2     0.792181    0.146091
# 3     0.806911    0.410569
# 4     0.864450    0.616368
#
# PROCESSING COMPLETE ✔
# ================================================================================

# %%
print("Saving Results")

df_2007.to_csv('dhs_regional_2007.csv', index=False)
print("Files saved successfully!")
# Out:
# Saving Results
# Files saved successfully!

# %% [markdown]
# ## D. Data DHS (2002)

# %% [markdown]
# ### 1. Load Data

# %%
print("Preprocessing Data SDKI 2002...")

ibu_dta_path = 'IDIR42FL.DTA' # File ibu
anak_dta_path = 'IDKR42FL.DTA' # File anak
lahir_dta_path = 'IDBR42FL.DTA' # File Kelahiran
rt_dta_path = 'IDHR42FL.DTA' # File House Hold

print("\nMembaca file data Stata (.DTA)...")

try:
    df_ibu, meta_ibu = pyreadstat.read_dta(ibu_dta_path)
    df_anak, meta_anak = pyreadstat.read_dta(anak_dta_path)
    df_lahir, meta_lahir = pyreadstat.read_dta(lahir_dta_path)
    df_rt, meta_rt = pyreadstat.read_dta(rt_dta_path)
    print("File Ibu, Rumah Tangga, Kelahiran, & Anak (.DTA) berhasil dibaca.")
except Exception as e:
    print(f"Error saat membaca file: {e}")
    exit()

df_ibu.columns = df_ibu.columns.str.lower()
df_anak.columns = df_anak.columns.str.lower()
df_lahir.columns = df_lahir.columns.str.lower()
df_rt.columns = df_rt.columns.str.lower()

print("\n--- Check Dataset ---")
print("Jumlah kolom di df_ibu:", len(df_ibu.columns))
print("Jumlah kolom di df_anak:", len(df_anak.columns))
print("Jumlah kolom di df_lahir:", len(df_lahir.columns))
print("Jumlah kolom di df_rt:", len(df_rt.columns))
print("-------------------------------------------------------")
# Out:
# Preprocessing Data SDKI 2002...
#
# Membaca file data Stata (.DTA)...
# File Ibu, Rumah Tangga, Kelahiran, & Anak (.DTA) berhasil dibaca.
#
# --- Check Dataset ---
# Jumlah kolom di df_ibu: 3833
# Jumlah kolom di df_anak: 974
# Jumlah kolom di df_lahir: 974
# Jumlah kolom di df_rt: 1758
# -------------------------------------------------------

# %% [markdown]
# ### 2. Check Variable Name

# %%
print("\n--- Mencari Variabel Pendidikan ---")
kata_kunci = 'educa'

# Mencari di dalam nama kolom dan label deskripsinya
for var, label in meta_ibu.column_names_to_labels.items():
    if kata_kunci in var.lower() or kata_kunci in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Pendidikan ---
# Nama Variabel: v106, Label: highest educational level
# Nama Variabel: v107, Label: highest year of education
# Nama Variabel: v133, Label: education in single years
# Nama Variabel: v149, Label: educational attainment
# Nama Variabel: awfacte, Label: all woman factor - educational
# Nama Variabel: v701, Label: partner's education level
# Nama Variabel: v702, Label: highest year of education
# Nama Variabel: v715, Label: husbands education-single yrs
# Nama Variabel: v729, Label: partner's educational attainm.
# Nama Variabel: awfacte1, Label: all women factor for education used in the report
# Nama Variabel: s108a, Label: highest educational level
# ---------------------------------

# %%
print("\n--- Mencari Variabel Ukuran Bayi Lahir ---")
# meta_anak berisi "kamus" untuk df_anak
kata_kunci_1 = 'size'  # Kata kunci: ukuran
kata_kunci_2 = 'weight' # Kata kunci: berat

# Mencari di dalam nama kolom dan label deskripsinya
for var, label in meta_anak.column_names_to_labels.items():
    if kata_kunci_1 in label.lower() or kata_kunci_2 in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Ukuran Bayi Lahir ---
# Nama Variabel: v005, Label: sample weight
# Nama Variabel: v419, Label: entries in height/weight table
# Nama Variabel: v437, Label: respondent's weight (kilos--na
# Nama Variabel: m18, Label: size of child at birth
# Nama Variabel: m19, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19a, Label: weight at birth recall
# Nama Variabel: hw2, Label: weight in kilograms (1 dec.-na
# ---------------------------------

# %%
print("\n--- Mencari Variabel Penolong Persalinan ---")
kata_kunci_1 = 'delivery'
kata_kunci_2 = 'birth'

for var, label in meta_ibu.column_names_to_labels.items():
    if kata_kunci_1 in label.lower() or kata_kunci_2 in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Penolong Persalinan ---
# Nama Variabel: v009, Label: respondent's month of birth
# Nama Variabel: v010, Label: respondent's year of birth
# Nama Variabel: v011, Label: date of birth (cmc)
# Nama Variabel: bidx_01, Label: birth column number
# Nama Variabel: bidx_02, Label: birth column number
# Nama Variabel: bidx_03, Label: birth column number
# Nama Variabel: bidx_04, Label: birth column number
# Nama Variabel: bidx_05, Label: birth column number
# Nama Variabel: bidx_06, Label: birth column number
# Nama Variabel: bidx_07, Label: birth column number
# Nama Variabel: bidx_08, Label: birth column number
# Nama Variabel: bidx_09, Label: birth column number
# Nama Variabel: bidx_10, Label: birth column number
# Nama Variabel: bidx_11, Label: birth column number
# Nama Variabel: bidx_12, Label: birth column number
# Nama Variabel: bidx_13, Label: birth column number
# Nama Variabel: bidx_14, Label: birth column number
# Nama Variabel: bidx_15, Label: birth column number
# Nama Variabel: bidx_16, Label: birth column number
# Nama Variabel: bidx_17, Label: birth column number
# Nama Variabel: bidx_18, Label: birth column number
# Nama Variabel: bidx_19, Label: birth column number
# Nama Variabel: bidx_20, Label: birth column number
# Nama Variabel: bord_01, Label: birth order number
# Nama Variabel: bord_02, Label: birth order number
# Nama Variabel: bord_03, Label: birth order number
# Nama Variabel: bord_04, Label: birth order number
# Nama Variabel: bord_05, Label: birth order number
# Nama Variabel: bord_06, Label: birth order number
# Nama Variabel: bord_07, Label: birth order number
# Nama Variabel: bord_08, Label: birth order number
# Nama Variabel: bord_09, Label: birth order number
# Nama Variabel: bord_10, Label: birth order number
# Nama Variabel: bord_11, Label: birth order number
# Nama Variabel: bord_12, Label: birth order number
# Nama Variabel: bord_13, Label: birth order number
# Nama Variabel: bord_14, Label: birth order number
# Nama Variabel: bord_15, Label: birth order number
# Nama Variabel: bord_16, Label: birth order number
# Nama Variabel: bord_17, Label: birth order number
# Nama Variabel: bord_18, Label: birth order number
# Nama Variabel: bord_19, Label: birth order number
# Nama Variabel: bord_20, Label: birth order number
# Nama Variabel: b1_01, Label: month of birth
# Nama Variabel: b1_02, Label: month of birth
# Nama Variabel: b1_03, Label: month of birth
# Nama Variabel: b1_04, Label: month of birth
# Nama Variabel: b1_05, Label: month of birth
# Nama Variabel: b1_06, Label: month of birth
# Nama Variabel: b1_07, Label: month of birth
# Nama Variabel: b1_08, Label: month of birth
# Nama Variabel: b1_09, Label: month of birth
# Nama Variabel: b1_10, Label: month of birth
# Nama Variabel: b1_11, Label: month of birth
# Nama Variabel: b1_12, Label: month of birth
# Nama Variabel: b1_13, Label: month of birth
# Nama Variabel: b1_14, Label: month of birth
# Nama Variabel: b1_15, Label: month of birth
# Nama Variabel: b1_16, Label: month of birth
# Nama Variabel: b1_17, Label: month of birth
# Nama Variabel: b1_18, Label: month of birth
# Nama Variabel: b1_19, Label: month of birth
# Nama Variabel: b1_20, Label: month of birth
# Nama Variabel: b2_01, Label: year of birth
# Nama Variabel: b2_02, Label: year of birth
# Nama Variabel: b2_03, Label: year of birth
# Nama Variabel: b2_04, Label: year of birth
# Nama Variabel: b2_05, Label: year of birth
# Nama Variabel: b2_06, Label: year of birth
# Nama Variabel: b2_07, Label: year of birth
# Nama Variabel: b2_08, Label: year of birth
# Nama Variabel: b2_09, Label: year of birth
# Nama Variabel: b2_10, Label: year of birth
# Nama Variabel: b2_11, Label: year of birth
# Nama Variabel: b2_12, Label: year of birth
# Nama Variabel: b2_13, Label: year of birth
# Nama Variabel: b2_14, Label: year of birth
# Nama Variabel: b2_15, Label: year of birth
# Nama Variabel: b2_16, Label: year of birth
# Nama Variabel: b2_17, Label: year of birth
# Nama Variabel: b2_18, Label: year of birth
# Nama Variabel: b2_19, Label: year of birth
# Nama Variabel: b2_20, Label: year of birth
# Nama Variabel: b3_01, Label: date of birth (cmc)
# Nama Variabel: b3_02, Label: date of birth (cmc)
# Nama Variabel: b3_03, Label: date of birth (cmc)
# Nama Variabel: b3_04, Label: date of birth (cmc)
# Nama Variabel: b3_05, Label: date of birth (cmc)
# Nama Variabel: b3_06, Label: date of birth (cmc)
# Nama Variabel: b3_07, Label: date of birth (cmc)
# Nama Variabel: b3_08, Label: date of birth (cmc)
# Nama Variabel: b3_09, Label: date of birth (cmc)
# Nama Variabel: b3_10, Label: date of birth (cmc)
# Nama Variabel: b3_11, Label: date of birth (cmc)
# Nama Variabel: b3_12, Label: date of birth (cmc)
# Nama Variabel: b3_13, Label: date of birth (cmc)
# Nama Variabel: b3_14, Label: date of birth (cmc)
# Nama Variabel: b3_15, Label: date of birth (cmc)
# Nama Variabel: b3_16, Label: date of birth (cmc)
# Nama Variabel: b3_17, Label: date of birth (cmc)
# Nama Variabel: b3_18, Label: date of birth (cmc)
# Nama Variabel: b3_19, Label: date of birth (cmc)
# Nama Variabel: b3_20, Label: date of birth (cmc)
# Nama Variabel: b11_01, Label: preceding birth interval
# Nama Variabel: b11_02, Label: preceding birth interval
# Nama Variabel: b11_03, Label: preceding birth interval
# Nama Variabel: b11_04, Label: preceding birth interval
# Nama Variabel: b11_05, Label: preceding birth interval
# Nama Variabel: b11_06, Label: preceding birth interval
# Nama Variabel: b11_07, Label: preceding birth interval
# Nama Variabel: b11_08, Label: preceding birth interval
# Nama Variabel: b11_09, Label: preceding birth interval
# Nama Variabel: b11_10, Label: preceding birth interval
# Nama Variabel: b11_11, Label: preceding birth interval
# Nama Variabel: b11_12, Label: preceding birth interval
# Nama Variabel: b11_13, Label: preceding birth interval
# Nama Variabel: b11_14, Label: preceding birth interval
# Nama Variabel: b11_15, Label: preceding birth interval
# Nama Variabel: b11_16, Label: preceding birth interval
# Nama Variabel: b11_17, Label: preceding birth interval
# Nama Variabel: b11_18, Label: preceding birth interval
# Nama Variabel: b11_19, Label: preceding birth interval
# Nama Variabel: b11_20, Label: preceding birth interval
# Nama Variabel: b12_01, Label: succeeding birth interval
# Nama Variabel: b12_02, Label: succeeding birth interval
# Nama Variabel: b12_03, Label: succeeding birth interval
# Nama Variabel: b12_04, Label: succeeding birth interval
# Nama Variabel: b12_05, Label: succeeding birth interval
# Nama Variabel: b12_06, Label: succeeding birth interval
# Nama Variabel: b12_07, Label: succeeding birth interval
# Nama Variabel: b12_08, Label: succeeding birth interval
# Nama Variabel: b12_09, Label: succeeding birth interval
# Nama Variabel: b12_10, Label: succeeding birth interval
# Nama Variabel: b12_11, Label: succeeding birth interval
# Nama Variabel: b12_12, Label: succeeding birth interval
# Nama Variabel: b12_13, Label: succeeding birth interval
# Nama Variabel: b12_14, Label: succeeding birth interval
# Nama Variabel: b12_15, Label: succeeding birth interval
# Nama Variabel: b12_16, Label: succeeding birth interval
# Nama Variabel: b12_17, Label: succeeding birth interval
# Nama Variabel: b12_18, Label: succeeding birth interval
# Nama Variabel: b12_19, Label: succeeding birth interval
# Nama Variabel: b12_20, Label: succeeding birth interval
# Nama Variabel: b15_01, Label: live birth between births
# Nama Variabel: b15_02, Label: live birth between births
# Nama Variabel: b15_03, Label: live birth between births
# Nama Variabel: b15_04, Label: live birth between births
# Nama Variabel: b15_05, Label: live birth between births
# Nama Variabel: b15_06, Label: live birth between births
# Nama Variabel: b15_07, Label: live birth between births
# Nama Variabel: b15_08, Label: live birth between births
# Nama Variabel: b15_09, Label: live birth between births
# Nama Variabel: b15_10, Label: live birth between births
# Nama Variabel: b15_11, Label: live birth between births
# Nama Variabel: b15_12, Label: live birth between births
# Nama Variabel: b15_13, Label: live birth between births
# Nama Variabel: b15_14, Label: live birth between births
# Nama Variabel: b15_15, Label: live birth between births
# Nama Variabel: b15_16, Label: live birth between births
# Nama Variabel: b15_17, Label: live birth between births
# Nama Variabel: b15_18, Label: live birth between births
# Nama Variabel: b15_19, Label: live birth between births
# Nama Variabel: b15_20, Label: live birth between births
# Nama Variabel: v208, Label: births in last five years
# Nama Variabel: v209, Label: births in past year
# Nama Variabel: v210, Label: births in month of interview
# Nama Variabel: v211, Label: date of first birth (cmc)
# Nama Variabel: v212, Label: age of respondent at 1st birth
# Nama Variabel: v221, Label: marriage to first birth int.
# Nama Variabel: v222, Label: last birth to interview
# Nama Variabel: v224, Label: entries in birth history
# Nama Variabel: v237, Label: birth between last & interview
# Nama Variabel: v238, Label: births in last three years
# Nama Variabel: v3a00t, Label: source of fp for non-users: delivery post
# Nama Variabel: midx_1, Label: index to birth history
# Nama Variabel: midx_2, Label: index to birth history
# Nama Variabel: midx_3, Label: index to birth history
# Nama Variabel: midx_4, Label: index to birth history
# Nama Variabel: midx_5, Label: index to birth history
# Nama Variabel: midx_6, Label: index to birth history
# Nama Variabel: m1_1, Label: tetanus injections bef. birth
# Nama Variabel: m1_2, Label: tetanus injections bef. birth
# Nama Variabel: m1_3, Label: tetanus injections bef. birth
# Nama Variabel: m1_4, Label: tetanus injections bef. birth
# Nama Variabel: m1_5, Label: tetanus injections bef. birth
# Nama Variabel: m1_6, Label: tetanus injections bef. birth
# Nama Variabel: m2f_1, Label: prenatal: trained birth att-na
# Nama Variabel: m2f_2, Label: prenatal: trained birth att-na
# Nama Variabel: m2f_3, Label: prenatal: trained birth att-na
# Nama Variabel: m2f_4, Label: prenatal: trained birth att-na
# Nama Variabel: m2f_5, Label: prenatal: trained birth att-na
# Nama Variabel: m2f_6, Label: prenatal: trained birth att-na
# Nama Variabel: m2g_1, Label: prenatal: trad.birth attendant
# Nama Variabel: m2g_2, Label: prenatal: trad.birth attendant
# Nama Variabel: m2g_3, Label: prenatal: trad.birth attendant
# Nama Variabel: m2g_4, Label: prenatal: trad.birth attendant
# Nama Variabel: m2g_5, Label: prenatal: trad.birth attendant
# Nama Variabel: m2g_6, Label: prenatal: trad.birth attendant
# Nama Variabel: m3f_1, Label: assistance: trained birth a-na
# Nama Variabel: m3f_2, Label: assistance: trained birth a-na
# Nama Variabel: m3f_3, Label: assistance: trained birth a-na
# Nama Variabel: m3f_4, Label: assistance: trained birth a-na
# Nama Variabel: m3f_5, Label: assistance: trained birth a-na
# Nama Variabel: m3f_6, Label: assistance: trained birth a-na
# Nama Variabel: m3g_1, Label: assistance: trad.birth attend.
# Nama Variabel: m3g_2, Label: assistance: trad.birth attend.
# Nama Variabel: m3g_3, Label: assistance: trad.birth attend.
# Nama Variabel: m3g_4, Label: assistance: trad.birth attend.
# Nama Variabel: m3g_5, Label: assistance: trad.birth attend.
# Nama Variabel: m3g_6, Label: assistance: trad.birth attend.
# Nama Variabel: m15_1, Label: place of delivery
# Nama Variabel: m15_2, Label: place of delivery
# Nama Variabel: m15_3, Label: place of delivery
# Nama Variabel: m15_4, Label: place of delivery
# Nama Variabel: m15_5, Label: place of delivery
# Nama Variabel: m15_6, Label: place of delivery
# Nama Variabel: m17_1, Label: delivery by caesarian section
# Nama Variabel: m17_2, Label: delivery by caesarian section
# Nama Variabel: m17_3, Label: delivery by caesarian section
# Nama Variabel: m17_4, Label: delivery by caesarian section
# Nama Variabel: m17_5, Label: delivery by caesarian section
# Nama Variabel: m17_6, Label: delivery by caesarian section
# Nama Variabel: m18_1, Label: size of child at birth
# Nama Variabel: m18_2, Label: size of child at birth
# Nama Variabel: m18_3, Label: size of child at birth
# Nama Variabel: m18_4, Label: size of child at birth
# Nama Variabel: m18_5, Label: size of child at birth
# Nama Variabel: m18_6, Label: size of child at birth
# Nama Variabel: m19_1, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19_2, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19_3, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19_4, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19_5, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19_6, Label: birth weight (kilos - 3 dec.)
# Nama Variabel: m19a_1, Label: weight at birth recall
# Nama Variabel: m19a_2, Label: weight at birth recall
# Nama Variabel: m19a_3, Label: weight at birth recall
# Nama Variabel: m19a_4, Label: weight at birth recall
# Nama Variabel: m19a_5, Label: weight at birth recall
# Nama Variabel: m19a_6, Label: weight at birth recall
# Nama Variabel: m50_1, Label: after birth, health professional checked health
# Nama Variabel: m50_2, Label: after birth, health professional checked health
# Nama Variabel: m50_3, Label: after birth, health professional checked health
# Nama Variabel: m50_4, Label: after birth, health professional checked health
# Nama Variabel: m50_5, Label: after birth, health professional checked health
# Nama Variabel: m50_6, Label: after birth, health professional checked health
# Nama Variabel: m52_1, Label: after birth, health professional checked health
# Nama Variabel: m52_2, Label: after birth, health professional checked health
# Nama Variabel: m52_3, Label: after birth, health professional checked health
# Nama Variabel: m52_4, Label: after birth, health professional checked health
# Nama Variabel: m52_5, Label: after birth, health professional checked health
# Nama Variabel: m52_6, Label: after birth, health professional checked health
# Nama Variabel: m54_1, Label: received vitamin a dose in first 2 months after delivery
# Nama Variabel: m54_2, Label: received vitamin a dose in first 2 months after delivery
# Nama Variabel: m54_3, Label: received vitamin a dose in first 2 months after delivery
# Nama Variabel: m54_4, Label: received vitamin a dose in first 2 months after delivery
# Nama Variabel: m54_5, Label: received vitamin a dose in first 2 months after delivery
# Nama Variabel: m54_6, Label: received vitamin a dose in first 2 months after delivery
# Nama Variabel: v401, Label: last birth ceasarean section
# Nama Variabel: v468, Label: columns used for last birth only variables
# Nama Variabel: hidx_1, Label: index to birth history
# Nama Variabel: hidx_2, Label: index to birth history
# Nama Variabel: hidx_3, Label: index to birth history
# Nama Variabel: hidx_4, Label: index to birth history
# Nama Variabel: hidx_5, Label: index to birth history
# Nama Variabel: hidx_6, Label: index to birth history
# Nama Variabel: h12u_1, Label: diarrhea: delivery post
# Nama Variabel: h12u_2, Label: diarrhea: delivery post
# Nama Variabel: h12u_3, Label: diarrhea: delivery post
# Nama Variabel: h12u_4, Label: diarrhea: delivery post
# Nama Variabel: h12u_5, Label: diarrhea: delivery post
# Nama Variabel: h12u_6, Label: diarrhea: delivery post
# Nama Variabel: h32u_1, Label: fever/cough: delivery post
# Nama Variabel: h32u_2, Label: fever/cough: delivery post
# Nama Variabel: h32u_3, Label: fever/cough: delivery post
# Nama Variabel: h32u_4, Label: fever/cough: delivery post
# Nama Variabel: h32u_5, Label: fever/cough: delivery post
# Nama Variabel: h32u_6, Label: fever/cough: delivery post
# Nama Variabel: hwidx_1, Label: index to birth history     -na
# Nama Variabel: hwidx_2, Label: index to birth history     -na
# Nama Variabel: hwidx_3, Label: index to birth history     -na
# Nama Variabel: hwidx_4, Label: index to birth history     -na
# Nama Variabel: hwidx_5, Label: index to birth history     -na
# Nama Variabel: hwidx_6, Label: index to birth history     -na
# Nama Variabel: hw16_1, Label: day of birth of child      -na
# Nama Variabel: hw16_2, Label: day of birth of child      -na
# Nama Variabel: hw16_3, Label: day of birth of child      -na
# Nama Variabel: hw16_4, Label: day of birth of child      -na
# Nama Variabel: hw16_5, Label: day of birth of child      -na
# Nama Variabel: hw16_6, Label: day of birth of child      -na
# Nama Variabel: v616, Label: time for future birth
# Nama Variabel: v633c, Label: reason for not having sex: recent birth
# Nama Variabel: v762at, Label: source for condoms: delivery post
# Nama Variabel: v774b, Label: aids transmit. during delivery
# Nama Variabel: mm4_01, Label: cmc date of birth of sibling
# Nama Variabel: mm4_02, Label: cmc date of birth of sibling
# Nama Variabel: mm4_03, Label: cmc date of birth of sibling
# Nama Variabel: mm4_04, Label: cmc date of birth of sibling
# Nama Variabel: mm4_05, Label: cmc date of birth of sibling
# Nama Variabel: mm4_06, Label: cmc date of birth of sibling
# Nama Variabel: mm4_07, Label: cmc date of birth of sibling
# Nama Variabel: mm4_08, Label: cmc date of birth of sibling
# Nama Variabel: mm4_09, Label: cmc date of birth of sibling
# Nama Variabel: mm4_10, Label: cmc date of birth of sibling
# Nama Variabel: mm4_11, Label: cmc date of birth of sibling
# Nama Variabel: mm4_12, Label: cmc date of birth of sibling
# Nama Variabel: mm4_13, Label: cmc date of birth of sibling
# Nama Variabel: mm4_14, Label: cmc date of birth of sibling
# Nama Variabel: mm4_15, Label: cmc date of birth of sibling
# Nama Variabel: mm4_16, Label: cmc date of birth of sibling
# Nama Variabel: mm4_17, Label: cmc date of birth of sibling
# Nama Variabel: mm4_18, Label: cmc date of birth of sibling
# Nama Variabel: mm4_19, Label: cmc date of birth of sibling
# Nama Variabel: mm4_20, Label: cmc date of birth of sibling
# Nama Variabel: mm12_01, Label: time between delivery & dea-na
# Nama Variabel: mm12_02, Label: time between delivery & dea-na
# Nama Variabel: mm12_03, Label: time between delivery & dea-na
# Nama Variabel: mm12_04, Label: time between delivery & dea-na
# Nama Variabel: mm12_05, Label: time between delivery & dea-na
# Nama Variabel: mm12_06, Label: time between delivery & dea-na
# Nama Variabel: mm12_07, Label: time between delivery & dea-na
# Nama Variabel: mm12_08, Label: time between delivery & dea-na
# Nama Variabel: mm12_09, Label: time between delivery & dea-na
# Nama Variabel: mm12_10, Label: time between delivery & dea-na
# Nama Variabel: mm12_11, Label: time between delivery & dea-na
# Nama Variabel: mm12_12, Label: time between delivery & dea-na
# Nama Variabel: mm12_13, Label: time between delivery & dea-na
# Nama Variabel: mm12_14, Label: time between delivery & dea-na
# Nama Variabel: mm12_15, Label: time between delivery & dea-na
# Nama Variabel: mm12_16, Label: time between delivery & dea-na
# Nama Variabel: mm12_17, Label: time between delivery & dea-na
# Nama Variabel: mm12_18, Label: time between delivery & dea-na
# Nama Variabel: mm12_19, Label: time between delivery & dea-na
# Nama Variabel: mm12_20, Label: time between delivery & dea-na
# Nama Variabel: mmc2, Label: preceeding births before resp.
# Nama Variabel: s242a, Label: problems during labor and delivery: water breaks too early
# Nama Variabel: s242b, Label: problems during labor and delivery: exscessive bleeding
# Nama Variabel: s242c, Label: problems during labor and delivery: fever
# Nama Variabel: s242d, Label: problems during labor and delivery: long labor
# Nama Variabel: s242e, Label: problems during labor and delivery: faint
# Nama Variabel: s242f, Label: problems during labor and delivery: convulsions
# Nama Variabel: s242g, Label: problems during labor and delivery: placenta does not come out
# Nama Variabel: s242h, Label: problems during labor and delivery: stillbirth
# Nama Variabel: s242x, Label: problems during labor and delivery: other
# Nama Variabel: s242z, Label: problems during labor and delivery: don't know
# Nama Variabel: s243a, Label: what to do for problem during delivery: nothing
# Nama Variabel: s243b, Label: what to do for problem during delivery: rest
# Nama Variabel: s243c, Label: what to do for problem during delivery: take medication
# Nama Variabel: s243d, Label: what to do for problem during delivery: take herbs
# Nama Variabel: s243e, Label: what to do for problem during delivery: see tba
# Nama Variabel: s243f, Label: what to do for problem during delivery: see midwife
# Nama Variabel: s243g, Label: what to do for problem during delivery: see doctor
# Nama Variabel: s243h, Label: what to do for problem during delivery: go to health facility
# Nama Variabel: s243x, Label: what to do for problem during delivery: other
# Nama Variabel: s243z, Label: what to do for problem during delivery: don't know
# Nama Variabel: s244a, Label: problems after birth: excessive bleeding
# Nama Variabel: s244b, Label: problems after birth: fainting
# Nama Variabel: s244c, Label: problems after birth: convulsions
# Nama Variabel: s244d, Label: problems after birth: fever
# Nama Variabel: s244e, Label: problems after birth: foul-smelling discharge
# Nama Variabel: s244f, Label: problems after birth: sore breast
# Nama Variabel: s244g, Label: problems after birth: sadness/depression
# Nama Variabel: s244x, Label: problems after birth: other
# Nama Variabel: s244z, Label: problems after birth: don't know
# Nama Variabel: s245a, Label: what to do for problem after birth: nothing
# Nama Variabel: s245b, Label: what to do for problem after birth: rest
# Nama Variabel: s245c, Label: what to do for problem after birth: take medication
# Nama Variabel: s245d, Label: what to do for problem after birth: take herbs
# Nama Variabel: s245e, Label: what to do for problem after birth: see tba
# Nama Variabel: s245f, Label: what to do for problem after birth: see midwife
# Nama Variabel: s245g, Label: what to do for problem after birth: see doctor
# Nama Variabel: s245h, Label: what to do for problem after birth: go to health facility
# Nama Variabel: s245x, Label: what to do for problem after birth: other
# Nama Variabel: s245z, Label: what to do for problem after birth: don't know
# Nama Variabel: idx94_1, Label: index to birth history
# Nama Variabel: idx94_2, Label: index to birth history
# Nama Variabel: idx94_3, Label: index to birth history
# Nama Variabel: idx94_4, Label: index to birth history
# Nama Variabel: idx94_5, Label: index to birth history
# Nama Variabel: idx94_6, Label: index to birth history
# Nama Variabel: s406a_1, Label: has birth been registered
# Nama Variabel: s406a_2, Label: has birth been registered
# Nama Variabel: s406a_3, Label: has birth been registered
# Nama Variabel: s406a_4, Label: has birth been registered
# Nama Variabel: s406a_5, Label: has birth been registered
# Nama Variabel: s406a_6, Label: has birth been registered
# Nama Variabel: s410ac_1, Label: antenatal care visits between month 7 and delivery
# Nama Variabel: s410ac_2, Label: antenatal care visits between month 7 and delivery
# Nama Variabel: s410ac_3, Label: antenatal care visits between month 7 and delivery
# Nama Variabel: s410ac_4, Label: antenatal care visits between month 7 and delivery
# Nama Variabel: s410ac_5, Label: antenatal care visits between month 7 and delivery
# Nama Variabel: s410ac_6, Label: antenatal care visits between month 7 and delivery
# Nama Variabel: s414aa_1, Label: during pregnancy discuss place of delivery
# Nama Variabel: s414aa_2, Label: during pregnancy discuss place of delivery
# Nama Variabel: s414aa_3, Label: during pregnancy discuss place of delivery
# Nama Variabel: s414aa_4, Label: during pregnancy discuss place of delivery
# Nama Variabel: s414aa_5, Label: during pregnancy discuss place of delivery
# Nama Variabel: s414aa_6, Label: during pregnancy discuss place of delivery
# Nama Variabel: s414ac_1, Label: during pregnancy discuss delivery assistant
# Nama Variabel: s414ac_2, Label: during pregnancy discuss delivery assistant
# Nama Variabel: s414ac_3, Label: during pregnancy discuss delivery assistant
# Nama Variabel: s414ac_4, Label: during pregnancy discuss delivery assistant
# Nama Variabel: s414ac_5, Label: during pregnancy discuss delivery assistant
# Nama Variabel: s414ac_6, Label: during pregnancy discuss delivery assistant
# Nama Variabel: s425a_1, Label: health professional/birth attendat checked baby's health
# Nama Variabel: s425a_2, Label: health professional/birth attendat checked baby's health
# Nama Variabel: s425a_3, Label: health professional/birth attendat checked baby's health
# Nama Variabel: s425a_4, Label: health professional/birth attendat checked baby's health
# Nama Variabel: s425a_5, Label: health professional/birth attendat checked baby's health
# Nama Variabel: s425a_6, Label: health professional/birth attendat checked baby's health
# Nama Variabel: s427a_1, Label: was husband present at time of delivery
# Nama Variabel: s427a_2, Label: was husband present at time of delivery
# Nama Variabel: s427a_3, Label: was husband present at time of delivery
# Nama Variabel: s427a_4, Label: was husband present at time of delivery
# Nama Variabel: s427a_5, Label: was husband present at time of delivery
# Nama Variabel: s427a_6, Label: was husband present at time of delivery
# Nama Variabel: s428aa_1, Label: delivery complication: prolonged labor
# Nama Variabel: s428aa_2, Label: delivery complication: prolonged labor
# Nama Variabel: s428aa_3, Label: delivery complication: prolonged labor
# Nama Variabel: s428aa_4, Label: delivery complication: prolonged labor
# Nama Variabel: s428aa_5, Label: delivery complication: prolonged labor
# Nama Variabel: s428aa_6, Label: delivery complication: prolonged labor
# Nama Variabel: s428ab_1, Label: delivery complications: vaginal bleeding
# Nama Variabel: s428ab_2, Label: delivery complications: vaginal bleeding
# Nama Variabel: s428ab_3, Label: delivery complications: vaginal bleeding
# Nama Variabel: s428ab_4, Label: delivery complications: vaginal bleeding
# Nama Variabel: s428ab_5, Label: delivery complications: vaginal bleeding
# Nama Variabel: s428ab_6, Label: delivery complications: vaginal bleeding
# Nama Variabel: s428ac_1, Label: delivery complications: high fever, foul smell vaginal discharge
# Nama Variabel: s428ac_2, Label: delivery complications: high fever, foul smell vaginal discharge
# Nama Variabel: s428ac_3, Label: delivery complications: high fever, foul smell vaginal discharge
# Nama Variabel: s428ac_4, Label: delivery complications: high fever, foul smell vaginal discharge
# Nama Variabel: s428ac_5, Label: delivery complications: high fever, foul smell vaginal discharge
# Nama Variabel: s428ac_6, Label: delivery complications: high fever, foul smell vaginal discharge
# Nama Variabel: s428ad_1, Label: delivery complications: convulsions, loss of consciousness
# Nama Variabel: s428ad_2, Label: delivery complications: convulsions, loss of consciousness
# Nama Variabel: s428ad_3, Label: delivery complications: convulsions, loss of consciousness
# Nama Variabel: s428ad_4, Label: delivery complications: convulsions, loss of consciousness
# Nama Variabel: s428ad_5, Label: delivery complications: convulsions, loss of consciousness
# Nama Variabel: s428ad_6, Label: delivery complications: convulsions, loss of consciousness
# Nama Variabel: s428ae_1, Label: delivery complications: other
# Nama Variabel: s428ae_2, Label: delivery complications: other
# Nama Variabel: s428ae_3, Label: delivery complications: other
# Nama Variabel: s428ae_4, Label: delivery complications: other
# Nama Variabel: s428ae_5, Label: delivery complications: other
# Nama Variabel: s428ae_6, Label: delivery complications: other
# Nama Variabel: idx95_1, Label: index to birth history
# Nama Variabel: idx95_2, Label: index to birth history
# Nama Variabel: idx95_3, Label: index to birth history
# Nama Variabel: idx95_4, Label: index to birth history
# Nama Variabel: idx95_5, Label: index to birth history
# Nama Variabel: idx95_6, Label: index to birth history
# ---------------------------------

# %%
print("\n--- Mencari Semua Variabel Bantuan Persalinan ---")
kata_kunci = 'assistance'

for var, label in meta_ibu.column_names_to_labels.items():
    # Kita hanya cari di variabel yang berawalan 'm3' untuk menjaga relevansi
    if var.startswith('m3') and kata_kunci in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Semua Variabel Bantuan Persalinan ---
# Nama Variabel: m3a_1, Label: assistance: doctor
# Nama Variabel: m3a_2, Label: assistance: doctor
# Nama Variabel: m3a_3, Label: assistance: doctor
# Nama Variabel: m3a_4, Label: assistance: doctor
# Nama Variabel: m3a_5, Label: assistance: doctor
# Nama Variabel: m3a_6, Label: assistance: doctor
# Nama Variabel: m3b_1, Label: assistance: nurse/midwife
# Nama Variabel: m3b_2, Label: assistance: nurse/midwife
# Nama Variabel: m3b_3, Label: assistance: nurse/midwife
# Nama Variabel: m3b_4, Label: assistance: nurse/midwife
# Nama Variabel: m3b_5, Label: assistance: nurse/midwife
# Nama Variabel: m3b_6, Label: assistance: nurse/midwife
# Nama Variabel: m3c_1, Label: assistance: auxiliary midwi-na
# Nama Variabel: m3c_2, Label: assistance: auxiliary midwi-na
# Nama Variabel: m3c_3, Label: assistance: auxiliary midwi-na
# Nama Variabel: m3c_4, Label: assistance: auxiliary midwi-na
# Nama Variabel: m3c_5, Label: assistance: auxiliary midwi-na
# Nama Variabel: m3c_6, Label: assistance: auxiliary midwi-na
# Nama Variabel: m3d_1, Label: assistance: obstetrician/gynecologist
# Nama Variabel: m3d_2, Label: assistance: obstetrician/gynecologist
# Nama Variabel: m3d_3, Label: assistance: obstetrician/gynecologist
# Nama Variabel: m3d_4, Label: assistance: obstetrician/gynecologist
# Nama Variabel: m3d_5, Label: assistance: obstetrician/gynecologist
# Nama Variabel: m3d_6, Label: assistance: obstetrician/gynecologist
# Nama Variabel: m3e_1, Label: assistance: village midwife
# Nama Variabel: m3e_2, Label: assistance: village midwife
# Nama Variabel: m3e_3, Label: assistance: village midwife
# Nama Variabel: m3e_4, Label: assistance: village midwife
# Nama Variabel: m3e_5, Label: assistance: village midwife
# Nama Variabel: m3e_6, Label: assistance: village midwife
# Nama Variabel: m3f_1, Label: assistance: trained birth a-na
# Nama Variabel: m3f_2, Label: assistance: trained birth a-na
# Nama Variabel: m3f_3, Label: assistance: trained birth a-na
# Nama Variabel: m3f_4, Label: assistance: trained birth a-na
# Nama Variabel: m3f_5, Label: assistance: trained birth a-na
# Nama Variabel: m3f_6, Label: assistance: trained birth a-na
# Nama Variabel: m3g_1, Label: assistance: trad.birth attend.
# Nama Variabel: m3g_2, Label: assistance: trad.birth attend.
# Nama Variabel: m3g_3, Label: assistance: trad.birth attend.
# Nama Variabel: m3g_4, Label: assistance: trad.birth attend.
# Nama Variabel: m3g_5, Label: assistance: trad.birth attend.
# Nama Variabel: m3g_6, Label: assistance: trad.birth attend.
# Nama Variabel: m3h_1, Label: assistance: relative, friend
# Nama Variabel: m3h_2, Label: assistance: relative, friend
# Nama Variabel: m3h_3, Label: assistance: relative, friend
# Nama Variabel: m3h_4, Label: assistance: relative, friend
# Nama Variabel: m3h_5, Label: assistance: relative, friend
# Nama Variabel: m3h_6, Label: assistance: relative, friend
# Nama Variabel: m3i_1, Label: assistance: cs other person-na
# Nama Variabel: m3i_2, Label: assistance: cs other person-na
# Nama Variabel: m3i_3, Label: assistance: cs other person-na
# Nama Variabel: m3i_4, Label: assistance: cs other person-na
# Nama Variabel: m3i_5, Label: assistance: cs other person-na
# Nama Variabel: m3i_6, Label: assistance: cs other person-na
# Nama Variabel: m3j_1, Label: assistance: cs other person-na
# Nama Variabel: m3j_2, Label: assistance: cs other person-na
# Nama Variabel: m3j_3, Label: assistance: cs other person-na
# Nama Variabel: m3j_4, Label: assistance: cs other person-na
# Nama Variabel: m3j_5, Label: assistance: cs other person-na
# Nama Variabel: m3j_6, Label: assistance: cs other person-na
# Nama Variabel: m3k_1, Label: assistance: other resp (uncod)
# Nama Variabel: m3k_2, Label: assistance: other resp (uncod)
# Nama Variabel: m3k_3, Label: assistance: other resp (uncod)
# Nama Variabel: m3k_4, Label: assistance: other resp (uncod)
# Nama Variabel: m3k_5, Label: assistance: other resp (uncod)
# Nama Variabel: m3k_6, Label: assistance: other resp (uncod)
# Nama Variabel: m3l_1, Label: assistance: cs other       -na
# Nama Variabel: m3l_2, Label: assistance: cs other       -na
# Nama Variabel: m3l_3, Label: assistance: cs other       -na
# Nama Variabel: m3l_4, Label: assistance: cs other       -na
# Nama Variabel: m3l_5, Label: assistance: cs other       -na
# Nama Variabel: m3l_6, Label: assistance: cs other       -na
# Nama Variabel: m3m_1, Label: assistance: cs other       -na
# Nama Variabel: m3m_2, Label: assistance: cs other       -na
# Nama Variabel: m3m_3, Label: assistance: cs other       -na
# Nama Variabel: m3m_4, Label: assistance: cs other       -na
# Nama Variabel: m3m_5, Label: assistance: cs other       -na
# Nama Variabel: m3m_6, Label: assistance: cs other       -na
# Nama Variabel: m3n_1, Label: assistance: no one
# Nama Variabel: m3n_2, Label: assistance: no one
# Nama Variabel: m3n_3, Label: assistance: no one
# Nama Variabel: m3n_4, Label: assistance: no one
# Nama Variabel: m3n_5, Label: assistance: no one
# Nama Variabel: m3n_6, Label: assistance: no one
# ---------------------------------

# %%
print("\n--- Mencari Variabel Pemeriksaan Nifas Ibu ---")
kata_kunci_1 = 'postnatal'

for var, label in meta_ibu.column_names_to_labels.items():
    if kata_kunci_1 in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Pemeriksaan Nifas Ibu ---
# ---------------------------------

# %%
print("\n--- Mencari Variabel Pemeriksaan Ibu (checkup) ---")
kata_kunci = 'checkup'

for var, label in meta_ibu.column_names_to_labels.items():
    # Kita cari di variabel 'm' (maternity)
    if var.startswith('m') and kata_kunci in label.lower():
        print(f"Nama Variabel: {var}, Label: {label}")

print("---------------------------------")
# Out:
# --- Mencari Variabel Pemeriksaan Ibu (checkup) ---
# Nama Variabel: m51_1, Label: checkup after deliver timing
# Nama Variabel: m51_2, Label: checkup after deliver timing
# Nama Variabel: m51_3, Label: checkup after deliver timing
# Nama Variabel: m51_4, Label: checkup after deliver timing
# Nama Variabel: m51_5, Label: checkup after deliver timing
# Nama Variabel: m51_6, Label: checkup after deliver timing
# Nama Variabel: m53_1, Label: place for checkup
# Nama Variabel: m53_2, Label: place for checkup
# Nama Variabel: m53_3, Label: place for checkup
# Nama Variabel: m53_4, Label: place for checkup
# Nama Variabel: m53_5, Label: place for checkup
# Nama Variabel: m53_6, Label: place for checkup
# ---------------------------------

# %%
# Cari variabel Asuransi
print("\n--- Mencari Variabel Asuransi (Pencarian Lanjutan) ---")

kata_kunci_list = [ 'jaminan', 'bpjs', 'insurance', 'asuransi'] # Kita coba beberapa kata kunci

for var, label in meta_rt.column_names_to_labels.items():
    for kata_kunci in kata_kunci_list:
        if kata_kunci in label.lower():
            print(f"Nama Variabel: {var}, Label: {label}")
            break # Hentikan jika sudah ketemu agar tidak duplikat

print("---------------------------------")
# Out:
# --- Mencari Variabel Asuransi (Pencarian Lanjutan) ---
# ---------------------------------

# %% [markdown]
# ### 3. Extracting

# %% [markdown]
# #### 3.1 Define Required Variables

# %%
print("Defining Required Variables")
print("="*70)

# Mother-level variables
ibu_vars_needed = [
    'caseid',           # Unique case identifier
    'v001',             # Cluster number
    'v002',             # Household number
    'v024',             # Region/Province
    'v025',             # Type of residence (1=Urban, 2=Rural)
    'v106',             # Highest education level
    'v201',             # Total children ever born (v201)
    'v212',             # Age of respondent
    'm14_1',            # Number of ANC visits for last birth
    'm15_1',            # Place of delivery (codes 20+ = health facility)
    'v208',             # Births in last five years
    'v005',             # Weighted
] + [f'm3{c}_1' for c in 'abcdef']

# Child-level variables
anak_vars_needed = [
    'caseid',           # Links to mother
    'v024',             # Region/Province
    'm18',              # Size of child at birth (1-3=Normal/Large, 4-5=Small)
    'h2',               # BCG vaccination (1=Yes)
    'h4',               # DPT1 vaccination (1=Yes)
    'h6',               # Polio1 vaccination (1=Yes)
    'h8',               # Measles vaccination (1=Yes)
    'v008',             # Interview Date (to calculate age)
    'b3',               # Date of birth of child (to calculate age)
    'v005'              # Weighted - Added to anak_vars_needed
]

# Birth history variables
lahir_vars_needed = [
    'caseid',           # Links to mother
    'v024',             # Region/Province
    'b11',               # Preceding birth interval
    'bord'              # birth order
]

print(f"Mother variables needed: {len(ibu_vars_needed)}")
print(f"Child variables needed: {len(anak_vars_needed)}")
print(f"Birth history variables needed: {len(lahir_vars_needed)}")
# Out:
# Defining Required Variables
# ======================================================================
# Mother variables needed: 18
# Child variables needed: 10
# Birth history variables needed: 4

# %% [markdown]
# #### 3.2 Check Data Availability & Quality

# %%
# ============================================================================
# VALIDATE DATASET AVAILABILITY
# ============================================================================
print("Validating Variable Availability")
print("-"*70)

def check_missing_variables(df, var_list, dataset_name):
    """Check if required variables exist in dataset"""
    missing = [v for v in var_list if v not in df.columns]
    if missing:
        print(f"\nWARNING - {dataset_name}:")
        print(f"   Missing {len(missing)} variables: {missing[:10]}")  # Show first 10
        if len(missing) > 10:
            print(f"   ... and {len(missing)-10} more")
        return False
    else:
        print(f"✓ {dataset_name}: All {len(var_list)} variables found")
        return True

# Validate each dataset
ibu_valid = check_missing_variables(df_ibu, ibu_vars_needed, "Mother Dataset")
anak_valid = check_missing_variables(df_anak, anak_vars_needed, "Child Dataset")
lahir_valid = check_missing_variables(df_lahir, lahir_vars_needed, "Birth Dataset")

if not all([ibu_valid, anak_valid, lahir_valid]):
    print("\nSome variables are missing. Please check your dataset!")
# Out:
# Validating Variable Availability
# ----------------------------------------------------------------------
# ✓ Mother Dataset: All 18 variables found
# ✓ Child Dataset: All 10 variables found
# ✓ Birth Dataset: All 4 variables found

# %%
# ============================================================================
# SELECT AND COPY VARIABLES
# ============================================================================
print("Selecting Required Variables")
print("="*70)

df_ibu_clean = df_ibu[ibu_vars_needed].copy()
df_anak_clean = df_anak[anak_vars_needed].copy()
df_lahir_clean = df_lahir[lahir_vars_needed].copy()

print(f"✓ Mother data: {df_ibu_clean.shape[0]:,} rows, {df_ibu_clean.shape[1]} columns")
print(f"✓ Child data: {df_anak_clean.shape[0]:,} rows, {df_anak_clean.shape[1]} columns")
print(f"✓ Birth data: {df_lahir_clean.shape[0]:,} rows, {df_lahir_clean.shape[1]} columns")
# Out:
# Selecting Required Variables
# ======================================================================
# ✓ Mother data: 29,483 rows, 18 columns
# ✓ Child data: 16,206 rows, 10 columns
# ✓ Birth data: 79,791 rows, 4 columns

# %%
# ============================================================================
# DATA CLEANING
# ============================================================================
print("Data Quality Checks & Cleaning")
print("="*70)

def handle_dhs_special_codes(df, var, missing_codes=[98, 99], method='nan'):
    """
    Handle DHS special codes (Don't Know, Missing, Not Applicable)

    Parameters:
    - df: DataFrame
    - var: Variable name
    - missing_codes: List of codes to treat as missing
    - method: 'nan' or 'zero'
    """
    if var in df.columns:
        original_missing = df[var].isna().sum()
        df[var] = df[var].replace(missing_codes, np.nan)
        new_missing = df[var].isna().sum()
        if new_missing > original_missing:
            print(f"  • {var}: Cleaned {new_missing - original_missing:,} special codes → NaN")
    return df

# Clean Mother data
print("\nCleaning Mother Dataset:")
# Corrected calls for handle_dhs_special_codes
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'm14_1', missing_codes=[97, 98, 99])  # ANC visits
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'm15_1', missing_codes=[97, 98, 99])  # Delivery Places
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'v212', missing_codes=[98, 99])  # Age
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'v106', missing_codes=[8, 9]) # Education
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'v481', missing_codes=[8, 9]) # Insurance
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'b11_01', missing_codes=[98, 99]) # Birth weight
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'm70_1', [8,9]) # Postnatal Check
df_ibu_clean = handle_dhs_special_codes(df_ibu_clean, 'm71_1', [998, 999]) # Time after delivery

# Clean Child data
print("\nCleaning Child Dataset:")
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'm18', missing_codes=[8, 9, 98, 99])  # Birth size
# Assuming immunization variables h2, h4, h6, h8 also need cleaning for 8, 9
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h2', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h4', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h6', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 'h8', missing_codes=[8, 9])
df_anak_clean = handle_dhs_special_codes(df_anak_clean, 's429a', [8,9,98,99,998,999])


required_cols = ['v008', 'b3']
missing_cols = [c for c in required_cols if c not in df_anak_clean.columns]
if missing_cols:
    raise ValueError(f"Missing required columns for age calculation: {missing_cols}")

# Hitung umur dalam bulan
df_anak_clean['age_months'] = df_anak_clean['v008'] - df_anak_clean['b3']

# Bersihkan nilai-nilai tidak valid
df_anak_clean.loc[df_anak_clean['age_months'] < 0, 'age_months'] = None  # impossible
df_anak_clean.loc[df_anak_clean['age_months'] > 200, 'age_months'] = None  # upper sanity bound

print("=== AGE MONTHS CHECK ===")
print(df_anak_clean['age_months'].describe())
print("Invalid ages:", df_anak_clean['age_months'].isna().sum())

# Clean Birth data
print("\nCleaning Birth Dataset:")
df_lahir_clean = handle_dhs_special_codes(df_lahir_clean, 'b11', missing_codes=[98, 99])  # Birth interval
# Out:
# Data Quality Checks & Cleaning
# ======================================================================
#
# Cleaning Mother Dataset:
#   • m14_1: Cleaned 161 special codes → NaN
#   • m15_1: Cleaned 46 special codes → NaN
#
# Cleaning Child Dataset:
#   • m18: Cleaned 865 special codes → NaN
#   • h2: Cleaned 95 special codes → NaN
#   • h4: Cleaned 80 special codes → NaN
#   • h6: Cleaned 122 special codes → NaN
#   • h8: Cleaned 122 special codes → NaN
# === AGE MONTHS CHECK ===
# count    16206.000000
# mean        29.017278
# std         17.067474
# min          0.000000
# 25%         14.000000
# 50%         29.000000
# 75%         43.000000
# max         59.000000
# Name: age_months, dtype: float64
# Invalid ages: 0
#
# Cleaning Birth Dataset:
#   • b11: Cleaned 186 special codes → NaN

# %%
# ============================================================================
# FILTER TO APPROPRIATE SAMPLE
# ============================================================================
print("="*70)
print("Sample Selection")
print("="*70)

print(f"Original sample: {len(df_ibu_clean):,} mothers")

# m14_1 is only asked for most recent birth in last 5 years
df_ibu_analysis = df_ibu_clean[df_ibu_clean['v208'] > 0].copy()
print(f"Analysis sample: {len(df_ibu_analysis):,} mothers with recent births")
print(f"Filtered out: {len(df_ibu_clean) - len(df_ibu_analysis):,} mothers without recent births")

df_anak_analysis = df_anak_clean[df_anak_clean['age_months'].between(0, 23)].copy()
print(f"Analysis child sample: {len(df_anak_analysis):,}")
print(f"Filtered out: {len(df_anak_clean) - len(df_anak_analysis):,}")
# Out:
# ======================================================================
# Sample Selection
# ======================================================================
# Original sample: 29,483 mothers
# Analysis sample: 13,349 mothers with recent births
# Filtered out: 16,134 mothers without recent births
# Analysis child sample: 6,451
# Filtered out: 9,755

# %%
# Show missing data summary
print("\nMissing Data Summary:")
print("-" * 50)
key_vars = ['m14_1', 'm15_1', 'v212', 'v481', 'm18', 'v220']
for var in key_vars:
    for df, name in [(df_ibu_clean, 'ibu'), (df_anak_clean, 'anak'), (df_lahir_clean, 'lahir')]:
        if var in df.columns:
            missing_pct = (df[var].isna().sum() / len(df)) * 100
            print(f"  {name}.{var}: {missing_pct:.1f}% missing")
# Out:
# Missing Data Summary:
# --------------------------------------------------
#   ibu.m14_1: 55.3% missing
#   ibu.m15_1: 54.9% missing
#   ibu.v212: 7.3% missing
#   anak.m18: 5.3% missing

# %% [markdown]
# #### 3.3 Feature Engineering

# %%
# ============================================================================
# FEATURE ENGINEERING
# ============================================================================
print("Feature Engineering")
print("-"*70)

# -----------------------------------------------------------------------------
# A. MATERNAL HEALTH SERVICE INDICATORS
# -----------------------------------------------------------------------------
print("\nA. Creating Maternal Health Service Indicators:")

# Ensure `df_ibu_analysis` is used as the base for feature engineering
df_ibu_analysis = df_ibu_analysis[df_ibu_analysis['m14_1'].notna()].copy()

# 1. ANC 4+ visits (m14_1 >= 4)
df_ibu_analysis['anc4_pct'] = (df_ibu_analysis['m14_1'] >= 4).astype(int)
print(f"4+ ANC visits: {df_ibu_analysis['anc4_pct'].mean()*100:.1f}%")

# 2. Facility delivery (m15_1: 20-36 = health facilities)
df_ibu_analysis['facility_delivery_pct'] = (
    ((df_ibu_analysis['m15_1'] >= 21) & (df_ibu_analysis['m15_1'] <= 27)) |
    ((df_ibu_analysis['m15_1'] >= 31) & (df_ibu_analysis['m15_1'] <= 37))
).astype(int)
print(f"Facility delivery: {df_ibu_analysis['facility_delivery_pct'].mean()*100:.1f}%")

# 3. Skilled Birth Attendant
# m3a_1 = doctor, m3b_1 = nurse/midwife, m3c_1 = auxiliary midwife
sba_cols = [col for col in df_ibu_analysis.columns if col.startswith('m3') and col.endswith('_1')]
excluded_tba = ['m3f_1'] # Not Skilled
sba_cols_filtered = [c for c in sba_cols if c not in excluded_tba]

df_ibu_analysis['sba_pct'] = df_ibu_analysis[sba_cols_filtered].eq(1).any(axis=1).astype(int)
print(f"Skilled Birth Attendant: {df_ibu_analysis['sba_pct'].mean()*100:.1f}%")

# 6. Parity
df_ibu_analysis.rename(columns={'v201': 'parity'}, inplace=True)

# -----------------------------------------------------------------------------
# B. SOCIO-DEMOGRAPHIC INDICATORS
# -----------------------------------------------------------------------------
print("\nB. Creating Socio-Demographic Indicators:")

df_ibu_analysis['urban_share_pct'] = (df_ibu_analysis['v025'] == 1).astype(int)
print(f"Urban residence: {df_ibu_analysis['urban_share_pct'].mean()*100:.1f}%")

df_ibu_analysis['low_education_pct'] = (df_ibu_analysis['v106'] <= 1).astype(int)
print(f"Low education (\u2264Primary): {df_ibu_analysis['low_education_pct'].mean()*100:.1f}%")

# -----------------------------------------------------------------------------
# C. RISK FACTORS
# -----------------------------------------------------------------------------
print("\nC. Creating Risk Factor Indicators:")

df_ibu_analysis['maternal_age_risky_pct'] = (
    (df_ibu_analysis['v212'] < 20) | (df_ibu_analysis['v212'] >= 35)
).astype(int)
print(f"Risky maternal age: {df_ibu_analysis['maternal_age_risky_pct'].mean()*100:.1f}%")

# Birth interval (from birth recode)
mask_multibirth = df_lahir_clean['bord'] > 1

df_lahir_clean['short_interval_flag'] = np.nan
df_lahir_clean.loc[mask_multibirth, 'short_interval_flag'] = (
    df_lahir_clean.loc[mask_multibirth, 'b11'] < 24
).astype(int)

print(f"Short birth interval (<24mo): {df_lahir_clean.loc[mask_multibirth, 'short_interval_flag'].mean()*100:.1f}%")

# Child variables
df_anak_analysis['small_birth_size_pct'] = (
    df_anak_analysis['m18'].isin([4, 5])  # 4=small, 5=very small
).astype(int)
print(f"Small birth size: {df_anak_analysis['small_birth_size_pct'].mean()*100:.1f}%")

valid_yes = [1, 2, 3]
mask_12_23 = df_anak_clean['age_months'].between(12, 23)

# Default: NaN (anak di luar 12–23 bulan tidak ikut denominator)
# Full immunization (h2=BCG, h4=DPT1, h6=Polio3, h8=Measles)
# Code 1/2/3 = Yes (card/recall/marked), 0 = No, 8 = Don't know
df_anak_clean['full_immun_binary'] = np.nan

df_anak_clean.loc[mask_12_23, 'full_immun_binary'] = (
    df_anak_clean.loc[mask_12_23, 'h2'].isin(valid_yes) &
    df_anak_clean.loc[mask_12_23, 'h4'].isin(valid_yes) &
    df_anak_clean.loc[mask_12_23, 'h6'].isin(valid_yes) &
    df_anak_clean.loc[mask_12_23, 'h8'].isin(valid_yes)
).astype(int)

print(
    "Full immunization (12–23 mo, all 4 vaccines): "
    f"{df_anak_clean.loc[mask_12_23, 'full_immun_binary'].mean()*100:.1f}%"
)
# Out:
# Feature Engineering
# ----------------------------------------------------------------------
#
# A. Creating Maternal Health Service Indicators:
# 4+ ANC visits: 79.7%
# Facility delivery: 38.3%
# Skilled Birth Attendant: 68.5%
#
# B. Creating Socio-Demographic Indicators:
# Urban residence: 41.4%
# Low education (≤Primary): 49.7%
#
# C. Creating Risk Factor Indicators:
# Risky maternal age: 40.3%
# Short birth interval (<24mo): 27.3%
# Small birth size: 13.9%
# Full immunization (12–23 mo, all 4 vaccines): 64.5%

# %% [markdown]
# #### 3.4 Merging

# %%
# Mother-level indicators

df_ibu_2002 = df_ibu_analysis.copy()

# ANC 4+
df_ibu_2002['anc4_flag'] = (df_ibu_2002['m14_1'] >= 4).astype(int)

# Facility delivery (20–89 = health facility)
df_ibu_2002['facility_flag'] = df_ibu_2002['m15_1'].between(20, 89).astype(int)

# SBA (pakai loop semua m3*_1 kecuali TBA, misal m3f_1)
sba_cols = [c for c in df_ibu_2002.columns if c.startswith('m3') and c.endswith('_1')]
excluded_tba = ['m3f_1']  # sesuaikan kalau TBA di kode lain
sba_cols = [c for c in sba_cols if c not in excluded_tba]
df_ibu_2002['sba_flag'] = df_ibu_2002[sba_cols].eq(1).any(axis=1).astype(int)

# Urban
df_ibu_2002['urban_flag'] = (df_ibu_2002['v025'] == 1).astype(int)

# Low education (≤ primary)
df_ibu_2002['lowedu_flag'] = df_ibu_2002['v106'].isin([0, 1]).astype(int)  # 0 = no edu, 1 = primary

# Risky maternal age (<20 or >=35)
df_ibu_2002['risky_age_flag'] = ((df_ibu_2002['v212'] < 20) | (df_ibu_2002['v212'] >= 35)).astype(int)

# Parity (bisa dipakai langsung mean)
df_ibu_2002['parity'] = df_ibu_2002['parity']

# Scaling Weight
df_ibu_2002['weight'] = df_ibu_2002['v005'] / 1_000_000  # scaling standard DHS

# %%
df_birth = df_lahir_clean.copy()

# Hanya kelahiran dengan older sibling yang punya interval
df_birth_valid = df_birth[df_birth['bord'] > 1].copy()

df_birth_valid['short_interval_flag'] = (df_birth_valid['b11'] < 24).astype(int)

# Aggregate ke ibu: jika ada short interval pada salah satu kelahiran → ibu berisiko
df_interval_mother = (
    df_birth_valid
    .groupby('caseid')['short_interval_flag']
    .max()
    .reset_index()
)

# Merge ke ibu
df_ibu_2002 = df_ibu_2002.merge(df_interval_mother, on='caseid', how='left')

# Ibu yang hanya punya 1 anak (tidak punya interval) = NA → bukan risiko, assign 0
df_ibu_2002['short_interval_flag'] = df_ibu_2002['short_interval_flag'].fillna(0).astype(int)

# %%
# Child-level indicators

df_child_2002 = df_anak_analysis.copy()

# LBW proxy: small_birth_size (m18: 4/5 = small/very small, 1–3 = average/large)
df_child_2002['small_birth_flag'] = df_child_2002['m18'].isin([4, 5]).astype(int)
df_child_2002['small_birth_flag'] = df_child_2002['small_birth_flag'].fillna(0)

# Immunization flags (anggap 1 = received, 2/3 juga treated as received kalau ada)
for col in ['h2', 'h4', 'h6', 'h8']:
    df_child_2002[col + '_flag'] = df_child_2002[col].isin([1, 2, 3]).astype(int)

# Full immunization (semua 4 vaksin diterima)
imm_cols = ['h2_flag', 'h4_flag', 'h6_flag', 'h8_flag']
df_child_2002['full_immun_flag'] = df_child_2002[imm_cols].all(axis=1).astype(int)
df_child_2002['full_immun_flag'] = df_child_2002['full_immun_flag'].fillna(0)

# %%
group_cols = ['v024']  # v024 = province

# Aggregate Mother
prov_mother = (
    df_ibu_2002
    .groupby(group_cols)
    .agg(
        anc4_pct=('anc4_flag', 'mean'),
        facility_delivery_pct=('facility_flag', 'mean'),
        sba_pct=('sba_flag', 'mean'),
        urban_share_pct=('urban_flag', 'mean'),
        low_education_pct=('lowedu_flag', 'mean'),
        risky_maternal_age_pct=('risky_age_flag', 'mean'),
        birth_interval_short_pct=('short_interval_flag', 'mean'),
        avg_parity=('parity', 'mean')
    )
    .reset_index()
)

# Aggregate Child
prov_child = (
    df_child_2002
    .groupby(group_cols)
    .agg(
        lbw_pct=('small_birth_flag', 'mean'),
        full_immun_pct=('full_immun_flag', 'mean')
    )
    .reset_index()
)

# %%
df_2002 = prov_mother.merge(prov_child, on=['v024'], how='left')

df_2002.rename(columns={'v024': 'region'}, inplace=True)

# %%
prov_map = {
    11: "Aceh",
    12: "Sumatera Utara",
    13: "Sumatera Barat",
    14: "Riau",
    15: "Jambi",
    16: "Sumatera Selatan",
    17: "Bengkulu",
    18: "Lampung",
    19: "Kepulauan Bangka Belitung",
    21: "Kepulauan Riau",
    31: "DKI Jakarta",
    32: "Jawa Barat",
    33: "Jawa Tengah",
    34: "DI Yogyakarta",
    35: "Jawa Timur",
    36: "Banten",
    51: "Bali",
    52: "Nusa Tenggara Barat",
    53: "Nusa Tenggara Timur",
    61: "Kalimantan Barat",
    62: "Kalimantan Tengah",
    63: "Kalimantan Selatan",
    64: "Kalimantan Timur",
    65: "Kalimantan Utara",
    71: "Sulawesi Utara",
    72: "Sulawesi Tengah",
    73: "Sulawesi Selatan",
    74: "Sulawesi Tenggara",
    75: "Gorontalo",
    76: "Sulawesi Barat",
    81: "Maluku",
    82: "Maluku Utara",
    91: "Papua",
    92: "Papua Barat",
    94: "Papua Barat"
}

df_2002['province'] = df_2002['region'].map(prov_map)

# cek apakah ada kode yang belum ter-map
unmapped = df_2002[df_2002['province'].isna()]['region'].unique()
print("Unmapped province codes:", unmapped)
# Out:
# Unmapped province codes: []

# %%
cols = df_2002.columns.tolist()

new_order = ['region', 'province'] + [c for c in cols if c not in ['region', 'province']]

# Reorder dataframe
df_2002 = df_2002[new_order]

# %%
# ============================================================================
# FINAL DATA QUALITY SUMMARY
# ============================================================================
print("="*80)
print("FINAL DATA QUALITY SUMMARY – PROVINCIAL INDICATORS")
print("="*80)

# 1. Basic dataset info
print(f"\nTotal observations        : {len(df_2002):,}")
print(f"Unique provinces          : {df_2002['region'].nunique()}")
print(f"Total indicators          : {df_2002.shape[1] - 2} (excluding region/year)")

# 2. Missing check
missing = df_2002.isna().sum()
if missing.sum() == 0:
    print("\nMissing values            : 0")
else:
    print("\nMissing values:")
    print(missing[missing > 0])

# 3. Indicator ranges (auto-detect pct columns)
print("\nIndicator Ranges by Province:")
print("-" * 80)

indicator_cols = [
    col for col in df_2002.columns
    if col not in ['region', 'province'] # Exclude 'province' column from numerical checks
]

for col in indicator_cols:
    col_min = df_2002[col].min()
    col_max = df_2002[col].max()

    # convert to percentage if value seems 0-1
    if col_max <= 1.5:
        print(f"{col:30s}: {col_min*100:6.1f}% – {col_max*100:6.1f}%")
    else:
        print(f"{col:30s}: {col_min:6.2f} – {col_max:6.2f}")

# 4. Quick descriptive stats
print("\nQuick Descriptive Stats:")
print("-" * 80)
print(df_2002[indicator_cols].describe().T[['mean','std','min','max']])

print("\nData preview:")
print(df_2002.head())

print("\nPROCESSING COMPLETE ✔")
print("="*80)
# Out:
# ================================================================================
# FINAL DATA QUALITY SUMMARY – PROVINCIAL INDICATORS
# ================================================================================
#
# Total observations        : 26
# Unique provinces          : 26
# Total indicators          : 10 (excluding region/year)
#
# Missing values            : 0
#
# Indicator Ranges by Province:
# --------------------------------------------------------------------------------
# anc4_pct                      :   63.7% –   96.7%
# facility_delivery_pct         :    5.1% –   89.6%
# sba_pct                       :   42.8% –   94.6%
# urban_share_pct               :   13.1% –  100.0%
# low_education_pct             :   28.3% –   68.9%
# risky_maternal_age_pct        :   22.9% –   51.4%
# birth_interval_short_pct      :   11.7% –   41.7%
# avg_parity                    :   1.98 –   3.11
# lbw_pct                       :    8.6% –   27.8%
# full_immun_pct                :   28.5% –   81.7%
#
# Quick Descriptive Stats:
# --------------------------------------------------------------------------------
#                               mean       std       min       max
# anc4_pct                  0.793785  0.091773  0.637131  0.967302
# facility_delivery_pct     0.375376  0.222920  0.050575  0.895541
# sba_pct                   0.683073  0.141657  0.428283  0.946497
# urban_share_pct           0.398029  0.174278  0.131313  1.000000
# low_education_pct         0.500767  0.112286  0.282803  0.688889
# risky_maternal_age_pct    0.404177  0.085833  0.228883  0.514161
# birth_interval_short_pct  0.233221  0.073479  0.117166  0.417178
# avg_parity                2.542143  0.290144  1.983651  3.108896
# lbw_pct                   0.139238  0.042665  0.086124  0.278008
# full_immun_pct            0.486093  0.126912  0.284698  0.817073
#
# Data preview:
#    region          province  anc4_pct  facility_delivery_pct   sba_pct  \
# 0      12    Sumatera Utara  0.687117               0.338957  0.814417
# 1      13    Sumatera Barat  0.841652               0.595525  0.807229
# 2      14              Riau  0.820106               0.393298  0.770723
# 3      15             Jambi  0.776549               0.247788  0.665929
# 4      16  Sumatera Selatan  0.818182               0.393235  0.763214
#
#    urban_share_pct  low_education_pct  risky_maternal_age_pct  \
# 0         0.403374           0.384969                0.283742
# 1         0.321859           0.376936                0.330465
# 2         0.499118           0.421517                0.366843
# 3         0.274336           0.577434                0.511062
# 4         0.325581           0.532770                0.435518
#
#    birth_interval_short_pct  avg_parity   lbw_pct  full_immun_pct
# 0                  0.417178    3.108896  0.095628        0.300546
# 1                  0.299484    2.843373  0.139860        0.531469
# 2                  0.255732    2.578483  0.135889        0.501742
# 3                  0.185841    2.504425  0.116822        0.369159
# 4                  0.217759    2.553911  0.086124        0.459330
#
# PROCESSING COMPLETE ✔
# ================================================================================

# %%
print("Saving Results")

df_2002.to_csv('dhs_regional_2002.csv', index=False)
print("Files saved successfully!")
# Out:
# Saving Results
# Files saved successfully!

# %% [markdown]
# ## Merge All Year

# %%
# Mapping provinsi baru -> provinsi induk (kode lama, 26 provinsi)
PROV_BACKWARD_MAP = {
    36: 32,  # Banten        -> Jawa Barat
    21: 14,  # Kep. Riau     -> Riau
    75: 71,  # Gorontalo     -> Sulawesi Utara
    76: 73,  # Sulawesi Barat-> Sulawesi Selatan
    92: 91,  # Papua Barat   -> Papua
    94: 91,  # varian kode Papua Barat (kalau muncul)
}

def wavg(x, w):
    """Weighted average yang aman terhadap NaN."""
    x = np.asarray(x, dtype=float)
    w = np.asarray(w, dtype=float)
    mask = ~np.isnan(x) & ~np.isnan(w)
    if mask.sum() == 0:
        return np.nan
    return np.average(x[mask], weights=w[mask])

# %%
def aggregate_province_year(
    df_mother,
    df_child,
    year,
    region_col='v024',
    weight_col='v005',
    apply_backward_mapping=True,
):
    """
    df_mother : dataframe level ibu (sudah FE)
    df_child  : dataframe level anak (sudah FE, small_birth_flag & full_immun_flag)
    year      : int (2002, 2007, 2012, 2017)
    region_col: kolom kode provinsi (v024/region)
    weight_col: kolom sampling weight DHS (v005)
    apply_backward_mapping:
        - 2002  -> False
        - 2007+ -> True
    """

    # --- copy & siapkan weight ---
    dm = df_mother.copy()
    dc = df_child.copy()

    # buang baris yang ga punya region / weight
    dm = dm[dm[region_col].notna() & dm[weight_col].notna()].copy()
    dc = dc[dc[region_col].notna() & dc[weight_col].notna()].copy()

    # pastikan region integer
    dm[region_col] = dm[region_col].astype(int)
    dc[region_col] = dc[region_col].astype(int)

    # scaling weight DHS
    dm['weight'] = dm[weight_col] / 1_000_000.0
    dc['weight'] = dc[weight_col] / 1_000_000.0

    # backward mapping (33 -> 26) kalau diminta
    if apply_backward_mapping:
        dm[region_col] = dm[region_col].replace(PROV_BACKWARD_MAP)
        dc[region_col] = dc[region_col].replace(PROV_BACKWARD_MAP)

    # --- daftar fitur yang mau di-aggregate ---
    mother_features = {
        'anc4_pct': 'anc4_flag',
        'facility_delivery_pct': 'facility_flag',
        'sba_pct': 'sba_flag',
        'urban_share_pct': 'urban_flag',
        'low_education_pct': 'lowedu_flag',
        'risky_maternal_age_pct': 'risky_age_flag',
        'birth_interval_short_pct': 'short_interval_flag',
        'avg_parity': 'parity',
    }

    child_features = {
        'lbw_pct': 'small_birth_flag',
        'full_immun_pct': 'full_immun_flag',
    }

    # filter kolom yang benar-benar ada (kalau beda tahun beda var)
    mother_features = {
        out: col for out, col in mother_features.items()
        if col in dm.columns
    }
    child_features = {
        out: col for out, col in child_features.items()
        if col in dc.columns
    }

    # --- aggregate mother-level (weighted) ---
    def agg_mother(group):
        w = group['weight'].values
        out = {}
        for out_name, col in mother_features.items():
            out[out_name] = wavg(group[col].values, w)
        return pd.Series(out)

    prov_mother = (
        dm
        .groupby(region_col)
        .apply(agg_mother)
        .reset_index()
    )

    # --- aggregate child-level (weighted) ---
    def agg_child(group):
        w = group['weight'].values
        out = {}
        for out_name, col in child_features.items():
            out[out_name] = wavg(group[col].values, w)
        return pd.Series(out)

    prov_child = (
        dc
        .groupby(region_col)
        .apply(agg_child)
        .reset_index()
    )

    # --- merge mother + child ---
    prov = prov_mother.merge(prov_child, on=region_col, how='left')

    # tambah kolom year & rapikan urutan kolom
    prov['year'] = year
    cols = ['year', region_col] + [c for c in prov.columns if c not in ['year', region_col]]
    prov = prov[cols]

    return prov

# %%
# 2002: belum ada pemekaran (26 prov), TIDAK backward-mapping
prov_2002 = aggregate_province_year(
    df_mother=df_ibu_2002,
    df_child=df_child_2002,
    year=2002,
    region_col='v024',
    weight_col='v005',
    apply_backward_mapping=False
)

# 2007
prov_2007 = aggregate_province_year(
    df_mother=df_ibu_2007,
    df_child=df_child_2007,
    year=2007,
    region_col='v024',
    weight_col='v005',
    apply_backward_mapping=True
)

# 2012
prov_2012 = aggregate_province_year(
    df_mother=df_ibu_2012,
    df_child=df_child_2012,
    year=2012,
    region_col='v024',
    weight_col='v005',
    apply_backward_mapping=True
)

# 2017
prov_2017 = aggregate_province_year(
    df_mother=df_ibu_2017,
    df_child=df_child_2017,
    year=2017,
    region_col='v024',
    weight_col='v005',
    apply_backward_mapping=True
)

# cek jumlah provinsi per tahun
for df in [prov_2002, prov_2007, prov_2012, prov_2017]:
    print(df['year'].iloc[0], df['v024'].nunique())
# Out:
# 2002 26
# 2007 28
# 2012 28
# 2017 29

# %%
base = set(prov_2002['v024'])  # atau 'region' kalau nama kolomnya itu

for df in [prov_2007, prov_2012, prov_2017]:
    year = df['year'].iloc[0]
    regs = set(df['v024'])
    extra = sorted(regs - base)
    print(year, "extra codes:", extra)
# Out:
# 2007 extra codes: [11, 81, 82, 91]
# 2012 extra codes: [11, 81, 82, 91]
# 2017 extra codes: [11, 65, 81, 82, 91]

# %%
print("prov 2002 unique:", sorted(prov_2002['v024'].unique()))
print("length:", len(prov_2002['v024'].unique()))
# Out:
# prov 2002 unique: [np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(31), np.int64(32), np.int64(33), np.int64(34), np.int64(35), np.int64(36), np.int64(51), np.int64(52), np.int64(53), np.int64(61), np.int64(62), np.int64(63), np.int64(64), np.int64(71), np.int64(72), np.int64(73), np.int64(74), np.int64(75)]
# length: 26

# %%
region_col = 'v024'

regs_2002 = set(prov_2002[region_col].unique())
regs_2007 = set(prov_2007[region_col].unique())
regs_2012 = set(prov_2012[region_col].unique())
regs_2017 = set(prov_2017[region_col].unique())

stable_regions = regs_2002 & regs_2007 & regs_2012 & regs_2017
print("Stable regions:", sorted(stable_regions), " (n =", len(stable_regions), ")")
# Out:
# Stable regions: [np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(31), np.int64(32), np.int64(33), np.int64(34), np.int64(35), np.int64(51), np.int64(52), np.int64(53), np.int64(61), np.int64(62), np.int64(63), np.int64(64), np.int64(71), np.int64(72), np.int64(73), np.int64(74)]  (n = 24 )

# %%
def align_to_stable(df_year, year, stable_regions, region_col='region'):
    df = df_year.copy()
    df['year'] = year
    df = df[df[region_col].isin(stable_regions)].copy()
    df[region_col] = df[region_col].astype(int)
    df = df.sort_values([region_col]).reset_index(drop=True)
    return df

prov_2002_aligned = align_to_stable(prov_2002, 2002, stable_regions, region_col)
prov_2007_aligned = align_to_stable(prov_2007, 2007, stable_regions, region_col)
prov_2012_aligned = align_to_stable(prov_2012, 2012, stable_regions, region_col)
prov_2017_aligned = align_to_stable(prov_2017, 2017, stable_regions, region_col)

for df in [prov_2002_aligned, prov_2007_aligned, prov_2012_aligned, prov_2017_aligned]:
    print(df['year'].iloc[0], df[region_col].nunique())
# Out:
# 2002 24
# 2007 24
# 2012 24
# 2017 24

# %%
meta_cols = ['year', region_col]
indicator_cols = [c for c in prov_2002_aligned.columns if c not in meta_cols]

panel = pd.concat(
    [prov_2002_aligned, prov_2007_aligned, prov_2012_aligned, prov_2017_aligned],
    ignore_index=True
)

print(panel.groupby('year')[region_col].nunique())

prov_name_map = {
    12: "Sumatera Utara",
    13: "Sumatera Barat",
    14: "Riau",
    15: "Jambi",
    16: "Sumatera Selatan",
    17: "Bengkulu",
    18: "Lampung",
    19: "Kep. Bangka Belitung",
    31: "DKI Jakarta",
    32: "Jawa Barat",
    33: "Jawa Tengah",
    34: "DI Yogyakarta",
    35: "Jawa Timur",
    36: "Banten",
    51: "Bali",
    52: "Nusa Tenggara Barat",
    53: "Nusa Tenggara Timur",
    61: "Kalimantan Barat",
    62: "Kalimantan Tengah",
    63: "Kalimantan Selatan",
    64: "Kalimantan Timur",
    71: "Sulawesi Utara",
    72: "Sulawesi Tengah",
    73: "Sulawesi Selatan",
    74: "Sulawesi Tenggara",
    75: "Gorontalo",
}

panel['province_name'] = panel[region_col].map(prov_name_map)
panel = panel[['year', region_col, 'province_name'] + indicator_cols]

panel.head()
# Out:
# year
# 2002    24
# 2007    24
# 2012    24
# 2017    24
# Name: v024, dtype: int64
#    year  v024     province_name  anc4_pct  facility_delivery_pct   sba_pct  \
# 0  2002    12    Sumatera Utara  0.709615               0.344487  0.827922
# 1  2002    13    Sumatera Barat  0.865139               0.602981  0.820163
# 2  2002    14              Riau  0.837971               0.381888  0.758697
# 3  2002    15             Jambi  0.799175               0.379680  0.718145
# 4  2002    16  Sumatera Selatan  0.793440               0.371098  0.773976
#
#    urban_share_pct  low_education_pct  risky_maternal_age_pct  \
# 0         0.429960           0.386486                0.278940
# 1         0.394327           0.337632                0.299571
# 2         0.534813           0.394638                0.366670
# 3         0.310392           0.502543                0.451023
# 4         0.313627           0.545571                0.449110
#
#    birth_interval_short_pct  avg_parity   lbw_pct  full_immun_pct
# 0                  0.391190    3.019732  0.115147        0.348179
# 1                  0.300608    2.816498  0.149896        0.539392
# 2                  0.247384    2.578850  0.130668        0.496350
# 3                  0.171904    2.399863  0.081931        0.395001
# 4                  0.224071    2.602079  0.096247        0.467269

# %%
panel.to_csv('dhs_regional_panel.csv', index=False)
print("Files saved successfully!")
# Out:
# Files saved successfully!

# %% [markdown]
# # Extract IMR Data

# %%
imr_2012 = pd.read_csv('imr_2012.csv',skiprows=2, header=None)
imr_2012.columns = ["provinsi", "imr"]
imr_2012["tahun"] = 2012
imr_2012 = imr_2012.dropna(subset=["provinsi"])

# Reset index
imr_2012 = imr_2012.reset_index(drop=True)

# Convert IMR to numeric
imr_2012["imr"] = pd.to_numeric(imr_2012["imr"], errors="coerce")

imr_2012["provinsi"] = imr_2012["provinsi"].str.title()

# %%
imr_2012_long = imr_2012.rename(columns={
    "province": "provinsi",
    "imr": "imr_per_1k",
    "year": "tahun"
})[["provinsi", "tahun", "imr_per_1k"]]

# %%
FILE_WIDE = "akb_1971_2020.csv"
OUT = "data_imr_bps.csv"
MIN_YEAR = 2000

# Read File
df = pd.read_csv(FILE_WIDE, dtype=str)

# Normalisasi (wide table with multi-row header) ---
header_row = df.iloc[2].tolist()
df.columns = df.columns.str.lower() # Corrected line

# buat kolom: first = 'provinsi', sisanya adalah tahun (kita ekstrak 4-digit year)
years = []
for v in header_row[1:]:
    if pd.isna(v):
        years.append(None)
    else:
        m = re.search(r'(19|20)\d{2}', str(v))
        years.append(m.group(0) if m else str(v))
cols = ['provinsi'] + years

# data aktual mulai dari row index 3
data_rows = df.iloc[3:].copy()
data_rows.columns = cols

# extract from 2000, 2010, & 2020
wanted = ['provinsi', '2000', '2010', '2020']
available = [c for c in wanted if c in data_rows.columns]
df_sub = data_rows[available].reset_index(drop=True)

# melt into long format (provinsi, tahun, imr_per_1k)
df_wide_long = df_sub.melt(id_vars='provinsi', var_name='tahun', value_name='imr_per_1k')

# cleaning nilai & convert as numeric (float)
df_wide_long['imr_per_1k'] = (
    df_wide_long['imr_per_1k'].astype(str)
    .str.replace(',', '.')
    .str.extract(r'(\d+\.?\d*)')[0]
)

df_wide_long = df_wide_long.dropna(subset=['imr_per_1k'])
df_wide_long['imr_per_1k'] = df_wide_long['imr_per_1k'].astype(float)

# tahun as string
df_wide_long['tahun'] = df_wide_long['tahun'].astype(str)

# Ambil daftar provinsi dari df (dipakai untuk filter long-form) ---
provinces = df_sub['provinsi'].dropna().astype(str).str.strip().tolist()

df_all = pd.concat([df_wide_long], ignore_index=True, sort=False)

# final tidy: standardisasi nama provinsi ringan & tipe data
def normalize_name(s):
    s = str(s).strip()
    if s.lower() in ['dki', 'dki jakarta', 'dkijakarta']:
        return "DKI Jakarta"
    if 'yogyakarta' in s.lower():
        return "DI Yogyakarta"
    return ' '.join(w.capitalize() for w in s.split())

df_all['provinsi'] = df_all['provinsi'].apply(normalize_name)
df_all['tahun'] = df_all['tahun'].astype(int)
df_all['imr_per_1k'] = df_all['imr_per_1k'].round(2)

# simpan
df_all.to_csv(OUT, index=False, encoding='utf-8')
print("Saved:", OUT)
print(df_all.head(15).to_string(index=False))
# Out:
# Saved: data_imr_bps.csv
#                  provinsi  tahun  imr_per_1k
#                      Aceh   2000        40.0
#            Sumatera Utara   2000        44.0
#            Sumatera Barat   2000        53.0
#                      Riau   2000        48.0
#                     Jambi   2000        53.0
#          Sumatera Selatan   2000        53.0
#                  Bengkulu   2000        53.0
#                   Lampung   2000        48.0
# Kepulauan Bangka Belitung   2000        53.0
#               DKI Jakarta   2000        25.0
#                Jawa Barat   2000        57.0
#               Jawa Tengah   2000        44.0
#             DI Yogyakarta   2000        25.0
#                Jawa Timur   2000        48.0
#                    Banten   2000        66.0

# %%
imr_data = pd.read_csv('data_imr_bps.csv')

panel_imr = pd.concat([imr_data, imr_2012_long], ignore_index=True)

panel_imr["tahun"] = panel_imr["tahun"].astype(int)

panel_imr = panel_imr.sort_values(["provinsi", "tahun"]).reset_index(drop=True)
panel_imr.head()
# Out:
#   provinsi  tahun  imr_per_1k
# 0     Aceh   2000       40.00
# 1     Aceh   2010       28.00
# 2     Aceh   2012       47.00
# 3     Aceh   2020       19.41
# 4     Bali   2000       36.00

# %%
panel_imr.to_csv('panel_imr.csv', index=False)
print("Files saved successfully!")
# Out:
# Files saved successfully!
